# %% [markdown]
# # MadMiner physics tutorial (part 3B)
#
# Johann Brehmer, Felix Kling, Irina Espejo, and Kyle Cranmer 2018-2019

# %% [markdown]
# In part 3A of this tutorial we will finally train a neural network to estimate likelihood ratios. We assume that you have run part 1 and 2A of this tutorial. If, instead of 2A, you have run part 2B, you just have to load a different filename later.

# %% [markdown]
# ## Preparations

# %% [markdown]
# Make sure you've run the first tutorial before executing this notebook!

# %%
import logging
import numpy as np
import matplotlib
from matplotlib import pyplot as plt

# %matplotlib inline

from madminer.sampling import SampleAugmenter
from madminer import sampling
from madminer.ml import ScoreEstimator

# %%
# MadMiner output
logging.basicConfig(
    format="%(asctime)-5.5s %(name)-20.20s %(levelname)-7.7s %(message)s",
    datefmt="%H:%M",
    level=logging.INFO,
)

# Output of all other modules (e.g. matplotlib)
for key in logging.Logger.manager.loggerDict:
    if "madminer" not in key:
        logging.getLogger(key).setLevel(logging.WARNING)

# %% [markdown]
# ## 1. Make (unweighted) training and test samples with augmented data

# %% [markdown]
# At this point, we have all the information we need from the simulations. But the data is not quite ready to be used for machine learning. The `madminer.sampling` class `SampleAugmenter` will take care of the remaining book-keeping steps before we can train our estimators:
#
# First, it unweights the samples, i.e. for a given parameter vector `theta` (or a distribution `p(theta)`) it picks events `x` such that their distribution follows `p(x|theta)`. The selected samples will all come from the event file we have so far, but their frequency is changed -- some events will appear multiple times, some will disappear.
#
# Second, `SampleAugmenter` calculates all the augmented data ("gold") that is the key to our new inference methods. Depending on the specific technique, these are the joint likelihood ratio and / or the joint score. It saves all these pieces of information for the selected events in a set of numpy files that can easily be used in any machine learning framework.

# %%
sampler = SampleAugmenter("data/lhe_data_shuffled.h5")
# sampler = SampleAugmenter('data/delphes_data_shuffled.h5')
# Out:
# 13:12 madminer.analysis.da INFO    Loading data from data/lhe_data_shuffled.h5
# 13:12 madminer.utils.inter INFO    HDF5 file does not contain nuisance parameters information
# 13:12 madminer.utils.inter INFO    HDF5 file does not contain finite difference information
# 13:12 madminer.utils.inter INFO    HDF5 file does not contain systematic information
# 13:12 madminer.analysis.da INFO    Found 2 parameters
# 13:12 madminer.analysis.da INFO      0: CWL2 (LHA: dim6 2, Power: 2, Range: (-20.0, 20.0))
# 13:12 madminer.analysis.da INFO      1: CPWL2 (LHA: dim6 5, Power: 2, Range: (-20.0, 20.0))
# 13:12 madminer.analysis.da INFO    Did not find nuisance parameters
# 13:12 madminer.analysis.da INFO    Found 6 benchmarks
# 13:12 madminer.analysis.da INFO    Found 3 observables
# 13:12 madminer.analysis.da INFO    Found 89993 events
# 13:12 madminer.analysis.da INFO      49993 signal events sampled from benchmark sm
# 13:12 madminer.analysis.da INFO      10000 signal events sampled from benchmark w
# 13:12 madminer.analysis.da INFO      10000 signal events sampled from benchmark neg_w
# 13:12 madminer.analysis.da INFO      10000 signal events sampled from benchmark ww
# 13:12 madminer.analysis.da INFO      10000 signal events sampled from benchmark neg_ww
# 13:12 madminer.analysis.da INFO      0 signal events sampled from benchmark morphing_basis_vector_5
# 13:12 madminer.analysis.da INFO    Found morphing setup with 6 components
# 13:12 madminer.analysis.da INFO    Did not find nuisance morphing setup

# %% [markdown]
# The relevant `SampleAugmenter` function for local score estimators is `extract_samples_train_local()`. As in part 3a of the tutorial, for the argument `theta` you can use the helper functions `sampling.benchmark()`, `sampling.benchmarks()`, `sampling.morphing_point()`, `sampling.morphing_points()`, and `sampling.random_morphing_points()`.

# %%
x, theta, t_xz, _ = sampler.sample_train_local(
    theta=sampling.benchmark("sm"),
    n_samples=500000,
    folder="./data/samples",
    filename="train_score",
)
# Out:
# 13:12 madminer.sampling.sa INFO    Extracting training sample for local score regression. Sampling and score evaluation according to sm
# 13:12 madminer.sampling.sa INFO    Starting sampling serially
# 13:12 madminer.sampling.sa INFO    Sampling from parameter point 1 / 1
# 13:12 madminer.sampling.sa INFO    Effective number of samples: mean 29939.0, with individual thetas ranging from 29939.0 to 29939.0

# %% [markdown]
# We can use the same data as in part 3a, so you only have to execute this if you haven't gone through tutorial 3a:

# %%
_ = sampler.sample_test(
    theta=sampling.benchmark("sm"),
    n_samples=1000,
    folder="./data/samples",
    filename="test",
)
# Out:
# 13:12 madminer.sampling.sa INFO    Extracting evaluation sample. Sampling according to sm
# 13:12 madminer.sampling.sa INFO    Starting sampling serially
# 13:12 madminer.sampling.sa INFO    Sampling from parameter point 1 / 1
# 13:12 madminer.sampling.sa INFO    Effective number of samples: mean 9988.0, with individual thetas ranging from 9988.0 to 9988.0

# %% [markdown]
# ## 2. Train score estimator

# %% [markdown]
# It's now time to build a neural network. Only this time, instead of the likelihood ratio itself, we will estimate the gradient of the log likelihood with respect to the theory parameters -- the score. To be precise, the output of the neural network is an estimate of the score at some reference parameter point, for instance the Standard Model. A neural network that estimates this "local" score can be used to calculate the Fisher information at that point. The estimated score can also be used as a machine learning version of Optimal Observables, and likelihoods can be estimated based on density estimation in the estimated score space. This method for likelihood ratio estimation is called SALLY, and there is a closely related version called SALLINO. Both are explained in ["Constraining Effective Field Theories With Machine Learning"](https://arxiv.org/abs/1805.00013) and ["A Guide to Constraining Effective Field Theories With Machine Learning"](https://arxiv.org/abs/1805.00020).
#
# The central object for this is the `madminer.ml.ScoreEstimator` class:

# %%
estimator = ScoreEstimator(n_hidden=(30, 30))

# %%
estimator.train(
    method="sally",
    x="data/samples/x_train_score.npy",
    t_xz="data/samples/t_xz_train_score.npy",
)

estimator.save("models/sally")
# Out:
# 13:12 madminer.ml.score    INFO    Starting training
# 13:12 madminer.ml.score    INFO      Batch size:             128
# 13:12 madminer.ml.score    INFO      Optimizer:              amsgrad
# 13:12 madminer.ml.score    INFO      Epochs:                 50
# 13:12 madminer.ml.score    INFO      Learning rate:          0.001 initially, decaying to 0.0001
# 13:12 madminer.ml.score    INFO      Validation split:       0.25
# 13:12 madminer.ml.score    INFO      Early stopping:         True
# 13:12 madminer.ml.score    INFO      Scale inputs:           True
# 13:12 madminer.ml.score    INFO      Shuffle labels          False
# 13:12 madminer.ml.score    INFO      Samples:                all
# 13:12 madminer.ml.score    INFO    Loading training data
# 13:12 madminer.utils.vario INFO      Loading data/samples/x_train_score.npy into RAM
# 13:12 madminer.utils.vario INFO      Loading data/samples/t_xz_train_score.npy into RAM
# 13:12 madminer.ml.score    INFO    Found 500000 samples with 2 parameters and 3 observables
# 13:12 madminer.ml.base     INFO    Setting up input rescaling
# 13:12 madminer.ml.score    INFO    Creating model
# 13:12 madminer.ml.score    INFO    Training model
# 13:12 madminer.utils.ml.tr INFO    Training on CPU with single precision
# 13:13 madminer.utils.ml.tr INFO      Epoch   2: train loss  0.20300 (mse_score:  0.203)
# 13:13 madminer.utils.ml.tr INFO                 val. loss   0.18839 (mse_score:  0.188)
# 13:14 madminer.utils.ml.tr INFO      Epoch   4: train loss  0.18964 (mse_score:  0.190)
# 13:14 madminer.utils.ml.tr INFO                 val. loss   0.18099 (mse_score:  0.181)
# 13:14 madminer.utils.ml.tr INFO      Epoch   6: train loss  0.18228 (mse_score:  0.182)
# 13:14 madminer.utils.ml.tr INFO                 val. loss   0.17917 (mse_score:  0.179)
# 13:15 madminer.utils.ml.tr INFO      Epoch   8: train loss  0.17750 (mse_score:  0.178)
# 13:15 madminer.utils.ml.tr INFO                 val. loss   0.17589 (mse_score:  0.176)
# 13:15 madminer.utils.ml.tr INFO      Epoch  10: train loss  0.17362 (mse_score:  0.174)
# 13:15 madminer.utils.ml.tr INFO                 val. loss   0.17289 (mse_score:  0.173)
# 13:16 madminer.utils.ml.tr INFO      Epoch  12: train loss  0.17106 (mse_score:  0.171)
# 13:16 madminer.utils.ml.tr INFO                 val. loss   0.17050 (mse_score:  0.171)
# 13:17 madminer.utils.ml.tr INFO      Epoch  14: train loss  0.16890 (mse_score:  0.169)
# 13:17 madminer.utils.ml.tr INFO                 val. loss   0.16882 (mse_score:  0.169)
# 13:17 madminer.utils.ml.tr INFO      Epoch  16: train loss  0.16713 (mse_score:  0.167)
# 13:17 madminer.utils.ml.tr INFO                 val. loss   0.16820 (mse_score:  0.168)
# 13:18 madminer.utils.ml.tr INFO      Epoch  18: train loss  0.16558 (mse_score:  0.166)
# 13:18 madminer.utils.ml.tr INFO                 val. loss   0.16715 (mse_score:  0.167)
# 13:18 madminer.utils.ml.tr INFO      Epoch  20: train loss  0.16409 (mse_score:  0.164)
# 13:18 madminer.utils.ml.tr INFO                 val. loss   0.16615 (mse_score:  0.166)
# 13:19 madminer.utils.ml.tr INFO      Epoch  22: train loss  0.16294 (mse_score:  0.163)
# 13:19 madminer.utils.ml.tr INFO                 val. loss   0.16523 (mse_score:  0.165)
# 13:19 madminer.utils.ml.tr INFO      Epoch  24: train loss  0.16211 (mse_score:  0.162)
# 13:19 madminer.utils.ml.tr INFO                 val. loss   0.16409 (mse_score:  0.164)
# 13:20 madminer.utils.ml.tr INFO      Epoch  26: train loss  0.16126 (mse_score:  0.161)
# 13:20 madminer.utils.ml.tr INFO                 val. loss   0.16438 (mse_score:  0.164)
# 13:20 madminer.utils.ml.tr INFO      Epoch  28: train loss  0.16044 (mse_score:  0.160)
# 13:20 madminer.utils.ml.tr INFO                 val. loss   0.16319 (mse_score:  0.163)
# 13:21 madminer.utils.ml.tr INFO      Epoch  30: train loss  0.15990 (mse_score:  0.160)
# 13:21 madminer.utils.ml.tr INFO                 val. loss   0.16331 (mse_score:  0.163)
# 13:22 madminer.utils.ml.tr INFO      Epoch  32: train loss  0.15934 (mse_score:  0.159)
# 13:22 madminer.utils.ml.tr INFO                 val. loss   0.16369 (mse_score:  0.164)
# 13:22 madminer.utils.ml.tr INFO      Epoch  34: train loss  0.15881 (mse_score:  0.159)
# 13:22 madminer.utils.ml.tr INFO                 val. loss   0.16214 (mse_score:  0.162)
# 13:23 madminer.utils.ml.tr INFO      Epoch  36: train loss  0.15845 (mse_score:  0.158)
# 13:23 madminer.utils.ml.tr INFO                 val. loss   0.16217 (mse_score:  0.162)
# 13:23 madminer.utils.ml.tr INFO      Epoch  38: train loss  0.15808 (mse_score:  0.158)
# 13:23 madminer.utils.ml.tr INFO                 val. loss   0.16186 (mse_score:  0.162)
# 13:24 madminer.utils.ml.tr INFO      Epoch  40: train loss  0.15777 (mse_score:  0.158)
# 13:24 madminer.utils.ml.tr INFO                 val. loss   0.16147 (mse_score:  0.161)
# 13:24 madminer.utils.ml.tr INFO      Epoch  42: train loss  0.15747 (mse_score:  0.157)
# 13:24 madminer.utils.ml.tr INFO                 val. loss   0.16124 (mse_score:  0.161)
# 13:25 madminer.utils.ml.tr INFO      Epoch  44: train loss  0.15724 (mse_score:  0.157)
# 13:25 madminer.utils.ml.tr INFO                 val. loss   0.16096 (mse_score:  0.161)
# 13:25 madminer.utils.ml.tr INFO      Epoch  46: train loss  0.15702 (mse_score:  0.157)
# 13:25 madminer.utils.ml.tr INFO                 val. loss   0.16087 (mse_score:  0.161)
# 13:26 madminer.utils.ml.tr INFO      Epoch  48: train loss  0.15672 (mse_score:  0.157)
# 13:26 madminer.utils.ml.tr INFO                 val. loss   0.16099 (mse_score:  0.161)
# 13:26 madminer.utils.ml.tr INFO      Epoch  50: train loss  0.15658 (mse_score:  0.157)
# 13:26 madminer.utils.ml.tr INFO                 val. loss   0.16060 (mse_score:  0.161)
# 13:26 madminer.utils.ml.tr INFO    Early stopping did not improve performance
# 13:26 madminer.utils.ml.tr INFO    Training time spend on:
# 13:26 madminer.utils.ml.tr INFO                      initialize model:   0.00h
# 13:26 madminer.utils.ml.tr INFO                                   ALL:   0.23h
# 13:26 madminer.utils.ml.tr INFO                            check data:   0.00h
# 13:26 madminer.utils.ml.tr INFO                          make dataset:   0.00h
# 13:26 madminer.utils.ml.tr INFO                       make dataloader:   0.00h
# 13:26 madminer.utils.ml.tr INFO                       setup optimizer:   0.00h
# 13:26 madminer.utils.ml.tr INFO                   initialize training:   0.00h
# 13:26 madminer.utils.ml.tr INFO                                set lr:   0.00h
# 13:26 madminer.utils.ml.tr INFO                   load training batch:   0.10h
# 13:26 madminer.utils.ml.tr INFO                        fwd: move data:   0.00h
# 13:26 madminer.utils.ml.tr INFO                   fwd: check for nans:   0.00h
# 13:26 madminer.utils.ml.tr INFO                    fwd: model.forward:   0.01h
# 13:26 madminer.utils.ml.tr INFO                 fwd: calculate losses:   0.00h
# 13:26 madminer.utils.ml.tr INFO                 training forward pass:   0.02h
# 13:26 madminer.utils.ml.tr INFO                   training sum losses:   0.00h
# 13:26 madminer.utils.ml.tr INFO                        opt: zero grad:   0.00h
# 13:26 madminer.utils.ml.tr INFO                         opt: backward:   0.01h
# 13:26 madminer.utils.ml.tr INFO                   opt: clip grad norm:   0.00h
# 13:26 madminer.utils.ml.tr INFO                             opt: step:   0.01h
# 13:26 madminer.utils.ml.tr INFO                        optimizer step:   0.03h
# 13:26 madminer.utils.ml.tr INFO                 load validation batch:   0.08h
# 13:26 madminer.utils.ml.tr INFO               validation forward pass:   0.00h
# 13:26 madminer.utils.ml.tr INFO                 validation sum losses:   0.00h
# 13:26 madminer.utils.ml.tr INFO                        early stopping:   0.00h
# 13:26 madminer.utils.ml.tr INFO                          report epoch:   0.00h
# 13:26 madminer.ml.base     INFO    Saving model to models/sally

# %% [markdown]
# ## 3. Evaluate score estimator

# %% [markdown]
# Let's evaluate the SM score on the test data

# %%
estimator.load("models/sally")

t_hat = estimator.evaluate_score(x="data/samples/x_test.npy")
# Out:
# 13:26 madminer.ml.base     INFO    Loading model from models/sally
# 13:26 madminer.utils.vario INFO      Loading data/samples/x_test.npy into RAM

# %% [markdown]
# Let's have a look at the estimated score and how it is related to the observables:

# %%
x = np.load("data/samples/x_test.npy")

fig = plt.figure(figsize=(10, 4))

for i in range(2):
    ax = plt.subplot(1, 2, i + 1)
    sc = plt.scatter(
        x[:, 0],
        x[:, 1],
        c=t_hat[:, i],
        s=25.0,
        cmap="viridis",
        vmin=-1.0,
        vmax=+1.0,
    )

    cbar = plt.colorbar(sc)

    cbar.set_label(r"$\hat{t}_" + str(i) + r"(x | \theta_{ref})$")
    plt.xlabel(r"$p_{T,j1}$ [GeV]")
    plt.ylabel(r"$\Delta \phi_{jj}$")
    plt.xlim(10.0, 300.0)
    plt.ylim(-3.15, 3.15)

plt.tight_layout()
plt.show()
