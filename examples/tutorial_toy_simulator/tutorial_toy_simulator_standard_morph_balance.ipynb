# %% [markdown]
# # Toy example
#
# Original notebook by Alexander Held, edited for the MadMiner repository by Johann Brehmer, Irina Espejo, Felix Kling, and Kyle Cranmer 2018-2019.

# %% [markdown]
# In this notebook, we use a simple toy example to demonstrate the machine learning and inference algorithms in MadMiner. This allows us to skip many of the more technical steps, and there's no dependency on MadGraph, Pythia, or Delphes.
#
# What this tutorial does not do, is explaining the inference methods. To understand what's happening, please have a look at ["Constraining Effective Field Theories With Machine Learning"](https://arxiv.org/abs/1805.00013), which will explain the basic idea in just a few pages. If you really want to get down to the dirty details, ["A Guide to Constraining Effective Field Theories With Machine Learning"](https://arxiv.org/abs/1805.00020) has you covered.

# %% [markdown]
# ## Preparations

# %%
import os
import logging
import numpy as np
from scipy.stats import norm
from matplotlib import pyplot as plt

# %matplotlib inline
import sys
sys.path.append('/remote/gpu02/crescenzo/MadMiner')

from madminer.ml import ParameterizedRatioEstimator, MorphParameterizedRatioEstimator

# %%
if not os.path.exists("data_balanced_morph"):
    os.makedirs("data_balanced_morph")

# %% [markdown]
# MadMiner uses the Python `logging` module to provide additional information and debugging output. You can choose how much of this output you want to see by switching the level in the following lines to `logging.DEBUG` or `logging.WARNING`.

# %%
# MadMiner output
logging.basicConfig(
    format="%(asctime)-5.5s %(name)-20.20s %(levelname)-7.7s %(message)s",
    datefmt="%H:%M",
    level=logging.INFO,
)

# Output of all other modules (e.g. matplotlib)
for key in logging.Logger.manager.loggerDict:
    if "madminer" not in key:
        logging.getLogger(key).setLevel(logging.WARNING)

# %% [markdown]
# ## 1. A toy simulator

# %% [markdown]
# Our simulator depends on just one parameter `theta` and produces one-dimensional observables `x`. It is characterized by one latent variable `z`. "Running" the simulator consists of two steps:
# - "Hard process": a value of `z` is drawn from a normal distribution, where the mean depends on `theta`.
# - "Detector": a value for `x` is drawn from a normal distribution with mean equal to `z`. There is no explicit dependence on `theta`.
#
# As in the particle physics case, we assume that we can calculate the joint likelihood ratio `r(x, z | theta0, theta1)` as well as the joint score `t(x, z | theta)`, which depend explicitly on `z` (and where the "detector" part cancels).
#
# Here are some general settings (feel free to play with them):

# %%
z_std = 2.0
x_std = 1.0

# %% [markdown]
# The following function runs the simulator for a value of `theta` and calculates the joint likelihood ratio between `theta0` and `theta1` as well as the joint score at `theta_score`:

# %%
alpha=3

# %%
npoints = 100

# %%
theta = 100

# %%
z1 = np.random.normal(loc=0, scale=z_std, size=npoints)
z2 = np.random.normal(loc=alpha, scale=z_std, size=npoints)
mask = np.random.choice([True, False],p=[1./(1+theta**2),theta**2/(1+theta**2)],size=npoints)

# %%
z1[mask].flatten()
# Out:
# array([], dtype=float64)

# %%
np.concatenate((z1[mask],z2[~mask]))
# Out:
# array([ 0.64253062,  0.59365342,  3.87320859,  1.31390282,  1.98853515,
#         6.07738364,  4.39908806,  4.6774243 ,  3.57220205,  3.33706176,
#         3.57105285,  2.31928873,  2.29097529,  1.70675001,  3.92549139,
#         4.37399834,  3.09046727,  6.96816976,  1.46712435,  4.76725553,
#         7.82626847, -0.15669058,  0.25920191,  3.99356933,  2.29493825,
#         3.75449085,  2.59458622,  1.00073824,  3.36870878,  0.17757634,
#         4.88301702,  4.21126886,  3.50931981,  1.06951771,  6.55566522,
#        -0.5776439 ,  3.32129192,  2.7932916 ,  7.39253057,  2.89710507,
#         0.58605604,  4.40425964,  3.3732975 ,  4.733698  ,  2.64971595,
#         2.62945598,  1.78343462,  1.81534391,  2.89322339,  6.43757463,
#         4.95123892,  3.90880612,  1.98356246,  3.72617518,  1.60243104,
#         2.60707873,  6.52386998,  4.61957456,  2.65096783,  2.8937357 ,
#        -0.12049566,  4.44117332,  3.93301995,  3.8377889 ,  5.69635369,
#         3.67958008,  6.19900995, -0.9236259 ,  2.34656364,  2.11801216,
#         1.96184935,  2.58499924,  4.58907514, -0.23360482,  4.58060391,
#        -2.5213598 ,  2.49566394,  5.1053282 ,  4.76955832,  4.49490886,
#         3.55574886,  4.71607758, -0.66106003,  3.57898623,  5.7321844 ,
#         2.29513706,  2.55533703,  2.14125794,  4.07281414,  2.26993852,
#         1.08635936,  4.31671171,  2.72423355,  5.13478576,  1.80226451,
#         2.73845303,  5.49611972,  4.14269236,  2.3466717 ,  1.04027639])

# %%
np.random.choice([True,False],p = [0.5,0.5],size = None)
# Out:
# False

# %%
def simulate(theta, theta00=None, theta01=None, theta1=None, theta_score=None, npoints=None):
    # Draw latent variables z
    z1 = np.random.normal(loc=0, scale=z_std, size=npoints)
    z2 = np.random.normal(loc=alpha, scale=z_std, size=npoints)
    mask = np.random.choice([True, False],p=[1./(1+theta**2),theta**2/(1+theta**2)],size=npoints)
    try:
        z = np.concatenate((z1[mask],z2[~mask]))
    except:
        if mask:
            z = z1
        else:
            z = z2
    # Draw observables x
    x = np.random.normal(loc=z, scale=x_std, size=None)

    # Calculate joint likelihood ratio and joint score
    if theta00 is not None and theta01 is not None and theta1 is not None:
        r_xz1 = (norm(loc=theta1, scale=z_std).pdf(z)+(theta00**2)*norm(loc=alpha, scale=z_std).pdf(z) )/ ((1+theta00**2)*norm(loc=theta1, scale=z_std).pdf(z))
        r_xz2 = (norm(loc=theta1, scale=z_std).pdf(z)+(theta01**2)*norm(loc=alpha, scale=z_std).pdf(z) )/ ((1+theta01**2)*norm(loc=theta1, scale=z_std).pdf(z))
    else:
        r_xz1 = None
        r_xz2 = None

    if theta_score is not None:
        t_xz = (x - theta_score) / z_std**2
    else:
        t_xz = None

    return x, r_xz1, r_xz2, t_xz

# %% [markdown]
# Usually the likelihood function `p(x|theta)` is intractable, but in this toy example it is just given by the convolution of two Gaussians, which is again a Gaussian. We will use this to validate the results later:

# %%
def calculate_likelihood_ratio(x, theta0, theta1=0.0):
    combined_std = (z_std**2 + x_std**2) ** 0.5
    r_x = (norm(loc=theta1, scale=combined_std).pdf(x)+(theta0**2)*norm(loc=alpha, scale=combined_std).pdf(x) )/ ((1+theta0**2)*norm(loc=theta1, scale=combined_std).pdf(x))
    return r_x

# %% [markdown]
# Let's now visualize that: we run the simulation and plot the probability distributions $p(x | \theta_i)$. Additionally, we also plot the true log-likelihood ratio $\log\,r(x|\theta_0,\theta_1)$.

# %%
x0, _, _, _ = simulate(100, npoints=10000)
x1, _, _, _ = simulate(0, npoints=10000)

xr = np.linspace(-20.0, 300.0, 100)
rx = np.log(calculate_likelihood_ratio(xr, 100, 0))

fig, ax1 = plt.subplots()
fig.set_size_inches(5, 5)
ax1.set_xlabel("$x$")
ax1.hist(x0, bins=50, range=(-20, 20.0), histtype="step", label=r"$p(x | \theta_0)$", density=True)
ax1.hist(x1, bins=50, range=(-20, 20.0), histtype="step", label=r"$p(x | \theta_1)$", density=True)
ax1.set_ylabel(r"$p(x|\theta)$")
ax1.legend(loc=2)

ax2 = ax1.twinx()
ax2.plot(xr, rx, color="black", label=r"$\log\,r(x|\theta_0,\theta_1)$")
ax2.set_ylabel(r"$\log\,r(x|\theta_0,\theta_1)$")
ax2.legend(loc=1)

plt.show()
# Out:
# /tmp/ipykernel_2894626/413034781.py:3: RuntimeWarning: divide by zero encountered in divide
#   r_x = (norm(loc=theta1, scale=combined_std).pdf(x)+(theta0**2)*norm(loc=alpha, scale=combined_std).pdf(x) )/ ((1+theta0**2)*norm(loc=theta1, scale=combined_std).pdf(x))
# /tmp/ipykernel_2894626/413034781.py:3: RuntimeWarning: invalid value encountered in divide
#   r_x = (norm(loc=theta1, scale=combined_std).pdf(x)+(theta0**2)*norm(loc=alpha, scale=combined_std).pdf(x) )/ ((1+theta0**2)*norm(loc=theta1, scale=combined_std).pdf(x))

# %%
x0.shape
# Out:
# (10000,)

# %% [markdown]
# ## 2. Run the simulation and generate training data

# %% [markdown]
# First, we define the parameter points we want to use for training: `theta0` is uniformly distributed while the reference model `theta1` is fixed at zero.

# %%
# number of parameter points to train
n_param_points = 5000

# numerator, uniform prior
theta00 = np.ones(shape=n_param_points)*(-4)
theta01 = np.ones(shape=n_param_points)*0.
theta02 = np.ones(shape=n_param_points)*4

# %% [markdown]
# We then run the simulator (one sample per parameter point). Remember that `simulate(theta, theta0, theta1, theta_score)` generates data `x` following a theory with `theta` and then evaluates the joint likelihood ratio `r(x,z|theta0,theta1)` and the join score `t(x,z|theta_score)` for each data point.

# %%
# Sample from theta0
x_from_theta00 = []
r_xz_from_theta00 = []
t_xz_from_theta00 = []
x_from_theta01 = []
r_xz_from_theta001 = []
r_xz_from_theta002 = []
t_xz_from_theta01 = []
x_from_theta02 = []
r_xz_from_theta02 = []
t_xz_from_theta02 = []
for t in theta00:
    out = simulate(t, t, t, 0., t)
    x_from_theta00.append(out[0])
    r_xz_from_theta00.append(out[1])
print("Done first sim")
for t in theta01:
    out = simulate(t, -4, 4, 0., t)
    x_from_theta01.append(out[0])
    r_xz_from_theta001.append(out[1])
    r_xz_from_theta002.append(out[2])
    #t_xz_from_theta01.append(out[2])
print("Done first sim")
for t in theta02:
    out = simulate(t, t,t, 0., t)
    x_from_theta02.append(out[0])
    r_xz_from_theta02.append(out[2])
    #t_xz_from_theta02.append(out[2])
print("Done first sim")
# Out:
# Done first sim
#  101.09213119867493,
#  1.0960444548617294,
#  12.4351619387014,
#  53.14408412300404,
#  0.7647835301890429,
#  3.254820328189563,
#  0.5301062595074814,
#  7.551413984681672,
#  1.4877575288919762,
#  0.6013034955492201,
#  3.6745616744628435,
#  6.709195177505167,
#  5.833866177747214,
#  3.2415862998941045,
#  0.08354642716628008,
#  45.86410726353818,
#  1.017797368698176,
#  0.3081536332436116,
#  28.578563551973076,
#  4.609196832073629,
#  2.0427519156866696,
#  3.266951160779788,
#  69.4812701762661,
#  0.43969034555002334,
#  2.464886861522305,
#  0.13137946469158499,
#  23.737265236025923,
#  7.9986303981185545,
#  6.023007959866943,
#  0.20775663161990404,
#  1.864125515162097,
#  0.6305102404993086,
#  0.8475771001070326,
#  3.914247493624456,
#  0.9188896354585299,
#  65.03827841628512,
#  4.284153758530893,
#  1.1698335885205045,
#  7.985105068287508,
#  0.9032122158641217,
#  2.928350590989178,
#  20.65094372425758,
#  10.370755857867024,
#  17.605352572264668,
#  2.96367523088256,
#  1.1034022852876049,
#  12.855738825286375,
#  2.130371825205952,
#  2.6592427786623976,
#  1.9599430596121417,
#  0.32358911921942013,
#  1.6472816448660308,
#  4.572952101380774,
#  2.3906612517340826,
#  0.7039242043476328,
#  32.86330918092785,
#  7.743828597885713,
#  0.7567389971790172,
#  5.948211162079049,
#  2.0373860564046304,
#  5.057134397317164,
#  3.4838345890834623,
#  0.8230392498190616,
#  1.2094559378617429,
#  0.5109607553806191,
#  0.5076201681582331,
#  0.9868618449988242,
#  34.06766593069543,
#  0.7878702710460891,
#  1.3537075959238145,
#  0.9760956453712587,
#  ...]

# %% [markdown]
# Now we combine and reshape the results (nothing interesting happening here) and save everything to files, so that we can load it later.

# %%
plt.hist(x_from_theta02)
# Out:
# (array([  10.,   42.,  198.,  544., 1105., 1339., 1081.,  526.,  131.,
#           24.]),
#  array([-6.06862017, -4.4318731 , -2.79512603, -1.15837896,  0.47836811,
#          2.11511518,  3.75186225,  5.38860931,  7.02535638,  8.66210345,
#         10.29885052]),
#  <BarContainer object of 10 artists>)

# %%
# Combine results and reshape
x_train0 = np.hstack((x_from_theta00, x_from_theta01)).reshape(-1, 1)
x_train1 = np.hstack((x_from_theta02, x_from_theta01)).reshape(-1, 1)
r_xz_train0 = np.hstack((r_xz_from_theta00, r_xz_from_theta001)).reshape(-1, 1)
r_xz_train1 = np.hstack((r_xz_from_theta02, r_xz_from_theta002)).reshape(-1, 1)
#t_xz_train0 = np.hstack((t_xz_from_theta0, t_xz_from_theta1)).reshape(-1, 1)
y_train0 = np.hstack((np.zeros_like(x_from_theta00), np.ones_like(np.ones_like(x_from_theta01)))).reshape(-1, 1)
y_train1 = np.hstack((np.zeros_like(x_from_theta02), np.ones_like(np.ones_like(x_from_theta01)))).reshape(-1, 1)
#theta0_train = np.hstack((theta0, theta0)).reshape(-1, 1)

# Save to file
#np.save("data/theta0_train.npy", theta0_train)
np.save("data_balanced_morph/x_train0.npy", x_train0)
np.save("data_balanced_morph/x_train1.npy", x_train1)
np.save("data_balanced_morph/y_train0.npy", y_train0)
np.save("data_balanced_morph/y_train1.npy", y_train1)
np.save("data_balanced_morph/r_xz_train0.npy", r_xz_train0)
np.save("data_balanced_morph/r_xz_train1.npy", r_xz_train1)
#np.save("data/t_xz_train.npy", t_xz_train)

# %% [markdown]
# ## 3. Model training

# %% [markdown]
# Let's train two neural networks to estimate the likelihood ratio. For one we use the CARL method introduced in ["Approximating Likelihood Ratios with Calibrated Discriminative Classifiers"](https://arxiv.org/abs/1506.02169), for the other the new ALICES method introduced in ["Likelihood-free inference with an improved cross-entropy estimator"](https://arxiv.org/abs/1808.00973).

# %%
nn = MorphParameterizedRatioEstimator(n_hidden=(20, 20))

loss = nn.train(
    method="carl",
    x="data_balanced_morph/x_train0.npy",
    y="data_balanced_morph/y_train0.npy",
    n_epochs=20,
)

nn.save("models_balanced_morph/carl0")
# Out:
# 10:21 madminer.ml.paramete INFO    Starting training
# 10:21 madminer.ml.paramete INFO      Method:                 carl
# 10:21 madminer.ml.paramete INFO      Batch size:             128
# 10:21 madminer.ml.paramete INFO      Optimizer:              amsgrad
# 10:21 madminer.ml.paramete INFO      Epochs:                 20
# 10:21 madminer.ml.paramete INFO      Learning rate:          0.001 initially, decaying to 0.0001
# 10:21 madminer.ml.paramete INFO      Validation split:       0.25
# 10:21 madminer.ml.paramete INFO      Early stopping:         True
# 10:21 madminer.ml.paramete INFO      Scale inputs:           True
# 10:21 madminer.ml.paramete INFO      Scale parameters:       True
# 10:21 madminer.ml.paramete INFO      Shuffle labels          False
# 10:21 madminer.ml.paramete INFO      Samples:                all
# 10:21 madminer.ml.paramete INFO    Loading training data
# 10:21 madminer.utils.vario INFO      Loading data_balanced_morph/x_train0.npy into RAM
# 10:21 madminer.utils.vario INFO      Loading data_balanced_morph/y_train0.npy into RAM
# 10:21 madminer.ml.paramete INFO    Found 10000 samples with 1 observables
# 10:21 madminer.ml.base     INFO    Setting up input rescaling
# 10:21 madminer.ml.paramete INFO    Creating model
# 10:21 madminer.ml.paramete INFO    Training model
# 10:21 madminer.utils.ml.tr INFO    Training on CPU with single precision
# 10:21 madminer.utils.ml.tr INFO      Epoch   1: train loss  0.62352 (xe:  0.624)
# 10:21 madminer.utils.ml.tr INFO                 val. loss   0.55283 (xe:  0.553)
# 10:21 madminer.utils.ml.tr INFO      Epoch   2: train loss  0.53305 (xe:  0.533)
# 10:21 madminer.utils.ml.tr INFO                 val. loss   0.53113 (xe:  0.531)
# 10:21 madminer.utils.ml.tr INFO      Epoch   3: train loss  0.52634 (xe:  0.526)
# 10:21 madminer.utils.ml.tr INFO                 val. loss   0.53342 (xe:  0.533)
# 10:21 madminer.utils.ml.tr INFO      Epoch   4: train loss  0.52547 (xe:  0.525)
# 10:21 madminer.utils.ml.tr INFO                 val. loss   0.52973 (xe:  0.530)
# 10:21 madminer.utils.ml.tr INFO      Epoch   5: train loss  0.52492 (xe:  0.525)
# 10:21 madminer.utils.ml.tr INFO                 val. loss   0.53191 (xe:  0.532)
# 10:21 madminer.utils.ml.tr INFO      Epoch   6: train loss  0.52591 (xe:  0.526)
# 10:21 madminer.utils.ml.tr INFO                 val. loss   0.53184 (xe:  0.532)
# 10:21 madminer.utils.ml.tr INFO      Epoch   7: train loss  0.52536 (xe:  0.525)
# 10:21 madminer.utils.ml.tr INFO                 val. loss   0.53220 (xe:  0.532)
# 10:21 madminer.utils.ml.tr INFO      Epoch   8: train loss  0.52555 (xe:  0.526)
# 10:21 madminer.utils.ml.tr INFO                 val. loss   0.53233 (xe:  0.532)
# 10:21 madminer.utils.ml.tr INFO      Epoch   9: train loss  0.52528 (xe:  0.525)
# 10:21 madminer.utils.ml.tr INFO                 val. loss   0.53209 (xe:  0.532)
# 10:21 madminer.utils.ml.tr INFO      Epoch  10: train loss  0.52498 (xe:  0.525)
# 10:21 madminer.utils.ml.tr INFO                 val. loss   0.53133 (xe:  0.531)
# 10:21 madminer.utils.ml.tr INFO      Epoch  11: train loss  0.52550 (xe:  0.525)
# 10:21 madminer.utils.ml.tr INFO                 val. loss   0.53159 (xe:  0.532)
# 10:21 madminer.utils.ml.tr INFO      Epoch  12: train loss  0.52531 (xe:  0.525)
# 10:21 madminer.utils.ml.tr INFO                 val. loss   0.53187 (xe:  0.532)
# 10:21 madminer.utils.ml.tr INFO      Epoch  13: train loss  0.52470 (xe:  0.525)
# 10:21 madminer.utils.ml.tr INFO                 val. loss   0.53144 (xe:  0.531)
# 10:21 madminer.utils.ml.tr INFO      Epoch  14: train loss  0.52467 (xe:  0.525)
# 10:21 madminer.utils.ml.tr INFO                 val. loss   0.53114 (xe:  0.531)
# 10:21 madminer.utils.ml.tr INFO      Epoch  15: train loss  0.52456 (xe:  0.525)
# 10:21 madminer.utils.ml.tr INFO                 val. loss   0.53144 (xe:  0.531)
# 10:21 madminer.utils.ml.tr INFO      Epoch  16: train loss  0.52461 (xe:  0.525)
# 10:21 madminer.utils.ml.tr INFO                 val. loss   0.53016 (xe:  0.530)
# 10:21 madminer.utils.ml.tr INFO      Epoch  17: train loss  0.52476 (xe:  0.525)
# 10:21 madminer.utils.ml.tr INFO                 val. loss   0.53127 (xe:  0.531)
# 10:21 madminer.utils.ml.tr INFO      Epoch  18: train loss  0.52506 (xe:  0.525)
# 10:21 madminer.utils.ml.tr INFO                 val. loss   0.53118 (xe:  0.531)
# 10:21 madminer.utils.ml.tr INFO      Epoch  19: train loss  0.52522 (xe:  0.525)
# 10:21 madminer.utils.ml.tr INFO                 val. loss   0.53001 (xe:  0.530)
# 10:21 madminer.utils.ml.tr INFO      Epoch  20: train loss  0.52418 (xe:  0.524)
# 10:21 madminer.utils.ml.tr INFO                 val. loss   0.53296 (xe:  0.533)
# 10:21 madminer.utils.ml.tr INFO    Early stopping after epoch 4, with loss  0.52973 compared to final loss  0.53296
# 10:21 madminer.utils.ml.tr INFO    Training time spend on:
# 10:21 madminer.utils.ml.tr INFO                      initialize model:   0.00h
# 10:21 madminer.utils.ml.tr INFO                                   ALL:   0.00h
# 10:21 madminer.utils.ml.tr INFO                            check data:   0.00h
# 10:21 madminer.utils.ml.tr INFO                          make dataset:   0.00h
# 10:21 madminer.utils.ml.tr INFO                       make dataloader:   0.00h
# 10:21 madminer.utils.ml.tr INFO                       setup optimizer:   0.00h
# 10:21 madminer.utils.ml.tr INFO                   initialize training:   0.00h
# 10:21 madminer.utils.ml.tr INFO                                set lr:   0.00h
# 10:21 madminer.utils.ml.tr INFO                   load training batch:   0.00h
# 10:21 madminer.utils.ml.tr INFO                        fwd: move data:   0.00h
# 10:21 madminer.utils.ml.tr INFO                   fwd: check for nans:   0.00h
# 10:21 madminer.utils.ml.tr INFO                    fwd: model.forward:   0.00h
# 10:21 madminer.utils.ml.tr INFO                 fwd: calculate losses:   0.00h
# 10:21 madminer.utils.ml.tr INFO                 training forward pass:   0.00h
# 10:21 madminer.utils.ml.tr INFO                   training sum losses:   0.00h
# 10:21 madminer.utils.ml.tr INFO                        opt: zero grad:   0.00h
# 10:21 madminer.utils.ml.tr INFO                         opt: backward:   0.00h
# 10:21 madminer.utils.ml.tr INFO                   opt: clip grad norm:   0.00h
# 10:21 madminer.utils.ml.tr INFO                             opt: step:   0.00h
# 10:21 madminer.utils.ml.tr INFO                        optimizer step:   0.00h
# 10:21 madminer.utils.ml.tr INFO                 load validation batch:   0.00h
# 10:21 madminer.utils.ml.tr INFO               validation forward pass:   0.00h
# 10:21 madminer.utils.ml.tr INFO                 validation sum losses:   0.00h
# 10:21 madminer.utils.ml.tr INFO                        early stopping:   0.00h
# 10:21 madminer.utils.ml.tr INFO                          report epoch:   0.00h
# 10:21 madminer.ml.base     INFO    Saving model to models_balanced_morph/carl0

# %%
nn = MorphParameterizedRatioEstimator(n_hidden=(20, 20))

loss = nn.train(
    method="alice",
    x="data_balanced_morph/x_train0.npy",
    y="data_balanced_morph/y_train0.npy",
    r_xz="data_balanced_morph/r_xz_train0.npy",
    n_epochs=80,
)

nn.save("models_balanced_morph/alice0")
# Out:
# 10:21 madminer.ml.paramete INFO    Starting training
# 10:21 madminer.ml.paramete INFO      Method:                 alice
# 10:21 madminer.ml.paramete INFO      Batch size:             128
# 10:21 madminer.ml.paramete INFO      Optimizer:              amsgrad
# 10:21 madminer.ml.paramete INFO      Epochs:                 80
# 10:21 madminer.ml.paramete INFO      Learning rate:          0.001 initially, decaying to 0.0001
# 10:21 madminer.ml.paramete INFO      Validation split:       0.25
# 10:21 madminer.ml.paramete INFO      Early stopping:         True
# 10:21 madminer.ml.paramete INFO      Scale inputs:           True
# 10:21 madminer.ml.paramete INFO      Scale parameters:       True
# 10:21 madminer.ml.paramete INFO      Shuffle labels          False
# 10:21 madminer.ml.paramete INFO      Samples:                all
# 10:21 madminer.ml.paramete INFO    Loading training data
# 10:21 madminer.utils.vario INFO      Loading data_balanced_morph/x_train0.npy into RAM
# 10:21 madminer.utils.vario INFO      Loading data_balanced_morph/y_train0.npy into RAM
# 10:21 madminer.utils.vario INFO      Loading data_balanced_morph/r_xz_train0.npy into RAM
# 10:21 madminer.ml.paramete INFO    Found 10000 samples with 1 observables
# 10:21 madminer.ml.base     INFO    Setting up input rescaling
# 10:21 madminer.ml.paramete INFO    Creating model
# 10:21 madminer.ml.paramete INFO    Training model
# 10:21 madminer.utils.ml.tr INFO    Training on CPU with single precision
# 10:21 madminer.utils.ml.tr INFO      Epoch   4: train loss  0.53186 (improved_xe:  0.532)
# 10:21 madminer.utils.ml.tr INFO                 val. loss   0.52918 (improved_xe:  0.529)
# 10:21 madminer.utils.ml.tr INFO      Epoch   8: train loss  0.53118 (improved_xe:  0.531)
# 10:21 madminer.utils.ml.tr INFO                 val. loss   0.52933 (improved_xe:  0.529)
# 10:21 madminer.utils.ml.tr INFO      Epoch  12: train loss  0.53125 (improved_xe:  0.531)
# 10:21 madminer.utils.ml.tr INFO                 val. loss   0.52912 (improved_xe:  0.529)
# 10:21 madminer.utils.ml.tr INFO      Epoch  16: train loss  0.53083 (improved_xe:  0.531)
# 10:21 madminer.utils.ml.tr INFO                 val. loss   0.52946 (improved_xe:  0.529)
# 10:21 madminer.utils.ml.tr INFO      Epoch  20: train loss  0.53039 (improved_xe:  0.530)
# 10:21 madminer.utils.ml.tr INFO                 val. loss   0.52816 (improved_xe:  0.528)
# 10:21 madminer.utils.ml.tr INFO      Epoch  24: train loss  0.53059 (improved_xe:  0.531)
# 10:21 madminer.utils.ml.tr INFO                 val. loss   0.52858 (improved_xe:  0.529)
# 10:21 madminer.utils.ml.tr INFO      Epoch  28: train loss  0.53067 (improved_xe:  0.531)
# 10:21 madminer.utils.ml.tr INFO                 val. loss   0.52757 (improved_xe:  0.528)
# 10:21 madminer.utils.ml.tr INFO      Epoch  32: train loss  0.53071 (improved_xe:  0.531)
# 10:21 madminer.utils.ml.tr INFO                 val. loss   0.52786 (improved_xe:  0.528)
# 10:21 madminer.utils.ml.tr INFO      Epoch  36: train loss  0.53086 (improved_xe:  0.531)
# 10:21 madminer.utils.ml.tr INFO                 val. loss   0.52798 (improved_xe:  0.528)
# 10:21 madminer.utils.ml.tr INFO      Epoch  40: train loss  0.53053 (improved_xe:  0.531)
# 10:21 madminer.utils.ml.tr INFO                 val. loss   0.52776 (improved_xe:  0.528)
# 10:21 madminer.utils.ml.tr INFO      Epoch  44: train loss  0.53045 (improved_xe:  0.530)
# 10:21 madminer.utils.ml.tr INFO                 val. loss   0.52904 (improved_xe:  0.529)
# 10:21 madminer.utils.ml.tr INFO      Epoch  48: train loss  0.53051 (improved_xe:  0.531)
# 10:21 madminer.utils.ml.tr INFO                 val. loss   0.52860 (improved_xe:  0.529)
# 10:21 madminer.utils.ml.tr INFO      Epoch  52: train loss  0.53044 (improved_xe:  0.530)
# 10:21 madminer.utils.ml.tr INFO                 val. loss   0.52828 (improved_xe:  0.528)
# 10:21 madminer.utils.ml.tr INFO      Epoch  56: train loss  0.53056 (improved_xe:  0.531)
# 10:21 madminer.utils.ml.tr INFO                 val. loss   0.52751 (improved_xe:  0.528)
# 10:21 madminer.utils.ml.tr INFO      Epoch  60: train loss  0.53056 (improved_xe:  0.531)
# 10:21 madminer.utils.ml.tr INFO                 val. loss   0.52874 (improved_xe:  0.529)
# 10:21 madminer.utils.ml.tr INFO      Epoch  64: train loss  0.53061 (improved_xe:  0.531)
# 10:21 madminer.utils.ml.tr INFO                 val. loss   0.52844 (improved_xe:  0.528)
# 10:21 madminer.utils.ml.tr INFO      Epoch  68: train loss  0.53069 (improved_xe:  0.531)
# 10:21 madminer.utils.ml.tr INFO                 val. loss   0.52734 (improved_xe:  0.527)
# 10:21 madminer.utils.ml.tr INFO      Epoch  72: train loss  0.53052 (improved_xe:  0.531)
# 10:21 madminer.utils.ml.tr INFO                 val. loss   0.52789 (improved_xe:  0.528)
# 10:21 madminer.utils.ml.tr INFO      Epoch  76: train loss  0.53062 (improved_xe:  0.531)
# 10:21 madminer.utils.ml.tr INFO                 val. loss   0.52806 (improved_xe:  0.528)
# 10:21 madminer.utils.ml.tr INFO      Epoch  80: train loss  0.53091 (improved_xe:  0.531)
# 10:21 madminer.utils.ml.tr INFO                 val. loss   0.52756 (improved_xe:  0.528)
# 10:21 madminer.utils.ml.tr INFO    Early stopping after epoch 58, with loss  0.52666 compared to final loss  0.52756
# 10:21 madminer.utils.ml.tr INFO    Training time spend on:
# 10:21 madminer.utils.ml.tr INFO                      initialize model:   0.00h
# 10:21 madminer.utils.ml.tr INFO                                   ALL:   0.01h
# 10:21 madminer.utils.ml.tr INFO                            check data:   0.00h
# 10:21 madminer.utils.ml.tr INFO                          make dataset:   0.00h
# 10:21 madminer.utils.ml.tr INFO                       make dataloader:   0.00h
# 10:21 madminer.utils.ml.tr INFO                       setup optimizer:   0.00h
# 10:21 madminer.utils.ml.tr INFO                   initialize training:   0.00h
# 10:21 madminer.utils.ml.tr INFO                                set lr:   0.00h
# 10:21 madminer.utils.ml.tr INFO                   load training batch:   0.00h
# 10:21 madminer.utils.ml.tr INFO                        fwd: move data:   0.00h
# 10:21 madminer.utils.ml.tr INFO                   fwd: check for nans:   0.00h
# 10:21 madminer.utils.ml.tr INFO                    fwd: model.forward:   0.00h
# 10:21 madminer.utils.ml.tr INFO                 fwd: calculate losses:   0.00h
# 10:21 madminer.utils.ml.tr INFO                 training forward pass:   0.00h
# 10:21 madminer.utils.ml.tr INFO                   training sum losses:   0.00h
# 10:21 madminer.utils.ml.tr INFO                        opt: zero grad:   0.00h
# 10:21 madminer.utils.ml.tr INFO                         opt: backward:   0.00h
# 10:21 madminer.utils.ml.tr INFO                   opt: clip grad norm:   0.00h
# 10:21 madminer.utils.ml.tr INFO                             opt: step:   0.00h
# 10:21 madminer.utils.ml.tr INFO                        optimizer step:   0.00h
# 10:21 madminer.utils.ml.tr INFO                 load validation batch:   0.00h
# 10:21 madminer.utils.ml.tr INFO               validation forward pass:   0.00h
# 10:21 madminer.utils.ml.tr INFO                 validation sum losses:   0.00h
# 10:21 madminer.utils.ml.tr INFO                        early stopping:   0.00h
# 10:21 madminer.utils.ml.tr INFO                          report epoch:   0.00h
# 10:21 madminer.ml.base     INFO    Saving model to models_balanced_morph/alice0

# %%
plt.plot(loss[0])
plt.plot(loss[1])

# %%
nn = MorphParameterizedRatioEstimator(n_hidden=(20, 20))

loss = nn.train(
    method="carl",
    x="data_balanced_morph/x_train1.npy",
    y="data_balanced_morph/y_train1.npy",
    n_epochs=20,
)

nn.save("models_balanced_morph/carl1")
# Out:
# 10:21 madminer.ml.paramete INFO    Starting training
# 10:21 madminer.ml.paramete INFO      Method:                 carl
# 10:21 madminer.ml.paramete INFO      Batch size:             128
# 10:21 madminer.ml.paramete INFO      Optimizer:              amsgrad
# 10:21 madminer.ml.paramete INFO      Epochs:                 20
# 10:21 madminer.ml.paramete INFO      Learning rate:          0.001 initially, decaying to 0.0001
# 10:21 madminer.ml.paramete INFO      Validation split:       0.25
# 10:21 madminer.ml.paramete INFO      Early stopping:         True
# 10:21 madminer.ml.paramete INFO      Scale inputs:           True
# 10:21 madminer.ml.paramete INFO      Scale parameters:       True
# 10:21 madminer.ml.paramete INFO      Shuffle labels          False
# 10:21 madminer.ml.paramete INFO      Samples:                all
# 10:21 madminer.ml.paramete INFO    Loading training data
# 10:21 madminer.utils.vario INFO      Loading data_balanced_morph/x_train1.npy into RAM
# 10:21 madminer.utils.vario INFO      Loading data_balanced_morph/y_train1.npy into RAM
# 10:21 madminer.ml.paramete INFO    Found 10000 samples with 1 observables
# 10:21 madminer.ml.base     INFO    Setting up input rescaling
# 10:21 madminer.ml.paramete INFO    Creating model
# 10:21 madminer.ml.paramete INFO    Training model
# 10:21 madminer.utils.ml.tr INFO    Training on CPU with single precision
# 10:21 madminer.utils.ml.tr INFO      Epoch   1: train loss  0.60532 (xe:  0.605)
# 10:21 madminer.utils.ml.tr INFO                 val. loss   0.54917 (xe:  0.549)
# 10:21 madminer.utils.ml.tr INFO      Epoch   2: train loss  0.53430 (xe:  0.534)
# 10:21 madminer.utils.ml.tr INFO                 val. loss   0.53166 (xe:  0.532)
# 10:21 madminer.utils.ml.tr INFO      Epoch   3: train loss  0.52865 (xe:  0.529)
# 10:21 madminer.utils.ml.tr INFO                 val. loss   0.52978 (xe:  0.530)
# 10:21 madminer.utils.ml.tr INFO      Epoch   4: train loss  0.52912 (xe:  0.529)
# 10:21 madminer.utils.ml.tr INFO                 val. loss   0.52993 (xe:  0.530)
# 10:21 madminer.utils.ml.tr INFO      Epoch   5: train loss  0.52922 (xe:  0.529)
# 10:21 madminer.utils.ml.tr INFO                 val. loss   0.53035 (xe:  0.530)
# 10:21 madminer.utils.ml.tr INFO      Epoch   6: train loss  0.52901 (xe:  0.529)
# 10:21 madminer.utils.ml.tr INFO                 val. loss   0.53151 (xe:  0.532)
# 10:21 madminer.utils.ml.tr INFO      Epoch   7: train loss  0.52895 (xe:  0.529)
# 10:21 madminer.utils.ml.tr INFO                 val. loss   0.52947 (xe:  0.529)
# 10:21 madminer.utils.ml.tr INFO      Epoch   8: train loss  0.52821 (xe:  0.528)
# 10:21 madminer.utils.ml.tr INFO                 val. loss   0.53259 (xe:  0.533)
# 10:21 madminer.utils.ml.tr INFO      Epoch   9: train loss  0.52810 (xe:  0.528)
# 10:21 madminer.utils.ml.tr INFO                 val. loss   0.53301 (xe:  0.533)
# 10:21 madminer.utils.ml.tr INFO      Epoch  10: train loss  0.52867 (xe:  0.529)
# 10:21 madminer.utils.ml.tr INFO                 val. loss   0.52879 (xe:  0.529)
# 10:21 madminer.utils.ml.tr INFO      Epoch  11: train loss  0.52859 (xe:  0.529)
# 10:21 madminer.utils.ml.tr INFO                 val. loss   0.53062 (xe:  0.531)
# 10:21 madminer.utils.ml.tr INFO      Epoch  12: train loss  0.52875 (xe:  0.529)
# 10:21 madminer.utils.ml.tr INFO                 val. loss   0.52808 (xe:  0.528)
# 10:21 madminer.utils.ml.tr INFO      Epoch  13: train loss  0.52817 (xe:  0.528)
# 10:21 madminer.utils.ml.tr INFO                 val. loss   0.52956 (xe:  0.530)
# 10:21 madminer.utils.ml.tr INFO      Epoch  14: train loss  0.52889 (xe:  0.529)
# 10:21 madminer.utils.ml.tr INFO                 val. loss   0.53074 (xe:  0.531)
# 10:21 madminer.utils.ml.tr INFO      Epoch  15: train loss  0.52830 (xe:  0.528)
# 10:21 madminer.utils.ml.tr INFO                 val. loss   0.53086 (xe:  0.531)
# 10:21 madminer.utils.ml.tr INFO      Epoch  16: train loss  0.52839 (xe:  0.528)
# 10:21 madminer.utils.ml.tr INFO                 val. loss   0.52974 (xe:  0.530)
# 10:21 madminer.utils.ml.tr INFO      Epoch  17: train loss  0.52877 (xe:  0.529)
# 10:21 madminer.utils.ml.tr INFO                 val. loss   0.52985 (xe:  0.530)
# 10:21 madminer.utils.ml.tr INFO      Epoch  18: train loss  0.52852 (xe:  0.529)
# 10:21 madminer.utils.ml.tr INFO                 val. loss   0.52757 (xe:  0.528)
# 10:21 madminer.utils.ml.tr INFO      Epoch  19: train loss  0.52832 (xe:  0.528)
# 10:21 madminer.utils.ml.tr INFO                 val. loss   0.52900 (xe:  0.529)
# 10:21 madminer.utils.ml.tr INFO      Epoch  20: train loss  0.52824 (xe:  0.528)
# 10:21 madminer.utils.ml.tr INFO                 val. loss   0.52991 (xe:  0.530)
# 10:21 madminer.utils.ml.tr INFO    Early stopping after epoch 18, with loss  0.52757 compared to final loss  0.52991
# 10:21 madminer.utils.ml.tr INFO    Training time spend on:
# 10:21 madminer.utils.ml.tr INFO                      initialize model:   0.00h
# 10:21 madminer.utils.ml.tr INFO                                   ALL:   0.00h
# 10:21 madminer.utils.ml.tr INFO                            check data:   0.00h
# 10:21 madminer.utils.ml.tr INFO                          make dataset:   0.00h
# 10:21 madminer.utils.ml.tr INFO                       make dataloader:   0.00h
# 10:21 madminer.utils.ml.tr INFO                       setup optimizer:   0.00h
# 10:21 madminer.utils.ml.tr INFO                   initialize training:   0.00h
# 10:21 madminer.utils.ml.tr INFO                                set lr:   0.00h
# 10:21 madminer.utils.ml.tr INFO                   load training batch:   0.00h
# 10:21 madminer.utils.ml.tr INFO                        fwd: move data:   0.00h
# 10:21 madminer.utils.ml.tr INFO                   fwd: check for nans:   0.00h
# 10:21 madminer.utils.ml.tr INFO                    fwd: model.forward:   0.00h
# 10:21 madminer.utils.ml.tr INFO                 fwd: calculate losses:   0.00h
# 10:21 madminer.utils.ml.tr INFO                 training forward pass:   0.00h
# 10:21 madminer.utils.ml.tr INFO                   training sum losses:   0.00h
# 10:21 madminer.utils.ml.tr INFO                        opt: zero grad:   0.00h
# 10:21 madminer.utils.ml.tr INFO                         opt: backward:   0.00h
# 10:21 madminer.utils.ml.tr INFO                   opt: clip grad norm:   0.00h
# 10:21 madminer.utils.ml.tr INFO                             opt: step:   0.00h
# 10:21 madminer.utils.ml.tr INFO                        optimizer step:   0.00h
# 10:21 madminer.utils.ml.tr INFO                 load validation batch:   0.00h
# 10:21 madminer.utils.ml.tr INFO               validation forward pass:   0.00h
# 10:21 madminer.utils.ml.tr INFO                 validation sum losses:   0.00h
# 10:21 madminer.utils.ml.tr INFO                        early stopping:   0.00h
# 10:21 madminer.utils.ml.tr INFO                          report epoch:   0.00h
# 10:21 madminer.ml.base     INFO    Saving model to models_balanced_morph/carl1

# %%
nn = MorphParameterizedRatioEstimator(n_hidden=(20, 20))

loss = nn.train(
    method="alice",
    x="data_balanced_morph/x_train1.npy",
    y="data_balanced_morph/y_train1.npy",
    r_xz="data_balanced_morph/r_xz_train1.npy",
    n_epochs=80,
)

nn.save("models_balanced_morph/alice1")
# Out:
# 10:21 madminer.ml.paramete INFO    Starting training
# 10:21 madminer.ml.paramete INFO      Method:                 alice
# 10:21 madminer.ml.paramete INFO      Batch size:             128
# 10:21 madminer.ml.paramete INFO      Optimizer:              amsgrad
# 10:21 madminer.ml.paramete INFO      Epochs:                 80
# 10:21 madminer.ml.paramete INFO      Learning rate:          0.001 initially, decaying to 0.0001
# 10:21 madminer.ml.paramete INFO      Validation split:       0.25
# 10:21 madminer.ml.paramete INFO      Early stopping:         True
# 10:21 madminer.ml.paramete INFO      Scale inputs:           True
# 10:21 madminer.ml.paramete INFO      Scale parameters:       True
# 10:21 madminer.ml.paramete INFO      Shuffle labels          False
# 10:21 madminer.ml.paramete INFO      Samples:                all
# 10:21 madminer.ml.paramete INFO    Loading training data
# 10:21 madminer.utils.vario INFO      Loading data_balanced_morph/x_train1.npy into RAM
# 10:21 madminer.utils.vario INFO      Loading data_balanced_morph/y_train1.npy into RAM
# 10:21 madminer.utils.vario INFO      Loading data_balanced_morph/r_xz_train1.npy into RAM
# 10:21 madminer.ml.paramete INFO    Found 10000 samples with 1 observables
# 10:21 madminer.ml.base     INFO    Setting up input rescaling
# 10:21 madminer.ml.paramete INFO    Creating model
# 10:21 madminer.ml.paramete INFO    Training model
# 10:21 madminer.utils.ml.tr INFO    Training on CPU with single precision
# 10:21 madminer.utils.ml.tr INFO      Epoch   4: train loss  0.53094 (improved_xe:  0.531)
# 10:21 madminer.utils.ml.tr INFO                 val. loss   0.53390 (improved_xe:  0.534)
# 10:21 madminer.utils.ml.tr INFO      Epoch   8: train loss  0.52987 (improved_xe:  0.530)
# 10:21 madminer.utils.ml.tr INFO                 val. loss   0.53321 (improved_xe:  0.533)
# 10:21 madminer.utils.ml.tr INFO      Epoch  12: train loss  0.52948 (improved_xe:  0.529)
# 10:21 madminer.utils.ml.tr INFO                 val. loss   0.53229 (improved_xe:  0.532)
# 10:21 madminer.utils.ml.tr INFO      Epoch  16: train loss  0.52948 (improved_xe:  0.529)
# 10:21 madminer.utils.ml.tr INFO                 val. loss   0.53220 (improved_xe:  0.532)
# 10:21 madminer.utils.ml.tr INFO      Epoch  20: train loss  0.52906 (improved_xe:  0.529)
# 10:21 madminer.utils.ml.tr INFO                 val. loss   0.53176 (improved_xe:  0.532)
# 10:21 madminer.utils.ml.tr INFO      Epoch  24: train loss  0.52914 (improved_xe:  0.529)
# 10:21 madminer.utils.ml.tr INFO                 val. loss   0.53159 (improved_xe:  0.532)
# 10:21 madminer.utils.ml.tr INFO      Epoch  28: train loss  0.52903 (improved_xe:  0.529)
# 10:21 madminer.utils.ml.tr INFO                 val. loss   0.53211 (improved_xe:  0.532)
# 10:21 madminer.utils.ml.tr INFO      Epoch  32: train loss  0.52932 (improved_xe:  0.529)
# 10:21 madminer.utils.ml.tr INFO                 val. loss   0.53231 (improved_xe:  0.532)
# 10:21 madminer.utils.ml.tr INFO      Epoch  36: train loss  0.52925 (improved_xe:  0.529)
# 10:21 madminer.utils.ml.tr INFO                 val. loss   0.53234 (improved_xe:  0.532)
# 10:21 madminer.utils.ml.tr INFO      Epoch  40: train loss  0.52892 (improved_xe:  0.529)
# 10:21 madminer.utils.ml.tr INFO                 val. loss   0.53212 (improved_xe:  0.532)
# 10:21 madminer.utils.ml.tr INFO      Epoch  44: train loss  0.52889 (improved_xe:  0.529)
# 10:21 madminer.utils.ml.tr INFO                 val. loss   0.53176 (improved_xe:  0.532)
# 10:22 madminer.utils.ml.tr INFO      Epoch  48: train loss  0.52908 (improved_xe:  0.529)
# 10:22 madminer.utils.ml.tr INFO                 val. loss   0.53186 (improved_xe:  0.532)
# 10:22 madminer.utils.ml.tr INFO      Epoch  52: train loss  0.52900 (improved_xe:  0.529)
# 10:22 madminer.utils.ml.tr INFO                 val. loss   0.53194 (improved_xe:  0.532)
# 10:22 madminer.utils.ml.tr INFO      Epoch  56: train loss  0.52900 (improved_xe:  0.529)
# 10:22 madminer.utils.ml.tr INFO                 val. loss   0.53262 (improved_xe:  0.533)
# 10:22 madminer.utils.ml.tr INFO      Epoch  60: train loss  0.52906 (improved_xe:  0.529)
# 10:22 madminer.utils.ml.tr INFO                 val. loss   0.53182 (improved_xe:  0.532)
# 10:22 madminer.utils.ml.tr INFO      Epoch  64: train loss  0.52892 (improved_xe:  0.529)
# 10:22 madminer.utils.ml.tr INFO                 val. loss   0.53199 (improved_xe:  0.532)
# 10:22 madminer.utils.ml.tr INFO      Epoch  68: train loss  0.52899 (improved_xe:  0.529)
# 10:22 madminer.utils.ml.tr INFO                 val. loss   0.53220 (improved_xe:  0.532)
# 10:22 madminer.utils.ml.tr INFO      Epoch  72: train loss  0.52891 (improved_xe:  0.529)
# 10:22 madminer.utils.ml.tr INFO                 val. loss   0.53333 (improved_xe:  0.533)
# 10:22 madminer.utils.ml.tr INFO      Epoch  76: train loss  0.52921 (improved_xe:  0.529)
# 10:22 madminer.utils.ml.tr INFO                 val. loss   0.53216 (improved_xe:  0.532)
# 10:22 madminer.utils.ml.tr INFO      Epoch  80: train loss  0.52926 (improved_xe:  0.529)
# 10:22 madminer.utils.ml.tr INFO                 val. loss   0.53200 (improved_xe:  0.532)
# 10:22 madminer.utils.ml.tr INFO    Early stopping after epoch 75, with loss  0.53126 compared to final loss  0.53200
# 10:22 madminer.utils.ml.tr INFO    Training time spend on:
# 10:22 madminer.utils.ml.tr INFO                      initialize model:   0.00h
# 10:22 madminer.utils.ml.tr INFO                                   ALL:   0.01h
# 10:22 madminer.utils.ml.tr INFO                            check data:   0.00h
# 10:22 madminer.utils.ml.tr INFO                          make dataset:   0.00h
# 10:22 madminer.utils.ml.tr INFO                       make dataloader:   0.00h
# 10:22 madminer.utils.ml.tr INFO                       setup optimizer:   0.00h
# 10:22 madminer.utils.ml.tr INFO                   initialize training:   0.00h
# 10:22 madminer.utils.ml.tr INFO                                set lr:   0.00h
# 10:22 madminer.utils.ml.tr INFO                   load training batch:   0.00h
# 10:22 madminer.utils.ml.tr INFO                        fwd: move data:   0.00h
# 10:22 madminer.utils.ml.tr INFO                   fwd: check for nans:   0.00h
# 10:22 madminer.utils.ml.tr INFO                    fwd: model.forward:   0.00h
# 10:22 madminer.utils.ml.tr INFO                 fwd: calculate losses:   0.00h
# 10:22 madminer.utils.ml.tr INFO                 training forward pass:   0.00h
# 10:22 madminer.utils.ml.tr INFO                   training sum losses:   0.00h
# 10:22 madminer.utils.ml.tr INFO                        opt: zero grad:   0.00h
# 10:22 madminer.utils.ml.tr INFO                         opt: backward:   0.00h
# 10:22 madminer.utils.ml.tr INFO                   opt: clip grad norm:   0.00h
# 10:22 madminer.utils.ml.tr INFO                             opt: step:   0.00h
# 10:22 madminer.utils.ml.tr INFO                        optimizer step:   0.00h
# 10:22 madminer.utils.ml.tr INFO                 load validation batch:   0.00h
# 10:22 madminer.utils.ml.tr INFO               validation forward pass:   0.00h
# 10:22 madminer.utils.ml.tr INFO                 validation sum losses:   0.00h
# 10:22 madminer.utils.ml.tr INFO                        early stopping:   0.00h
# 10:22 madminer.utils.ml.tr INFO                          report epoch:   0.00h
# 10:22 madminer.ml.base     INFO    Saving model to models_balanced_morph/alice1

# %%
plt.plot(loss[0])
plt.plot(loss[1])

# %%
np.exp(nn.evaluate_log_likelihood_ratio(np.asarray([10,20,30])).detach().numpy())
# Out:
# array([[33.046032],
#        [39.93467 ],
#        [40.229637]], dtype=float32)

# %% [markdown]
# ## 4. Generate evaluation data

# %% [markdown]
# Let us now generate some test data, which is sampled corresponding to `theta=1`

# %%
n_param_points_test = 1000  # number of parameter points to test
theta_test = 1.0 * np.ones(shape=n_param_points_test)

# %% [markdown]
# Run the simulator to get observations:

# %%
x_test = []
for t in theta_test:
    x_test.append(simulate(t)[0])
np.save("data_balanced_morph/x_test.npy", x_test)

# %% [markdown]
# We want to evaluate the expected likelihood ratio on a range of parameter points:

# %%
theta_grid = np.linspace(-5.0, 5.0, 1000).reshape(-1, 1)
np.save("data_balanced_morph/theta_grid.npy", theta_grid)

# %% [markdown]
# In this toy example, we can calculate the true likelihood ratio. We will save the expected log likelihood ratio (multiplied with a conventional factor of -2):

# %%
all_log_r_test_true = []
nllr_test_true = []

for theta in theta_grid:
    log_r = np.log(calculate_likelihood_ratio(x_test, theta))
    nllr_test_true.append(-2.0 * np.mean(log_r))
    all_log_r_test_true.append(log_r)

all_log_r_test_true = np.asarray(all_log_r_test_true).reshape((1000, n_param_points_test))
nllr_test_true = np.asarray(nllr_test_true)

# %% [markdown]
# ## 5. Evaluation

# %% [markdown]
# It's time to evaluate our likelihood ratio estimators!

# %%
x_test
# Out:
# [0.12975928524213787,
#  2.0862823242254427,
#  1.9049482392125068,
#  7.268685840804638,
#  0.04006144160556846,
#  -0.04296116156333535,
#  3.2557326446505206,
#  0.18267314090662157,
#  0.7526955868222563,
#  1.2333769530092034,
#  1.36197479160603,
#  3.446535125508281,
#  0.553420126033062,
#  -0.15015069128689196,
#  -2.3017693468077263,
#  2.0047010222902975,
#  1.690141336677411,
#  -1.1993455836387192,
#  3.12283631471821,
#  -0.2947012401423502,
#  5.6816872749981115,
#  1.6224628355053001,
#  1.4793173537467683,
#  5.83701135951715,
#  -0.3041093581424554,
#  0.49274979405794683,
#  -1.200559987805771,
#  4.446245667418739,
#  2.0978801982262243,
#  -3.240229845877873,
#  4.214260565304805,
#  -1.616121157151263,
#  3.093658872314036,
#  4.433351119351649,
#  1.543953993339902,
#  -1.561840147731438,
#  2.627146512591119,
#  4.473700259985769,
#  -1.8342647002094468,
#  -1.4845437818999183,
#  2.236922204464981,
#  2.1663954190028325,
#  -0.14166349870379663,
#  0.9150998113449655,
#  0.27563000066463084,
#  0.8195243061938228,
#  0.1324041120149792,
#  1.8955032021629101,
#  6.9738754231280895,
#  5.192196275118331,
#  0.9573890102935694,
#  4.666403328942817,
#  2.161905061981995,
#  -0.1347303903909416,
#  3.2722533725806646,
#  2.101965881400834,
#  4.0011704556998104,
#  3.8454499920180036,
#  -3.749846214289535,
#  3.847427751884841,
#  1.6941585499881648,
#  7.151737249624476,
#  -0.28674380651645404,
#  4.790112081059184,
#  5.626860903754939,
#  2.3338850208209987,
#  0.4685789836718395,
#  4.550417146522656,
#  3.6723268557904163,
#  -0.17305201542416668,
#  5.520942730198405,
#  3.5521514623833337,
#  4.0240200126292525,
#  1.5294474820020696,
#  4.947153539772929,
#  -1.5121662381409042,
#  3.0355524974494124,
#  3.402621859308171,
#  -0.6152862365148988,
#  2.95078499337999,
#  0.21283932938808436,
#  -0.2691951965943642,
#  -1.4063448263756033,
#  0.38357354354605355,
#  6.339214999859667,
#  -0.5435928415952967,
#  -1.0453592231895614,
#  3.807597680675852,
#  3.708571416713981,
#  0.447857819306414,
#  3.380442378428949,
#  4.723349889354576,
#  1.4122888355912062,
#  1.949451777239069,
#  2.2625663271607768,
#  4.7051120150410295,
#  3.86233711188582,
#  1.7786638351090107,
#  7.3522597133049015,
#  0.2552650054910357,
#  2.518092886775759]

# %%
loader1 = MorphParameterizedRatioEstimator(n_hidden=(20, 20))
loader2 = MorphParameterizedRatioEstimator(n_hidden=(20, 20))
loader_alice1 = MorphParameterizedRatioEstimator(n_hidden=(20, 20))
loader_alice2 = MorphParameterizedRatioEstimator(n_hidden=(20, 20))
loader1.load("models_balanced_morph/carl0")
loader2.load("models_balanced_morph/carl1")
loader_alice1.load("models_balanced_morph/alice0")
loader_alice2.load("models_balanced_morph/alice1")

ratio_1 = np.exp(loader1.evaluate_log_likelihood_ratio(np.asarray(x_test)).detach().numpy())
ratio_2 = np.exp(loader2.evaluate_log_likelihood_ratio(np.asarray(x_test)).detach().numpy())
ratio_alice1 = np.exp(loader_alice1.evaluate_log_likelihood_ratio(np.asarray(x_test)).detach().numpy())
ratio_alice2 = np.exp(loader_alice2.evaluate_log_likelihood_ratio(np.asarray(x_test)).detach().numpy())
# Out:
# 10:22 madminer.ml.base     INFO    Loading model from models_balanced_morph/carl0
# 10:22 madminer.ml.base     WARNING Parameter scaling information not found in models_balanced_morph/carl0
# 10:22 madminer.ml.base     INFO    Loading model from models_balanced_morph/carl1
# 10:22 madminer.ml.base     WARNING Parameter scaling information not found in models_balanced_morph/carl1
# 10:22 madminer.ml.base     INFO    Loading model from models_balanced_morph/alice0
# 10:22 madminer.ml.base     WARNING Parameter scaling information not found in models_balanced_morph/alice0
# 10:22 madminer.ml.base     INFO    Loading model from models_balanced_morph/alice1
# 10:22 madminer.ml.base     WARNING Parameter scaling information not found in models_balanced_morph/alice1

# %%
plt.scatter(x_test,ratio_alice1)
plt.hist(x_test,histtype="step",density="True")
plt.hist(x1,histtype="step",density="True")
# Out:
# (array([0.0009605 , 0.00876456, 0.03829992, 0.10271342, 0.17120904,
#         0.15914277, 0.08494418, 0.02773442, 0.00600312, 0.00054028]),
#  array([-8.1391132 , -6.47331332, -4.80751344, -3.14171355, -1.47591367,
#          0.18988622,  1.8556861 ,  3.52148599,  5.18728587,  6.85308576,
#          8.51888564]),
#  [<matplotlib.patches.Polygon at 0x7fa3b32b92d0>])

# %%
def ratio(ratios1,ratios2,theta,th0,th1):
    matrix = [[1,0,0],
              [1./(1.+th0**2),th0/(1.+th0**2),th0**2/(1.+th0**2)],
              [1./(1.+th1**2),th1/(1.+th1**2),th1**2/(1.+th1**2)]]
    arr = np.asarray([1/(1+theta**2),theta/(1+theta**2),theta**2/(1+theta**2)])
    sh = np.shape(ratios1)[0]
    #print(sh)
    return arr@np.linalg.inv(matrix)@np.asarray([np.ones(sh),ratios1.flatten(),ratios2.flatten()])

# %%
theta_grid
# Out:
# array([[-5.        ],
#        [-4.98998999],
#        [-4.97997998],
#        [-4.96996997],
#        [-4.95995996],
#        [-4.94994995],
#        [-3.57857858],
#        [-3.56856857],
#        [-3.55855856],
#        [-3.54854855],
#        [-3.53853854],
#        [-3.52852853],
#        [-3.51851852],
#        [-3.50850851],
#        [-3.4984985 ],
#        [-3.48848849],
#        [-3.47847848],
#        [-3.46846847],
#        [-3.45845846],
#        [-3.44844845],
#        [-3.43843844],
#        [-3.42842843],
#        [-3.41841842],
#        [-3.40840841],
#        [-3.3983984 ],
#        [-3.38838839],
#        [-3.37837838],
#        [-3.36836837],
#        [-3.35835836],
#        [-3.34834835],
#        [-3.33833834],
#        [-3.32832833],
#        [-3.31831832],
#        [-3.30830831],
#        [-3.2982983 ],
#        [-3.28828829],
#        [-3.27827828],
#        [-3.26826827],
#        [-3.25825826],
#        [-3.24824825],
#        [-3.23823824],
#        [-3.22822823],
#        [-3.21821822],
#        [-3.20820821],
#        [-3.1981982 ],
#        [-3.18818819],
#        [-3.17817818],
#        [-3.16816817],
#        [-3.15815816],
#        [-3.14814815],
#        [-3.13813814],
#        [-3.12812813],
#        [-3.11811812],
#        [-3.10810811],
#        [-3.0980981 ],
#        [-3.08808809],
#        [-3.07807808],
#        [-3.06806807],
#        [-3.05805806],
#        [-3.04804805],
#        [-3.03803804],
#        [-3.02802803],
#        [-3.01801802],
#        [-3.00800801],
#        [-2.997998  ],
#        [-2.98798799],
#        [-2.97797798],
#        [-2.96796797],
#        [-2.95795796],
#        [-2.94794795],
#        [-2.93793794],
#        [-2.92792793],
#        [-2.91791792],
#        [-2.90790791],
#        [-2.8978979 ],
#        [-2.88788789],
#        [-2.87787788],
#        [-2.86786787],
#        [-2.85785786],
#        [-2.84784785],
#        [-2.83783784],
#        [-2.82782783],
#        [-2.81781782],
#        [-2.80780781],
#        [-2.7977978 ],
#        [-2.78778779],
#        [-2.77777778],
#        [-2.76776777],
#        [-2.75775776],
#        [-2.74774775],
#        [-2.73773774],
#        [-2.72772773],
#        [-2.71771772],
#        [-2.70770771],
#        [-2.6976977 ],
#        [-2.68768769],
#        [-2.67767768],
#        [-2.66766767],
#        [-2.65765766],
#        [-2.64764765],
#        [-2.63763764],
#        [-2.62762763],
#        [-2.61761762],
#        [-2.60760761],
#        [-2.5975976 ],
#        [-2.58758759],
#        [-2.57757758],
#        [-2.56756757],
#        [-2.55755756],
#        [-2.54754755],
#        [-2.53753754],
#        [-2.52752753],
#        [-2.51751752],
#        [-2.50750751],
#        [-2.4974975 ],
#        [-2.48748749],
#        [-2.47747748],
#        [-2.46746747],
#        [-2.45745746],
#        [-2.44744745],
#        [-2.43743744],
#        [-2.42742743],
#        [-2.41741742],
#        [-2.40740741],
#        [-2.3973974 ],
#        [-2.38738739],
#        [-2.37737738],
#        [-2.36736737],
#        [-2.35735736],
#        [-2.34734735],
#        [-2.33733734],
#        [-2.32732733],
#        [-2.31731732],
#        [-2.30730731],
#        [-2.2972973 ],
#        [-2.28728729],
#        [-2.27727728],
#        [-2.26726727],
#        [-2.25725726],
#        [-2.24724725],
#        [-2.23723724],
#        [-2.22722723],
#        [-2.21721722],
#        [ 2.98798799],
#        [ 2.997998  ],
#        [ 3.00800801],
#        [ 3.01801802],
#        [ 3.02802803],
#        [ 3.03803804],
#        [ 3.04804805],
#        [ 3.05805806],
#        [ 3.06806807],
#        [ 3.07807808],
#        [ 3.08808809],
#        [ 3.0980981 ],
#        [ 3.10810811],
#        [ 3.11811812],
#        [ 3.12812813],
#        [ 3.13813814],
#        [ 3.14814815],
#        [ 3.15815816],
#        [ 3.16816817],
#        [ 3.17817818],
#        [ 3.18818819],
#        [ 3.1981982 ],
#        [ 3.20820821],
#        [ 3.21821822],
#        [ 3.22822823],
#        [ 3.23823824],
#        [ 3.24824825],
#        [ 3.25825826],
#        [ 3.26826827],
#        [ 3.27827828],
#        [ 3.28828829],
#        [ 3.2982983 ],
#        [ 3.30830831],
#        [ 3.31831832],
#        [ 3.32832833],
#        [ 3.33833834],
#        [ 3.34834835],
#        [ 3.35835836],
#        [ 3.36836837],
#        [ 3.37837838],
#        [ 3.38838839],
#        [ 3.3983984 ],
#        [ 3.40840841],
#        [ 3.41841842],
#        [ 3.42842843],
#        [ 3.43843844],
#        [ 3.44844845],
#        [ 3.45845846],
#        [ 3.46846847],
#        [ 3.47847848],
#        [ 3.48848849],
#        [ 3.4984985 ],
#        [ 3.50850851],
#        [ 3.51851852],
#        [ 3.52852853],
#        [ 3.53853854],
#        [ 3.54854855],
#        [ 3.55855856],
#        [ 3.56856857],
#        [ 3.57857858],
#        [ 3.58858859],
#        [ 3.5985986 ],
#        [ 3.60860861],
#        [ 3.61861862],
#        [ 3.62862863],
#        [ 3.63863864],
#        [ 3.64864865],
#        [ 3.65865866],
#        [ 3.66866867],
#        [ 3.67867868],
#        [ 3.68868869],
#        [ 3.6986987 ],
#        [ 3.70870871],
#        [ 3.71871872],
#        [ 3.72872873],
#        [ 3.73873874],
#        [ 3.74874875],
#        [ 3.75875876],
#        [ 3.76876877],
#        [ 3.77877878],
#        [ 3.78878879],
#        [ 3.7987988 ],
#        [ 3.80880881],
#        [ 3.81881882],
#        [ 3.82882883],
#        [ 3.83883884],
#        [ 3.84884885],
#        [ 3.85885886],
#        [ 3.86886887],
#        [ 3.87887888],
#        [ 3.88888889],
#        [ 3.8988989 ],
#        [ 3.90890891],
#        [ 3.91891892],
#        [ 3.92892893],
#        [ 3.93893894],
#        [ 3.94894895],
#        [ 3.95895896],
#        [ 3.96896897],
#        [ 3.97897898],
#        [ 3.98898899],
#        [ 3.998999  ],
#        [ 4.00900901],
#        [ 4.01901902],
#        [ 4.02902903],
#        [ 4.03903904],
#        [ 4.04904905],
#        [ 4.05905906],
#        [ 4.06906907],
#        [ 4.07907908],
#        [ 4.08908909],
#        [ 4.0990991 ],
#        [ 4.10910911],
#        [ 4.11911912],
#        [ 4.12912913],
#        [ 4.13913914],
#        [ 4.14914915],
#        [ 4.15915916],
#        [ 4.16916917],
#        [ 4.17917918],
#        [ 4.18918919],
#        [ 4.1991992 ],
#        [ 4.20920921],
#        [ 4.21921922],
#        [ 4.22922923],
#        [ 4.23923924],
#        [ 4.24924925],
#        [ 4.25925926],
#        [ 4.26926927],
#        [ 4.27927928],
#        [ 4.28928929],
#        [ 4.2992993 ],
#        [ 4.30930931],
#        [ 4.31931932],
#        [ 4.32932933],
#        [ 4.33933934],
#        [ 4.34934935],
#        [ 4.35935936],
#        [ 4.36936937],
#        [ 4.37937938],
#        [ 4.38938939],
#        [ 4.3993994 ],
#        [ 4.40940941],
#        [ 4.41941942],
#        [ 4.42942943],
#        [ 4.43943944],
#        [ 4.44944945],
#        [ 4.45945946],
#        [ 4.46946947],
#        [ 4.47947948],
#        [ 4.48948949],
#        [ 4.4994995 ],
#        [ 4.50950951],
#        [ 4.51951952],
#        [ 4.52952953],
#        [ 4.53953954],
#        [ 4.54954955],
#        [ 4.55955956],
#        [ 4.56956957],
#        [ 4.57957958],
#        [ 4.58958959],
#        [ 4.5995996 ],
#        [ 4.60960961],
#        [ 4.61961962],
#        [ 4.62962963],
#        [ 4.63963964],
#        [ 4.64964965],
#        [ 4.65965966],
#        [ 4.66966967],
#        [ 4.67967968],
#        [ 4.68968969],
#        [ 4.6996997 ],
#        [ 4.70970971],
#        [ 4.71971972],
#        [ 4.72972973],
#        [ 4.73973974],
#        [ 4.74974975],
#        [ 4.75975976],
#        [ 4.76976977],
#        [ 4.77977978],
#        [ 4.78978979],
#        [ 4.7997998 ],
#        [ 4.80980981],
#        [ 4.81981982],
#        [ 4.82982983],
#        [ 4.83983984],
#        [ 4.84984985],
#        [ 4.85985986],
#        [ 4.86986987],
#        [ 4.87987988],
#        [ 4.88988989],
#        [ 4.8998999 ],
#        [ 4.90990991],
#        [ 4.91991992],
#        [ 4.92992993],
#        [ 4.93993994],
#        [ 4.94994995],
#        [ 4.95995996],
#        [ 4.96996997],
#        [ 4.97997998],
#        [ 4.98998999],
#        [ 5.        ]])

# %%
thetas = np.linspace(-5.0, 5.0, 1000)
means_alice = []
means_carl = []
for t in thetas:
    rs_carl = (ratio(ratio_1,ratio_2,t,-4,4))
    mask_carl = rs_carl > 0
    rs_carl = rs_carl[mask_carl]
    rs_alice = (ratio(ratio_alice1,ratio_alice2,t,-4,4))
    mask_alice = rs_alice > 0
    rs_alice = rs_alice[mask_alice]
    means_alice.append(-2*np.mean(np.log(rs_alice)))
    means_carl.append(-2*np.mean(np.log(rs_carl)))

# %% [markdown]
# This is the expected log likelihood ratio over parameter space:

# %%
fig = plt.figure(figsize=(5, 5))

plt.plot(
    theta_grid,
    nllr_test_true,
    ls="--",
    c="black",
    label=r"Ground truth ($\theta = 1.0$)",
)
plt.plot(
    theta_grid,
    means_carl,
    c="red",
    label=r"morph carl",
)
plt.plot(
    theta_grid,
    means_alice,
    c="blue",
    label=r"morph alice",
)
plt.xlabel(r"$\theta$")
plt.ylabel(r"$\mathbb{E}_x [ -2\, \log \,r(x | \theta, \theta_{1}) ]$")

plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# You should see that the new ALICES approach leads to a better approximation of the true likelihood ratio than the CARL estimate. Note that we only trained in the parameter range (-4, 4), so the deviations at the left and right of the plot are to be expected.
