# %% [markdown]
# # Toy example
#
# Original notebook by Alexander Held, edited for the MadMiner repository by Johann Brehmer, Irina Espejo, Felix Kling, and Kyle Cranmer 2018-2019.

# %% [markdown]
# In this notebook, we use a simple toy example to demonstrate the machine learning and inference algorithms in MadMiner. This allows us to skip many of the more technical steps, and there's no dependency on MadGraph, Pythia, or Delphes.
#
# What this tutorial does not do, is explaining the inference methods. To understand what's happening, please have a look at ["Constraining Effective Field Theories With Machine Learning"](https://arxiv.org/abs/1805.00013), which will explain the basic idea in just a few pages. If you really want to get down to the dirty details, ["A Guide to Constraining Effective Field Theories With Machine Learning"](https://arxiv.org/abs/1805.00020) has you covered.

# %% [markdown]
# ## Preparations

# %%
import os
import logging
import numpy as np
from scipy.stats import norm
from matplotlib import pyplot as plt

# %matplotlib inline

from madminer.ml import ParameterizedRatioEstimator, RepulsiveEnsembleParameterizedRatioEstimator, BayesianParameterizedRatioEstimator

# %%
if not os.path.exists("data"):
    os.makedirs("data")

# %% [markdown]
# MadMiner uses the Python `logging` module to provide additional information and debugging output. You can choose how much of this output you want to see by switching the level in the following lines to `logging.DEBUG` or `logging.WARNING`.

# %%
# MadMiner output
logging.basicConfig(
    format="%(asctime)-5.5s %(name)-20.20s %(levelname)-7.7s %(message)s",
    datefmt="%H:%M",
    level=logging.INFO,
)

# Output of all other modules (e.g. matplotlib)
for key in logging.Logger.manager.loggerDict:
    if "madminer" not in key:
        logging.getLogger(key).setLevel(logging.WARNING)

# %% [markdown]
# ## 1. A toy simulator

# %% [markdown]
# Our simulator depends on just one parameter `theta` and produces one-dimensional observables `x`. It is characterized by one latent variable `z`. "Running" the simulator consists of two steps:
# - "Hard process": a value of `z` is drawn from a normal distribution, where the mean depends on `theta`.
# - "Detector": a value for `x` is drawn from a normal distribution with mean equal to `z`. There is no explicit dependence on `theta`.
#
# As in the particle physics case, we assume that we can calculate the joint likelihood ratio `r(x, z | theta0, theta1)` as well as the joint score `t(x, z | theta)`, which depend explicitly on `z` (and where the "detector" part cancels).
#
# Here are some general settings (feel free to play with them):

# %%
z_std = 2.0
x_std = 1.0

# %% [markdown]
# The following function runs the simulator for a value of `theta` and calculates the joint likelihood ratio between `theta0` and `theta1` as well as the joint score at `theta_score`:

# %%
def simulate(theta, theta0=None, theta1=None, theta_score=None, npoints=None):
    # Draw latent variables z
    z = np.random.normal(loc=theta, scale=z_std, size=npoints)

    # Draw observables x
    x = np.random.normal(loc=z, scale=x_std, size=None)

    # Calculate joint likelihood ratio and joint score
    if theta0 is not None and theta1 is not None:
        r_xz = norm(loc=theta0, scale=z_std).pdf(z) / norm(loc=theta1, scale=z_std).pdf(z)
    else:
        r_xz = None

    if theta_score is not None:
        t_xz = (x - theta_score) / z_std**2
    else:
        t_xz = None

    return x, r_xz, t_xz

# %% [markdown]
# Usually the likelihood function `p(x|theta)` is intractable, but in this toy example it is just given by the convolution of two Gaussians, which is again a Gaussian. We will use this to validate the results later:

# %%
def calculate_likelihood_ratio(x, theta0, theta1=0.0):
    combined_std = (z_std**2 + x_std**2) ** 0.5
    r_x = norm(loc=theta0, scale=combined_std).pdf(x) / norm(loc=theta1, scale=combined_std).pdf(x)
    return r_x

# %% [markdown]
# Let's now visualize that: we run the simulation and plot the probability distributions $p(x | \theta_i)$. Additionally, we also plot the true log-likelihood ratio $\log\,r(x|\theta_0,\theta_1)$.

# %%
x0, _, _ = simulate(-2, npoints=10000)
x1, _, _ = simulate(2, npoints=10000)

xr = np.linspace(-4.0, 4.0, 100)
rx = np.log(calculate_likelihood_ratio(xr, -2, 2))

fig, ax1 = plt.subplots()
fig.set_size_inches(5, 5)
ax1.set_xlabel("$x$")
ax1.hist(x0, bins=50, range=(-10, 10.0), histtype="step", label=r"$p(x | \theta_0)$", density=True)
ax1.hist(x1, bins=50, range=(-10, 10.0), histtype="step", label=r"$p(x | \theta_1)$", density=True)
ax1.set_ylabel(r"$p(x|\theta)$")
ax1.legend(loc=2)

ax2 = ax1.twinx()
ax2.plot(xr, rx, color="black", label=r"$\log\,r(x|\theta_0,\theta_1)$")
ax2.set_ylabel(r"$\log\,r(x|\theta_0,\theta_1)$")
ax2.legend(loc=1)

plt.show()

# %% [markdown]
# ## 2. Run the simulation and generate training data

# %% [markdown]
# First, we define the parameter points we want to use for training: `theta0` is uniformly distributed while the reference model `theta1` is fixed at zero.

# %%
# number of parameter points to train
n_param_points = 50000

# numerator, uniform prior
theta0 = np.random.uniform(low=-4.0, high=4.0, size=n_param_points)

# denominator: fixed at 0
theta1 = np.zeros(shape=n_param_points)

# %% [markdown]
# We then run the simulator (one sample per parameter point). Remember that `simulate(theta, theta0, theta1, theta_score)` generates data `x` following a theory with `theta` and then evaluates the joint likelihood ratio `r(x,z|theta0,theta1)` and the join score `t(x,z|theta_score)` for each data point.

# %%
# Sample from theta0
x_from_theta0, r_xz_from_theta0, t_xz_from_theta0 = simulate(theta0, theta0, theta1, theta0)

# Sample from theta1
x_from_theta1, r_xz_from_theta1, t_xz_from_theta1 = simulate(theta1, theta0, theta1, theta0)

# %% [markdown]
# Now we combine and reshape the results (nothing interesting happening here) and save everything to files, so that we can load it later.

# %%
# Combine results and reshape
x_train = np.hstack((x_from_theta0, x_from_theta1)).reshape(-1, 1)
r_xz_train = np.hstack((r_xz_from_theta0, r_xz_from_theta1)).reshape(-1, 1)
t_xz_train = np.hstack((t_xz_from_theta0, t_xz_from_theta1)).reshape(-1, 1)
y_train = np.hstack((np.zeros_like(x_from_theta0), np.ones_like(np.ones_like(x_from_theta1)))).reshape(-1, 1)
theta0_train = np.hstack((theta0, theta0)).reshape(-1, 1)

# Save to file
np.save("data/theta0_train.npy", theta0_train)
np.save("data/x_train.npy", x_train)
np.save("data/y_train.npy", y_train)
np.save("data/r_xz_train.npy", r_xz_train)
np.save("data/t_xz_train.npy", t_xz_train)

# %% [markdown]
# ## 3. Model training

# %% [markdown]
# Let's train two neural networks to estimate the likelihood ratio. For one we use the CARL method introduced in ["Approximating Likelihood Ratios with Calibrated Discriminative Classifiers"](https://arxiv.org/abs/1506.02169), for the other the new ALICES method introduced in ["Likelihood-free inference with an improved cross-entropy estimator"](https://arxiv.org/abs/1808.00973).

# %%
alice = ParameterizedRatioEstimator(n_hidden=(20, 20))

alice.train(
    method="alice",
    x="data/x_train.npy",
    y="data/y_train.npy",
    theta="data/theta0_train.npy",
    r_xz="data/r_xz_train.npy",
    t_xz="data/t_xz_train.npy",
    alpha=0.1,
    n_epochs=20,
    initial_lr=0.0001
)

alice.save("models/alice")
# Out:
# 14:21 madminer.ml.paramete INFO    Starting training
# 14:21 madminer.ml.paramete INFO      Method:                 alice
# 14:21 madminer.ml.paramete INFO      Batch size:             128
# 14:21 madminer.ml.paramete INFO      Optimizer:              amsgrad
# 14:21 madminer.ml.paramete INFO      Epochs:                 20
# 14:21 madminer.ml.paramete INFO      Learning rate:          0.0001 initially, decaying to 0.0001
# 14:21 madminer.ml.paramete INFO      Validation split:       0.25
# 14:21 madminer.ml.paramete INFO      Early stopping:         True
# 14:21 madminer.ml.paramete INFO      Scale inputs:           True
# 14:21 madminer.ml.paramete INFO      Scale parameters:       True
# 14:21 madminer.ml.paramete INFO      Shuffle labels          False
# 14:21 madminer.ml.paramete INFO      Samples:                all
# 14:21 madminer.ml.paramete INFO    Loading training data
# 14:21 madminer.utils.vario INFO      Loading data/theta0_train.npy into RAM
# 14:21 madminer.utils.vario INFO      Loading data/x_train.npy into RAM
# 14:21 madminer.utils.vario INFO      Loading data/y_train.npy into RAM
# 14:21 madminer.utils.vario INFO      Loading data/r_xz_train.npy into RAM
# 14:21 madminer.utils.vario INFO      Loading data/t_xz_train.npy into RAM
# 14:21 madminer.ml.paramete INFO    Found 100000 samples with 1 parameters and 1 observables
# 14:21 madminer.ml.base     INFO    Setting up input rescaling
# 14:21 madminer.ml.paramete INFO    Rescaling parameters
# 14:21 madminer.ml.base     INFO    Setting up parameter rescaling
# 14:21 madminer.ml.paramete INFO    Creating model
# 14:21 madminer.ml.paramete INFO    Training model
# 14:21 madminer.utils.ml.tr INFO    Training on CPU with single precision
# 14:21 madminer.utils.ml.tr INFO      Epoch   1: train loss 0.690896119 (improved_xe:  0.691)
# 14:21 madminer.utils.ml.tr INFO                 val. loss  0.679841540 (improved_xe:  0.680)
# 14:21 madminer.utils.ml.tr INFO               total. loss  1.370737659 (improved_xe:  0.680)
# 14:21 madminer.utils.ml.tr INFO      Epoch   2: train loss 0.665627225 (improved_xe:  0.666)
# 14:21 madminer.utils.ml.tr INFO                 val. loss  0.647225721 (improved_xe:  0.647)
# 14:21 madminer.utils.ml.tr INFO               total. loss  1.312852947 (improved_xe:  0.647)
# 14:21 madminer.utils.ml.tr INFO      Epoch   3: train loss 0.626954831 (improved_xe:  0.627)
# 14:21 madminer.utils.ml.tr INFO                 val. loss  0.608757893 (improved_xe:  0.609)
# 14:21 madminer.utils.ml.tr INFO               total. loss  1.235712725 (improved_xe:  0.609)
# 14:21 madminer.utils.ml.tr INFO      Epoch   4: train loss 0.599585913 (improved_xe:  0.600)
# 14:21 madminer.utils.ml.tr INFO                 val. loss  0.593846251 (improved_xe:  0.594)
# 14:21 madminer.utils.ml.tr INFO               total. loss  1.193432163 (improved_xe:  0.594)
# 14:21 madminer.utils.ml.tr INFO      Epoch   5: train loss 0.591944617 (improved_xe:  0.592)
# 14:21 madminer.utils.ml.tr INFO                 val. loss  0.590810102 (improved_xe:  0.591)
# 14:21 madminer.utils.ml.tr INFO               total. loss  1.182754719 (improved_xe:  0.591)
# 14:21 madminer.utils.ml.tr INFO      Epoch   6: train loss 0.590113048 (improved_xe:  0.590)
# 14:21 madminer.utils.ml.tr INFO                 val. loss  0.589854050 (improved_xe:  0.590)
# 14:21 madminer.utils.ml.tr INFO               total. loss  1.179967099 (improved_xe:  0.590)
# 14:21 madminer.utils.ml.tr INFO      Epoch   7: train loss 0.589258287 (improved_xe:  0.589)
# 14:21 madminer.utils.ml.tr INFO                 val. loss  0.588926083 (improved_xe:  0.589)
# 14:21 madminer.utils.ml.tr INFO               total. loss  1.178184370 (improved_xe:  0.589)
# 14:21 madminer.utils.ml.tr INFO      Epoch   8: train loss 0.588665106 (improved_xe:  0.589)
# 14:21 madminer.utils.ml.tr INFO                 val. loss  0.588413406 (improved_xe:  0.588)
# 14:21 madminer.utils.ml.tr INFO               total. loss  1.177078512 (improved_xe:  0.588)
# 14:21 madminer.utils.ml.tr INFO      Epoch   9: train loss 0.588209499 (improved_xe:  0.588)
# 14:21 madminer.utils.ml.tr INFO                 val. loss  0.588067544 (improved_xe:  0.588)
# 14:21 madminer.utils.ml.tr INFO               total. loss  1.176277043 (improved_xe:  0.588)
# 14:21 madminer.utils.ml.tr INFO      Epoch  10: train loss 0.587826969 (improved_xe:  0.588)
# 14:21 madminer.utils.ml.tr INFO                 val. loss  0.587683950 (improved_xe:  0.588)
# 14:21 madminer.utils.ml.tr INFO               total. loss  1.175510919 (improved_xe:  0.588)
# 14:21 madminer.utils.ml.tr INFO      Epoch  11: train loss 0.587508539 (improved_xe:  0.588)
# 14:21 madminer.utils.ml.tr INFO                 val. loss  0.587162324 (improved_xe:  0.587)
# 14:21 madminer.utils.ml.tr INFO               total. loss  1.174670863 (improved_xe:  0.587)
# 14:21 madminer.utils.ml.tr INFO      Epoch  12: train loss 0.587235841 (improved_xe:  0.587)
# 14:21 madminer.utils.ml.tr INFO                 val. loss  0.587180512 (improved_xe:  0.587)
# 14:21 madminer.utils.ml.tr INFO               total. loss  1.174416353 (improved_xe:  0.587)
# 14:21 madminer.utils.ml.tr INFO      Epoch  13: train loss 0.587001200 (improved_xe:  0.587)
# 14:21 madminer.utils.ml.tr INFO                 val. loss  0.586976414 (improved_xe:  0.587)
# 14:21 madminer.utils.ml.tr INFO               total. loss  1.173977614 (improved_xe:  0.587)
# 14:21 madminer.utils.ml.tr INFO      Epoch  14: train loss 0.586794317 (improved_xe:  0.587)
# 14:21 madminer.utils.ml.tr INFO                 val. loss  0.586800947 (improved_xe:  0.587)
# 14:21 madminer.utils.ml.tr INFO               total. loss  1.173595264 (improved_xe:  0.587)
# 14:21 madminer.utils.ml.tr INFO      Epoch  15: train loss 0.586616377 (improved_xe:  0.587)
# 14:21 madminer.utils.ml.tr INFO                 val. loss  0.586627119 (improved_xe:  0.587)
# 14:21 madminer.utils.ml.tr INFO               total. loss  1.173243496 (improved_xe:  0.587)
# 14:21 madminer.utils.ml.tr INFO      Epoch  16: train loss 0.586458118 (improved_xe:  0.586)
# 14:21 madminer.utils.ml.tr INFO                 val. loss  0.586231134 (improved_xe:  0.586)
# 14:21 madminer.utils.ml.tr INFO               total. loss  1.172689253 (improved_xe:  0.586)
# 14:21 madminer.utils.ml.tr INFO      Epoch  17: train loss 0.586307820 (improved_xe:  0.586)
# 14:21 madminer.utils.ml.tr INFO                 val. loss  0.586463638 (improved_xe:  0.586)
# 14:21 madminer.utils.ml.tr INFO               total. loss  1.172771458 (improved_xe:  0.586)
# 14:22 madminer.utils.ml.tr INFO      Epoch  18: train loss 0.586193755 (improved_xe:  0.586)
# 14:22 madminer.utils.ml.tr INFO                 val. loss  0.586178004 (improved_xe:  0.586)
# 14:22 madminer.utils.ml.tr INFO               total. loss  1.172371759 (improved_xe:  0.586)
# 14:22 madminer.utils.ml.tr INFO      Epoch  19: train loss 0.586075856 (improved_xe:  0.586)
# 14:22 madminer.utils.ml.tr INFO                 val. loss  0.585923277 (improved_xe:  0.586)
# 14:22 madminer.utils.ml.tr INFO               total. loss  1.171999133 (improved_xe:  0.586)
# 14:22 madminer.utils.ml.tr INFO      Epoch  20: train loss 0.585966266 (improved_xe:  0.586)
# 14:22 madminer.utils.ml.tr INFO                 val. loss  0.586002543 (improved_xe:  0.586)
# 14:22 madminer.utils.ml.tr INFO               total. loss  1.171968809 (improved_xe:  0.586)
# 14:22 madminer.utils.ml.tr INFO    Early stopping after epoch 19, with loss  0.58592 compared to final loss  0.58600
# 14:22 madminer.utils.ml.tr INFO    Training time spend on:
# 14:22 madminer.utils.ml.tr INFO                      initialize model:   0.00h
# 14:22 madminer.utils.ml.tr INFO                                   ALL:   0.00h
# 14:22 madminer.utils.ml.tr INFO                            check data:   0.00h
# 14:22 madminer.utils.ml.tr INFO                          make dataset:   0.00h
# 14:22 madminer.utils.ml.tr INFO                       make dataloader:   0.00h
# 14:22 madminer.utils.ml.tr INFO                       setup optimizer:   0.00h
# 14:22 madminer.utils.ml.tr INFO                   initialize training:   0.00h
# 14:22 madminer.utils.ml.tr INFO                                set lr:   0.00h
# 14:22 madminer.utils.ml.tr INFO                   load training batch:   0.00h
# 14:22 madminer.utils.ml.tr INFO                        fwd: move data:   0.00h
# 14:22 madminer.utils.ml.tr INFO                   fwd: check for nans:   0.00h
# 14:22 madminer.utils.ml.tr INFO                    fwd: model.forward:   0.00h
# 14:22 madminer.utils.ml.tr INFO                 fwd: calculate losses:   0.00h
# 14:22 madminer.utils.ml.tr INFO                 training forward pass:   0.00h
# 14:22 madminer.utils.ml.tr INFO                   training sum losses:   0.00h
# 14:22 madminer.utils.ml.tr INFO                        opt: zero grad:   0.00h
# 14:22 madminer.utils.ml.tr INFO                         opt: backward:   0.00h
# 14:22 madminer.utils.ml.tr INFO                   opt: clip grad norm:   0.00h
# 14:22 madminer.utils.ml.tr INFO                             opt: step:   0.00h
# 14:22 madminer.utils.ml.tr INFO                        optimizer step:   0.00h
# 14:22 madminer.utils.ml.tr INFO                 load validation batch:   0.00h
# 14:22 madminer.utils.ml.tr INFO               validation forward pass:   0.00h
# 14:22 madminer.utils.ml.tr INFO                 validation sum losses:   0.00h
# 14:22 madminer.utils.ml.tr INFO                        early stopping:   0.00h
# 14:22 madminer.utils.ml.tr INFO                          report epoch:   0.00h
# 14:22 madminer.ml.base     INFO    Saving model to models/alice

# %%
repulsive_alice = RepulsiveEnsembleParameterizedRatioEstimator(n_hidden=(20, 20))

repulsive_alice.train(
    method="repulsive_alice",
    x="data/x_train.npy",
    y="data/y_train.npy",
    theta="data/theta0_train.npy",
    r_xz="data/r_xz_train.npy",
    t_xz="data/t_xz_train.npy",
    n_epochs=20,
    initial_lr=0.0001
)

repulsive_alice.save("models/repulsive_alice")
# Out:
# 14:22 madminer.ml.paramete INFO    Starting training
# 14:22 madminer.ml.paramete INFO      Method:                 repulsive_alice
# 14:22 madminer.ml.paramete INFO      Batch size:             128
# 14:22 madminer.ml.paramete INFO      Optimizer:              amsgrad
# 14:22 madminer.ml.paramete INFO      Epochs:                 20
# 14:22 madminer.ml.paramete INFO      Learning rate:          0.0001 initially, decaying to 0.0001
# 14:22 madminer.ml.paramete INFO      Validation split:       0.25
# 14:22 madminer.ml.paramete INFO      Early stopping:         True
# 14:22 madminer.ml.paramete INFO      Scale inputs:           True
# 14:22 madminer.ml.paramete INFO      Scale parameters:       True
# 14:22 madminer.ml.paramete INFO      Shuffle labels          False
# 14:22 madminer.ml.paramete INFO      Samples:                all
# 14:22 madminer.ml.paramete INFO    Loading training data
# 14:22 madminer.utils.vario INFO      Loading data/theta0_train.npy into RAM
# 14:22 madminer.utils.vario INFO      Loading data/x_train.npy into RAM
# 14:22 madminer.utils.vario INFO      Loading data/y_train.npy into RAM
# 14:22 madminer.utils.vario INFO      Loading data/r_xz_train.npy into RAM
# 14:22 madminer.utils.vario INFO      Loading data/t_xz_train.npy into RAM
# 14:22 madminer.ml.paramete INFO    Found 100000 samples with 1 parameters and 1 observables
# 14:22 madminer.ml.base     INFO    Setting up input rescaling
# 14:22 madminer.ml.paramete INFO    Rescaling parameters
# 14:22 madminer.ml.base     INFO    Setting up parameter rescaling
# 14:22 madminer.ml.paramete INFO    Creating model
# 14:22 madminer.ml.paramete INFO    Training model
# 14:22 madminer.utils.ml.tr INFO    Training on CPU with single precision
# 14:22 madminer.utils.ml.tr INFO      Epoch   1: train loss 0.685865444 (repulsive_improved_xe:  0.686)
# 14:22 madminer.utils.ml.tr INFO                 val. loss  0.675297822 (repulsive_improved_xe:  0.675)
# 14:22 madminer.utils.ml.tr INFO               total. loss  1.361163265 (repulsive_improved_xe:  0.675)
# 14:22 madminer.utils.ml.tr INFO      Epoch   2: train loss 0.659196759 (repulsive_improved_xe:  0.659)
# 14:22 madminer.utils.ml.tr INFO                 val. loss  0.642050766 (repulsive_improved_xe:  0.642)
# 14:22 madminer.utils.ml.tr INFO               total. loss  1.301247525 (repulsive_improved_xe:  0.642)
# 14:22 madminer.utils.ml.tr INFO      Epoch   3: train loss 0.623918691 (repulsive_improved_xe:  0.624)
# 14:22 madminer.utils.ml.tr INFO                 val. loss  0.611242187 (repulsive_improved_xe:  0.611)
# 14:22 madminer.utils.ml.tr INFO               total. loss  1.235160878 (repulsive_improved_xe:  0.611)
# 14:22 madminer.utils.ml.tr INFO      Epoch   4: train loss 0.601462986 (repulsive_improved_xe:  0.601)
# 14:22 madminer.utils.ml.tr INFO                 val. loss  0.598304724 (repulsive_improved_xe:  0.598)
# 14:22 madminer.utils.ml.tr INFO               total. loss  1.199767710 (repulsive_improved_xe:  0.598)
# 14:22 madminer.utils.ml.tr INFO      Epoch   5: train loss 0.593137644 (repulsive_improved_xe:  0.593)
# 14:22 madminer.utils.ml.tr INFO                 val. loss  0.593794121 (repulsive_improved_xe:  0.594)
# 14:22 madminer.utils.ml.tr INFO               total. loss  1.186931765 (repulsive_improved_xe:  0.594)
# 14:22 madminer.utils.ml.tr INFO      Epoch   6: train loss 0.590011310 (repulsive_improved_xe:  0.590)
# 14:22 madminer.utils.ml.tr INFO                 val. loss  0.591902897 (repulsive_improved_xe:  0.592)
# 14:22 madminer.utils.ml.tr INFO               total. loss  1.181914206 (repulsive_improved_xe:  0.592)
# 14:22 madminer.utils.ml.tr INFO      Epoch   7: train loss 0.588597823 (repulsive_improved_xe:  0.589)
# 14:22 madminer.utils.ml.tr INFO                 val. loss  0.590895433 (repulsive_improved_xe:  0.591)
# 14:22 madminer.utils.ml.tr INFO               total. loss  1.179493256 (repulsive_improved_xe:  0.591)
# 14:22 madminer.utils.ml.tr INFO      Epoch   8: train loss 0.587822563 (repulsive_improved_xe:  0.588)
# 14:22 madminer.utils.ml.tr INFO                 val. loss  0.590291771 (repulsive_improved_xe:  0.590)
# 14:22 madminer.utils.ml.tr INFO               total. loss  1.178114334 (repulsive_improved_xe:  0.590)
# 14:22 madminer.utils.ml.tr INFO      Epoch   9: train loss 0.587307448 (repulsive_improved_xe:  0.587)
# 14:22 madminer.utils.ml.tr INFO                 val. loss  0.589964944 (repulsive_improved_xe:  0.590)
# 14:22 madminer.utils.ml.tr INFO               total. loss  1.177272392 (repulsive_improved_xe:  0.590)
# 14:22 madminer.utils.ml.tr INFO      Epoch  10: train loss 0.586913147 (repulsive_improved_xe:  0.587)
# 14:22 madminer.utils.ml.tr INFO                 val. loss  0.589509499 (repulsive_improved_xe:  0.590)
# 14:22 madminer.utils.ml.tr INFO               total. loss  1.176422646 (repulsive_improved_xe:  0.590)
# 14:23 madminer.utils.ml.tr INFO      Epoch  11: train loss 0.586604878 (repulsive_improved_xe:  0.587)
# 14:23 madminer.utils.ml.tr INFO                 val. loss  0.589255376 (repulsive_improved_xe:  0.589)
# 14:23 madminer.utils.ml.tr INFO               total. loss  1.175860254 (repulsive_improved_xe:  0.589)
# 14:23 madminer.utils.ml.tr INFO      Epoch  12: train loss 0.586342659 (repulsive_improved_xe:  0.586)
# 14:23 madminer.utils.ml.tr INFO                 val. loss  0.589142021 (repulsive_improved_xe:  0.589)
# 14:23 madminer.utils.ml.tr INFO               total. loss  1.175484680 (repulsive_improved_xe:  0.589)
# 14:23 madminer.utils.ml.tr INFO      Epoch  13: train loss 0.586112018 (repulsive_improved_xe:  0.586)
# 14:23 madminer.utils.ml.tr INFO                 val. loss  0.588769176 (repulsive_improved_xe:  0.589)
# 14:23 madminer.utils.ml.tr INFO               total. loss  1.174881194 (repulsive_improved_xe:  0.589)
# 14:23 madminer.utils.ml.tr INFO      Epoch  14: train loss 0.585923734 (repulsive_improved_xe:  0.586)
# 14:23 madminer.utils.ml.tr INFO                 val. loss  0.588606909 (repulsive_improved_xe:  0.589)
# 14:23 madminer.utils.ml.tr INFO               total. loss  1.174530643 (repulsive_improved_xe:  0.589)
# 14:23 madminer.utils.ml.tr INFO      Epoch  15: train loss 0.585750461 (repulsive_improved_xe:  0.586)
# 14:23 madminer.utils.ml.tr INFO                 val. loss  0.588567849 (repulsive_improved_xe:  0.589)
# 14:23 madminer.utils.ml.tr INFO               total. loss  1.174318309 (repulsive_improved_xe:  0.589)
# 14:23 madminer.utils.ml.tr INFO      Epoch  16: train loss 0.585605777 (repulsive_improved_xe:  0.586)
# 14:23 madminer.utils.ml.tr INFO                 val. loss  0.588210733 (repulsive_improved_xe:  0.588)
# 14:23 madminer.utils.ml.tr INFO               total. loss  1.173816510 (repulsive_improved_xe:  0.588)
# 14:23 madminer.utils.ml.tr INFO      Epoch  17: train loss 0.585468207 (repulsive_improved_xe:  0.585)
# 14:23 madminer.utils.ml.tr INFO                 val. loss  0.588117346 (repulsive_improved_xe:  0.588)
# 14:23 madminer.utils.ml.tr INFO               total. loss  1.173585553 (repulsive_improved_xe:  0.588)
# 14:23 madminer.utils.ml.tr INFO      Epoch  18: train loss 0.585351625 (repulsive_improved_xe:  0.585)
# 14:23 madminer.utils.ml.tr INFO                 val. loss  0.588205966 (repulsive_improved_xe:  0.588)
# 14:23 madminer.utils.ml.tr INFO               total. loss  1.173557591 (repulsive_improved_xe:  0.588)
# 14:23 madminer.utils.ml.tr INFO      Epoch  19: train loss 0.585236887 (repulsive_improved_xe:  0.585)
# 14:23 madminer.utils.ml.tr INFO                 val. loss  0.587943864 (repulsive_improved_xe:  0.588)
# 14:23 madminer.utils.ml.tr INFO               total. loss  1.173180750 (repulsive_improved_xe:  0.588)
# 14:23 madminer.utils.ml.tr INFO      Epoch  20: train loss 0.585143856 (repulsive_improved_xe:  0.585)
# 14:23 madminer.utils.ml.tr INFO                 val. loss  0.587879077 (repulsive_improved_xe:  0.588)
# 14:23 madminer.utils.ml.tr INFO               total. loss  1.173022932 (repulsive_improved_xe:  0.588)
# 14:23 madminer.utils.ml.tr INFO    Early stopping did not improve performance
# 14:23 madminer.utils.ml.tr INFO    Training time spend on:
# 14:23 madminer.utils.ml.tr INFO                      initialize model:   0.00h
# 14:23 madminer.utils.ml.tr INFO                                   ALL:   0.02h
# 14:23 madminer.utils.ml.tr INFO                            check data:   0.00h
# 14:23 madminer.utils.ml.tr INFO                          make dataset:   0.00h
# 14:23 madminer.utils.ml.tr INFO                       make dataloader:   0.00h
# 14:23 madminer.utils.ml.tr INFO                       setup optimizer:   0.00h
# 14:23 madminer.utils.ml.tr INFO                   initialize training:   0.00h
# 14:23 madminer.utils.ml.tr INFO                                set lr:   0.00h
# 14:23 madminer.utils.ml.tr INFO                   load training batch:   0.00h
# 14:23 madminer.utils.ml.tr INFO                        fwd: move data:   0.00h
# 14:23 madminer.utils.ml.tr INFO                   fwd: check for nans:   0.00h
# 14:23 madminer.utils.ml.tr INFO                    fwd: model.forward:   0.01h
# 14:23 madminer.utils.ml.tr INFO                 fwd: calculate losses:   0.01h
# 14:23 madminer.utils.ml.tr INFO                 training forward pass:   0.01h
# 14:23 madminer.utils.ml.tr INFO                   training sum losses:   0.00h
# 14:23 madminer.utils.ml.tr INFO                        opt: zero grad:   0.00h
# 14:23 madminer.utils.ml.tr INFO                         opt: backward:   0.01h
# 14:23 madminer.utils.ml.tr INFO                   opt: clip grad norm:   0.00h
# 14:23 madminer.utils.ml.tr INFO                             opt: step:   0.00h
# 14:23 madminer.utils.ml.tr INFO                        optimizer step:   0.01h
# 14:23 madminer.utils.ml.tr INFO                 load validation batch:   0.00h
# 14:23 madminer.utils.ml.tr INFO               validation forward pass:   0.00h
# 14:23 madminer.utils.ml.tr INFO                 validation sum losses:   0.00h
# 14:23 madminer.utils.ml.tr INFO                        early stopping:   0.00h
# 14:23 madminer.utils.ml.tr INFO                          report epoch:   0.00h
# 14:23 madminer.ml.base     INFO    Saving model to models/repulsive_alice

# %%
bayesian_alice = BayesianParameterizedRatioEstimator(n_hidden=(20,20))

bayesian_alice.train(
    method="bayesian_alice",
    x="data/x_train.npy",
    y="data/y_train.npy",
    theta="data/theta0_train.npy",
    r_xz="data/r_xz_train.npy",
    t_xz="data/t_xz_train.npy",
    n_epochs=20,
    initial_lr=0.0001,
    alpha=0.01
)

bayesian_alice.save("models/bayesian_alice")
# Out:
# 14:26 madminer.ml.paramete INFO    Starting training
# 14:26 madminer.ml.paramete INFO      Method:                 bayesian_alice
# 14:26 madminer.ml.paramete INFO      Batch size:             128
# 14:26 madminer.ml.paramete INFO      Optimizer:              amsgrad
# 14:26 madminer.ml.paramete INFO      Epochs:                 20
# 14:26 madminer.ml.paramete INFO      Learning rate:          0.0001 initially, decaying to 0.0001
# 14:26 madminer.ml.paramete INFO      Validation split:       0.25
# 14:26 madminer.ml.paramete INFO      Early stopping:         True
# 14:26 madminer.ml.paramete INFO      Scale inputs:           True
# 14:26 madminer.ml.paramete INFO      Scale parameters:       True
# 14:26 madminer.ml.paramete INFO      Shuffle labels          False
# 14:26 madminer.ml.paramete INFO      Samples:                all
# 14:26 madminer.ml.paramete INFO    Loading training data
# 14:26 madminer.utils.vario INFO      Loading data/theta0_train.npy into RAM
# 14:26 madminer.utils.vario INFO      Loading data/x_train.npy into RAM
# 14:26 madminer.utils.vario INFO      Loading data/y_train.npy into RAM
# 14:26 madminer.utils.vario INFO      Loading data/r_xz_train.npy into RAM
# 14:26 madminer.utils.vario INFO      Loading data/t_xz_train.npy into RAM
# 14:26 madminer.ml.paramete INFO    Found 100000 samples with 1 parameters and 1 observables
# 14:26 madminer.ml.base     INFO    Setting up input rescaling
# 14:26 madminer.ml.paramete INFO    Rescaling parameters
# 14:26 madminer.ml.base     INFO    Setting up parameter rescaling
# 14:26 madminer.ml.paramete INFO    Creating model
# 14:26 madminer.ml.paramete INFO    Training model
# 14:26 madminer.utils.ml.tr INFO    Training on CPU with single precision
# 14:26 madminer.utils.ml.tr INFO      Epoch   1: train loss 0.836743322 (bayesian_nl:  0.692, bayesian_kl: 14.481)
# 14:26 madminer.utils.ml.tr INFO                 val. loss  0.832241888 (bayesian_nl:  0.686, bayesian_kl: 14.591)
# 14:26 madminer.utils.ml.tr INFO               total. loss  1.668985209 (bayesian_nl:  0.686, bayesian_kl: 14.591)
# 14:26 madminer.utils.ml.tr INFO      Epoch   2: train loss 0.821602054 (bayesian_nl:  0.678, bayesian_kl: 14.383)
# 14:26 madminer.utils.ml.tr INFO                 val. loss  0.811545264 (bayesian_nl:  0.667, bayesian_kl: 14.495)
# 14:26 madminer.utils.ml.tr INFO               total. loss  1.633147318 (bayesian_nl:  0.667, bayesian_kl: 14.495)
# 14:26 madminer.utils.ml.tr INFO      Epoch   3: train loss 0.795586447 (bayesian_nl:  0.653, bayesian_kl: 14.291)
# 14:26 madminer.utils.ml.tr INFO                 val. loss  0.781567538 (bayesian_nl:  0.638, bayesian_kl: 14.405)
# 14:26 madminer.utils.ml.tr INFO               total. loss  1.577153985 (bayesian_nl:  0.638, bayesian_kl: 14.405)
# 14:26 madminer.utils.ml.tr INFO      Epoch   4: train loss 0.766899770 (bayesian_nl:  0.625, bayesian_kl: 14.203)
# 14:26 madminer.utils.ml.tr INFO                 val. loss  0.756501013 (bayesian_nl:  0.613, bayesian_kl: 14.316)
# 14:26 madminer.utils.ml.tr INFO               total. loss  1.523400782 (bayesian_nl:  0.613, bayesian_kl: 14.316)
# 14:26 madminer.utils.ml.tr INFO      Epoch   5: train loss 0.748507012 (bayesian_nl:  0.607, bayesian_kl: 14.113)
# 14:26 madminer.utils.ml.tr INFO                 val. loss  0.744487106 (bayesian_nl:  0.602, bayesian_kl: 14.223)
# 14:26 madminer.utils.ml.tr INFO               total. loss  1.492994117 (bayesian_nl:  0.602, bayesian_kl: 14.223)
# 14:26 madminer.utils.ml.tr INFO      Epoch   6: train loss 0.740348075 (bayesian_nl:  0.600, bayesian_kl: 14.019)
# 14:26 madminer.utils.ml.tr INFO                 val. loss  0.738916197 (bayesian_nl:  0.598, bayesian_kl: 14.126)
# 14:26 madminer.utils.ml.tr INFO               total. loss  1.479264272 (bayesian_nl:  0.598, bayesian_kl: 14.126)
# 14:26 madminer.utils.ml.tr INFO      Epoch   7: train loss 0.736028855 (bayesian_nl:  0.597, bayesian_kl: 13.923)
# 14:26 madminer.utils.ml.tr INFO                 val. loss  0.735244445 (bayesian_nl:  0.595, bayesian_kl: 14.028)
# 14:26 madminer.utils.ml.tr INFO               total. loss  1.471273300 (bayesian_nl:  0.595, bayesian_kl: 14.028)
# 14:26 madminer.utils.ml.tr INFO      Epoch   8: train loss 0.732912473 (bayesian_nl:  0.595, bayesian_kl: 13.826)
# 14:26 madminer.utils.ml.tr INFO                 val. loss  0.732409322 (bayesian_nl:  0.593, bayesian_kl: 13.930)
# 14:26 madminer.utils.ml.tr INFO               total. loss  1.465321796 (bayesian_nl:  0.593, bayesian_kl: 13.930)
# 14:26 madminer.utils.ml.tr INFO      Epoch   9: train loss 0.730360494 (bayesian_nl:  0.593, bayesian_kl: 13.729)
# 14:26 madminer.utils.ml.tr INFO                 val. loss  0.730249057 (bayesian_nl:  0.592, bayesian_kl: 13.833)
# 14:26 madminer.utils.ml.tr INFO               total. loss  1.460609551 (bayesian_nl:  0.592, bayesian_kl: 13.833)
# 14:26 madminer.utils.ml.tr INFO      Epoch  10: train loss 0.728211898 (bayesian_nl:  0.592, bayesian_kl: 13.633)
# 14:26 madminer.utils.ml.tr INFO                 val. loss  0.728226210 (bayesian_nl:  0.591, bayesian_kl: 13.736)
# 14:26 madminer.utils.ml.tr INFO               total. loss  1.456438109 (bayesian_nl:  0.591, bayesian_kl: 13.736)
# 14:26 madminer.utils.ml.tr INFO      Epoch  11: train loss 0.726288271 (bayesian_nl:  0.591, bayesian_kl: 13.538)
# 14:26 madminer.utils.ml.tr INFO                 val. loss  0.726189827 (bayesian_nl:  0.590, bayesian_kl: 13.640)
# 14:26 madminer.utils.ml.tr INFO               total. loss  1.452478097 (bayesian_nl:  0.590, bayesian_kl: 13.640)
# 14:26 madminer.utils.ml.tr INFO      Epoch  12: train loss 0.724649140 (bayesian_nl:  0.590, bayesian_kl: 13.443)
# 14:26 madminer.utils.ml.tr INFO                 val. loss  0.724699156 (bayesian_nl:  0.589, bayesian_kl: 13.544)
# 14:26 madminer.utils.ml.tr INFO               total. loss  1.449348296 (bayesian_nl:  0.589, bayesian_kl: 13.544)
# 14:26 madminer.utils.ml.tr INFO      Epoch  13: train loss 0.723093088 (bayesian_nl:  0.590, bayesian_kl: 13.348)
# 14:26 madminer.utils.ml.tr INFO                 val. loss  0.723149793 (bayesian_nl:  0.589, bayesian_kl: 13.449)
# 14:26 madminer.utils.ml.tr INFO               total. loss  1.446242881 (bayesian_nl:  0.589, bayesian_kl: 13.449)
# 14:26 madminer.utils.ml.tr INFO      Epoch  14: train loss 0.721630093 (bayesian_nl:  0.589, bayesian_kl: 13.255)
# 14:26 madminer.utils.ml.tr INFO                 val. loss  0.721738661 (bayesian_nl:  0.588, bayesian_kl: 13.355)
# 14:26 madminer.utils.ml.tr INFO               total. loss  1.443368754 (bayesian_nl:  0.588, bayesian_kl: 13.355)
# 14:26 madminer.utils.ml.tr INFO      Epoch  15: train loss 0.720236083 (bayesian_nl:  0.589, bayesian_kl: 13.161)
# 14:26 madminer.utils.ml.tr INFO                 val. loss  0.720406157 (bayesian_nl:  0.588, bayesian_kl: 13.260)
# 14:26 madminer.utils.ml.tr INFO               total. loss  1.440642240 (bayesian_nl:  0.588, bayesian_kl: 13.260)
# 14:26 madminer.utils.ml.tr INFO      Epoch  16: train loss 0.719032458 (bayesian_nl:  0.588, bayesian_kl: 13.068)
# 14:26 madminer.utils.ml.tr INFO                 val. loss  0.719259170 (bayesian_nl:  0.588, bayesian_kl: 13.167)
# 14:26 madminer.utils.ml.tr INFO               total. loss  1.438291628 (bayesian_nl:  0.588, bayesian_kl: 13.167)
# 14:26 madminer.utils.ml.tr INFO      Epoch  17: train loss 0.717810533 (bayesian_nl:  0.588, bayesian_kl: 12.976)
# 14:26 madminer.utils.ml.tr INFO                 val. loss  0.717965247 (bayesian_nl:  0.587, bayesian_kl: 13.074)
# 14:26 madminer.utils.ml.tr INFO               total. loss  1.435775780 (bayesian_nl:  0.587, bayesian_kl: 13.074)
# 14:26 madminer.utils.ml.tr INFO      Epoch  18: train loss 0.716609893 (bayesian_nl:  0.588, bayesian_kl: 12.884)
# 14:26 madminer.utils.ml.tr INFO                 val. loss  0.716798418 (bayesian_nl:  0.587, bayesian_kl: 12.981)
# 14:26 madminer.utils.ml.tr INFO               total. loss  1.433408311 (bayesian_nl:  0.587, bayesian_kl: 12.981)
# 14:26 madminer.utils.ml.tr INFO      Epoch  19: train loss 0.715582211 (bayesian_nl:  0.588, bayesian_kl: 12.793)
# 14:26 madminer.utils.ml.tr INFO                 val. loss  0.715687182 (bayesian_nl:  0.587, bayesian_kl: 12.889)
# 14:26 madminer.utils.ml.tr INFO               total. loss  1.431269394 (bayesian_nl:  0.587, bayesian_kl: 12.889)
# 14:26 madminer.utils.ml.tr INFO      Epoch  20: train loss 0.714471421 (bayesian_nl:  0.587, bayesian_kl: 12.702)
# 14:26 madminer.utils.ml.tr INFO                 val. loss  0.714634588 (bayesian_nl:  0.587, bayesian_kl: 12.798)
# 14:26 madminer.utils.ml.tr INFO               total. loss  1.429106009 (bayesian_nl:  0.587, bayesian_kl: 12.798)
# 14:26 madminer.utils.ml.tr INFO    Early stopping did not improve performance
# 14:26 madminer.utils.ml.tr INFO    Training time spend on:
# 14:26 madminer.utils.ml.tr INFO                      initialize model:   0.00h
# 14:26 madminer.utils.ml.tr INFO                                   ALL:   0.00h
# 14:26 madminer.utils.ml.tr INFO                            check data:   0.00h
# 14:26 madminer.utils.ml.tr INFO                          make dataset:   0.00h
# 14:26 madminer.utils.ml.tr INFO                       make dataloader:   0.00h
# 14:26 madminer.utils.ml.tr INFO                       setup optimizer:   0.00h
# 14:26 madminer.utils.ml.tr INFO                   initialize training:   0.00h
# 14:26 madminer.utils.ml.tr INFO                                set lr:   0.00h
# 14:26 madminer.utils.ml.tr INFO                   load training batch:   0.00h
# 14:26 madminer.utils.ml.tr INFO                        fwd: move data:   0.00h
# 14:26 madminer.utils.ml.tr INFO                   fwd: check for nans:   0.00h
# 14:26 madminer.utils.ml.tr INFO                    fwd: model.forward:   0.00h
# 14:26 madminer.utils.ml.tr INFO                 fwd: calculate losses:   0.00h
# 14:26 madminer.utils.ml.tr INFO                 training forward pass:   0.00h
# 14:26 madminer.utils.ml.tr INFO                   training sum losses:   0.00h
# 14:26 madminer.utils.ml.tr INFO                        opt: zero grad:   0.00h
# 14:26 madminer.utils.ml.tr INFO                         opt: backward:   0.00h
# 14:26 madminer.utils.ml.tr INFO                   opt: clip grad norm:   0.00h
# 14:26 madminer.utils.ml.tr INFO                             opt: step:   0.00h
# 14:26 madminer.utils.ml.tr INFO                        optimizer step:   0.00h
# 14:26 madminer.utils.ml.tr INFO                 load validation batch:   0.00h
# 14:26 madminer.utils.ml.tr INFO               validation forward pass:   0.00h
# 14:26 madminer.utils.ml.tr INFO                 validation sum losses:   0.00h
# 14:26 madminer.utils.ml.tr INFO                        early stopping:   0.00h
# 14:26 madminer.utils.ml.tr INFO                          report epoch:   0.00h
# 14:26 madminer.ml.base     INFO    Saving model to models/bayesian_alice

# %% [markdown]
# ## 4. Generate evaluation data

# %% [markdown]
# Let us now generate some test data, which is sampled corresponding to `theta=1`

# %%
n_param_points_test = 1000  # number of parameter points to test
theta_test = 1.0 * np.ones(shape=n_param_points_test).reshape(-1, 1)

# %% [markdown]
# Run the simulator to get observations:

# %%
x_test, _, _ = simulate(theta_test)
np.save("data/x_test.npy", x_test)

# %% [markdown]
# We want to evaluate the expected likelihood ratio on a range of parameter points:

# %%
theta_grid = np.linspace(-5.0, 5.0, 100).reshape(-1, 1)
np.save("data/theta_grid.npy", theta_grid)

# %% [markdown]
# In this toy example, we can calculate the true likelihood ratio. We will save the expected log likelihood ratio (multiplied with a conventional factor of -2):

# %%
all_log_r_test_true = []
nllr_test_true = []

for theta in theta_grid:
    log_r = np.log(calculate_likelihood_ratio(x_test, theta))
    nllr_test_true.append(-2.0 * np.mean(log_r))
    all_log_r_test_true.append(log_r)

all_log_r_test_true = np.asarray(all_log_r_test_true).reshape((100, n_param_points_test))
nllr_test_true = np.asarray(nllr_test_true)

# %% [markdown]
# ## 5. Evaluation

# %% [markdown]
# It's time to evaluate our likelihood ratio estimators!

# %%
alice = ParameterizedRatioEstimator()
alice.load("models/alice")

log_r, _ = alice.evaluate(
    theta="data/theta_grid.npy",
    x="data/x_test.npy",
    evaluate_score=False,
)
print(log_r.shape)
nllr_test_alice = -2.0 * np.mean(log_r, axis=1)
mse_alice = np.mean((all_log_r_test_true - log_r) ** 2)
print("MSE:", mse_alice)
# Out:
# 14:26 madminer.ml.base     INFO    Loading model from models/alice
# 14:26 madminer.utils.vario INFO      Loading data/x_test.npy into RAM
# 14:26 madminer.utils.vario INFO      Loading data/theta_grid.npy into RAM
# (100, 1000)
# MSE: 0.41510972418169

# %%
repulsive_alice = RepulsiveEnsembleParameterizedRatioEstimator()
repulsive_alice.load("models/repulsive_alice")

log_r, _, log_r_std = repulsive_alice.evaluate(
    theta="data/theta_grid.npy",
    x="data/x_test.npy",
    evaluate_score=False,
)
print(log_r.shape)
nllr_test_repulsive_alice = -2.0 * np.mean(log_r, axis=1)
nllr_std_test_repulsive_alice = -2.0 * np.mean(log_r_std, axis=1)
mse_repulsive_alice = np.mean((all_log_r_test_true - log_r) ** 2)
print("MSE:", mse_repulsive_alice)
# Out:
# 14:26 madminer.ml.base     INFO    Loading model from models/repulsive_alice
# 14:26 madminer.utils.vario INFO      Loading data/x_test.npy into RAM
# 14:26 madminer.utils.vario INFO      Loading data/theta_grid.npy into RAM
# (100, 1000)
# MSE: 0.39724434231787503

# %%
bayesian_alice = BayesianParameterizedRatioEstimator()
bayesian_alice.load("models/bayesian_alice")

log_r, _, log_r_std = bayesian_alice.evaluate(
    theta="data/theta_grid.npy",
    x="data/x_test.npy",
    evaluate_score=False,
)
nllr_test_bayesian_alice = -2.0 * np.mean(log_r, axis=1)
nllr_std_test_bayesian_alice = -2.0 * np.mean(log_r_std, axis=1)
mse_bayesian_alice = np.mean((all_log_r_test_true - log_r) ** 2)
print("MSE:", mse_bayesian_alice)
# Out:
# 14:26 madminer.ml.base     INFO    Loading model from models/bayesian_alice
# 14:26 madminer.utils.vario INFO      Loading data/x_test.npy into RAM
# 14:26 madminer.utils.vario INFO      Loading data/theta_grid.npy into RAM
# MSE: 0.5145870275055938

# %% [markdown]
# This is the expected log likelihood ratio over parameter space:

# %%
best_fit_alice = float(theta_grid[np.argmin(nllr_test_alice)])
best_fit_bayesian_alice = float(theta_grid[np.argmin(nllr_test_bayesian_alice)])
# best_fit_bayesian_alice2 = float(theta_grid[np.argmin(nllr_test_bayesian_alice2)])

fig = plt.figure(figsize=(5, 5))

plt.plot(
    theta_grid,
    nllr_test_true,
    ls="--",
    c="black",
    label=r"Ground truth ($\theta = 1.0$)",
)
plt.plot(
    theta_grid,
    nllr_test_bayesian_alice,
    label=r"Bayesian ALICE ($\hat{\theta} = " + "{:.3f}$)".format(best_fit_bayesian_alice),
    color='orange',
    ls="--",
)
plt.fill_between(
    theta_grid.flatten(),
    nllr_test_bayesian_alice - nllr_std_test_bayesian_alice,
    nllr_test_bayesian_alice + nllr_std_test_bayesian_alice,
    color='orange',
    alpha=0.3,
)
# plt.plot(
#     theta_grid,
#     nllr_test_bayesian_alice2,
#     label=r"Bayesian ALICE2 ($\hat{\theta} = " + "{:.3f}$)".format(best_fit_bayesian_alice2),
#     color='yellowgreen',
#     ls="--",
# )
# plt.fill_between(
#     theta_grid.flatten(),
#     nllr_test_bayesian_alice2 - nllr_std_test_bayesian_alice2,
#     nllr_test_bayesian_alice2 + nllr_std_test_bayesian_alice2,
#     color='yellowgreen',
#     alpha=0.3,
# )

plt.xlabel(r"$\theta$")
plt.ylabel(r"$\mathbb{E}_x [ -2\, \log \,r(x | \theta, \theta_{1}) ]$")

plt.legend()
plt.tight_layout()
plt.show()

# %%
best_fit_alice = float(theta_grid[np.argmin(nllr_test_alice)])
best_fit_repulsive_alice = float(theta_grid[np.argmin(nllr_test_repulsive_alice)])
best_fit_bayesian_alice = float(theta_grid[np.argmin(nllr_test_bayesian_alice)])

fig = plt.figure(figsize=(5, 5))

plt.plot(
    theta_grid,
    nllr_test_true,
    ls="--",
    c="black",
    label=r"Ground truth ($\theta = 1.0$)",
)
plt.plot(
    theta_grid,
    nllr_test_alice,
    label=r"ALICE ($\hat{\theta} = " + "{:.3f}$)".format(best_fit_alice),
)
plt.plot(
    theta_grid,
    nllr_test_repulsive_alice,
    label=r"repulsive ALICE ($\hat{\theta} = " + "{:.3f}$)".format(best_fit_repulsive_alice),
    color='orange',
    ls="--",
)
plt.fill_between(
    theta_grid.flatten(),
    nllr_test_repulsive_alice - nllr_std_test_repulsive_alice,
    nllr_test_repulsive_alice + nllr_std_test_repulsive_alice,
    color='orange',
    alpha=0.3,
)
plt.plot(
    theta_grid,
    nllr_test_bayesian_alice,
    label=r"Bayesian ALICE ($\hat{\theta} = " + "{:.3f}$)".format(best_fit_bayesian_alice),
    color='yellowgreen',
    ls="--",
)
plt.fill_between(
    theta_grid.flatten(),
    nllr_test_bayesian_alice - nllr_std_test_bayesian_alice,
    nllr_test_bayesian_alice + nllr_std_test_bayesian_alice,
    color='yellowgreen',
    alpha=0.3,
)

plt.xlabel(r"$\theta$")
plt.ylabel(r"$\mathbb{E}_x [ -2\, \log \,r(x | \theta, \theta_{1}) ]$")

plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Coverage plots

# %%
repulsive_alice = RepulsiveEnsembleParameterizedRatioEstimator()
repulsive_alice.load("models/repulsive_alice")

# log_r, _, log_r_std = repulsive_alice.evaluate(
#     theta="data/theta_grid.npy",
#     x="data/x_test.npy",
#     evaluate_score=False,
# )
# print(log_r.shape)
# nllr_test_repulsive_alice = -2.0 * np.mean(log_r, axis=1)
# nllr_std_test_repulsive_alice = -2.0 * np.mean(log_r_std, axis=1)
# mse_repulsive_alice = np.mean((all_log_r_test_true - log_r) ** 2)
# print("MSE:", mse_repulsive_alice)
# Out:
# 14:52 madminer.ml.base     INFO    Loading model from models/repulsive_alice

# %%
from scipy.stats import chi2
from tqdm import tqdm

theta_range = np.linspace(-1, 1, 100)

def calc_confidence_interval(llr, alpha):
    pvalues = chi2.sf(llr, 1)
    # print(pvalues.shape)
    range_allowed = theta_range[pvalues > 1 - alpha]
    # print(range_allowed)
    if len(range_allowed) == 0:
        return 0, 0
    else:
        return range_allowed.min(), range_allowed.max()

def calc_emperical_coverage(alpha):
    res = []
    for i in range(10):
        sample = simulate(0, npoints=100)[0]
        
        log_r =  -2.0 * np.sum(repulsive_alice.evaluate(theta=theta_range, x=sample)[0], axis=1)
        log_r -= log_r.min()
        conf_interval = calc_confidence_interval(log_r, alpha)
        res.append([conf_interval[0] < 0 < conf_interval[1], conf_interval[0], conf_interval[1]])
        # print(conf_interval, conf_interval[0] < 0 < conf_interval[1])
    res = np.array(res)
    return [np.count_nonzero(res[:,0]) / len(res), res[:,1].mean(), res[:,2].mean(), res[:,1].std(), res[:,2].std()]

# %%
coverages = []
for alpha in tqdm(np.linspace(0, 1, 10)):
    cs = []
    for i in range(10):
        cs.append(calc_emperical_coverage(alpha))
    cs = np.array(cs)
    coverages.append([alpha, cs[:,0].mean(), cs[:,0].std()])
coverages = np.array(coverages)
# Out:
# 100%|██████████| 10/10 [02:59<00:00, 17.96s/it]

# %%
plt.errorbar(coverages[:, 0], coverages[:, 1], yerr=coverages[:, 2], fmt='o')
plt.plot([0, 1], [0, 1], c='r')
plt.axis('square')
plt.xlim(0, 1)
plt.ylim(0, 1)
plt.show()
