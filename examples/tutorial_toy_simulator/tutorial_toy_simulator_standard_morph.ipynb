# %% [markdown]
# # Toy example
#
# Original notebook by Alexander Held, edited for the MadMiner repository by Johann Brehmer, Irina Espejo, Felix Kling, and Kyle Cranmer 2018-2019.

# %% [markdown]
# In this notebook, we use a simple toy example to demonstrate the machine learning and inference algorithms in MadMiner. This allows us to skip many of the more technical steps, and there's no dependency on MadGraph, Pythia, or Delphes.
#
# What this tutorial does not do, is explaining the inference methods. To understand what's happening, please have a look at ["Constraining Effective Field Theories With Machine Learning"](https://arxiv.org/abs/1805.00013), which will explain the basic idea in just a few pages. If you really want to get down to the dirty details, ["A Guide to Constraining Effective Field Theories With Machine Learning"](https://arxiv.org/abs/1805.00020) has you covered.

# %% [markdown]
# ## Preparations

# %%
import os
import logging
import numpy as np
from scipy.stats import norm
from matplotlib import pyplot as plt

# %matplotlib inline
import sys
sys.path.append('/remote/gpu02/crescenzo/MadMiner')

from madminer.ml import ParameterizedRatioEstimator, MorphParameterizedRatioEstimator

# %%
if not os.path.exists("data_far_morph"):
    os.makedirs("data_far_morph")

# %% [markdown]
# MadMiner uses the Python `logging` module to provide additional information and debugging output. You can choose how much of this output you want to see by switching the level in the following lines to `logging.DEBUG` or `logging.WARNING`.

# %%
# MadMiner output
logging.basicConfig(
    format="%(asctime)-5.5s %(name)-20.20s %(levelname)-7.7s %(message)s",
    datefmt="%H:%M",
    level=logging.INFO,
)

# Output of all other modules (e.g. matplotlib)
for key in logging.Logger.manager.loggerDict:
    if "madminer" not in key:
        logging.getLogger(key).setLevel(logging.WARNING)

# %% [markdown]
# ## 1. A toy simulator

# %% [markdown]
# Our simulator depends on just one parameter `theta` and produces one-dimensional observables `x`. It is characterized by one latent variable `z`. "Running" the simulator consists of two steps:
# - "Hard process": a value of `z` is drawn from a normal distribution, where the mean depends on `theta`.
# - "Detector": a value for `x` is drawn from a normal distribution with mean equal to `z`. There is no explicit dependence on `theta`.
#
# As in the particle physics case, we assume that we can calculate the joint likelihood ratio `r(x, z | theta0, theta1)` as well as the joint score `t(x, z | theta)`, which depend explicitly on `z` (and where the "detector" part cancels).
#
# Here are some general settings (feel free to play with them):

# %%
z_std = 2.0
x_std = 1.0

# %% [markdown]
# The following function runs the simulator for a value of `theta` and calculates the joint likelihood ratio between `theta0` and `theta1` as well as the joint score at `theta_score`:

# %%
alpha=10

# %%
npoints = 100

# %%
theta = 100

# %%
z1 = np.random.normal(loc=0, scale=z_std, size=npoints)
z2 = np.random.normal(loc=alpha, scale=z_std, size=npoints)
mask = np.random.choice([True, False],p=[1./(1+theta**2),theta**2/(1+theta**2)],size=npoints)

# %%
z1[mask].flatten()
# Out:
# array([], dtype=float64)

# %%
np.concatenate((z1[mask],z2[~mask]))
# Out:
# array([ 8.40300489,  9.02765778,  8.40069442,  8.55395131, 11.64895736,
#         6.1477368 ,  9.23219659,  9.95915075, 13.43980835,  8.17232494,
#        10.58825117,  9.70046367, 12.37829532,  6.81415427, 12.26065021,
#         5.97605106, 10.18953118,  9.98317537, 11.79862296,  6.48418119,
#        13.61111984, 11.24477512, 15.04393638,  8.83358816, 11.04917886,
#         9.64610332, 11.3275578 , 13.306793  ,  4.86836705,  9.58180657,
#         8.4649634 ,  6.94925665,  8.62575895, 10.15708762, 10.6690816 ,
#         8.2584736 ,  8.62720956, 10.25327477,  5.69523319, 10.15022373,
#        10.66644285,  7.66929351,  2.15761645, 10.36528967,  9.17588839,
#        10.67488243, 13.06989629,  8.49717495, 11.17088603,  7.83124936,
#         9.93287438, 13.74948731,  8.87733017, 11.31943452,  9.45470113,
#        11.50551417, 10.53618965, 11.00337557,  8.34620716, 11.54188126,
#         9.88836649, 10.9231553 , 10.78178299, 10.12088865, 11.44646621,
#        12.99736534,  5.95682766, 10.6622211 , 11.32865443, 11.78212353,
#         9.04274532,  8.65138943, 11.90128269,  8.39722554,  9.64765554,
#         8.21942728,  8.26632453, 13.09393559, 15.78062935,  9.82424178,
#        12.63858739, 11.16493403,  9.28659063,  7.92603524, 14.02164224,
#        10.8012693 ,  6.25177328, 12.09015955, 12.70654978, 10.2770777 ,
#        10.25116128,  9.19781745, 10.57205918,  6.73684351, 10.11442671,
#        11.78949699, 10.72294149,  8.54857951,  7.20096137, 11.22532307])

# %%
np.random.choice([True,False],p = [0.5,0.5],size = None)
# Out:
# False

# %%
def simulate(theta, theta00=None, theta01=None, theta1=None, theta_score=None, npoints=None):
    # Draw latent variables z
    z1 = np.random.normal(loc=0, scale=z_std, size=npoints)
    z2 = np.random.normal(loc=alpha, scale=z_std, size=npoints)
    mask = np.random.choice([True, False],p=[1./(1+theta**2),theta**2/(1+theta**2)],size=npoints)
    try:
        z = np.concatenate((z1[mask],z2[~mask]))
    except:
        if mask:
            z = z1
        else:
            z = z2
    # Draw observables x
    x = np.random.normal(loc=z, scale=x_std, size=None)

    # Calculate joint likelihood ratio and joint score
    if theta00 is not None and theta01 is not None and theta1 is not None:
        r_xz1 = (norm(loc=theta1, scale=z_std).pdf(z)+(theta00**2)*norm(loc=alpha, scale=z_std).pdf(z) )/ ((1+theta00**2)*norm(loc=theta1, scale=z_std).pdf(z))
        r_xz2 = (norm(loc=theta1, scale=z_std).pdf(z)+(theta01**2)*norm(loc=alpha, scale=z_std).pdf(z) )/ ((1+theta01**2)*norm(loc=theta1, scale=z_std).pdf(z))
    else:
        r_xz1 = None
        r_xz2 = None

    if theta_score is not None:
        t_xz = (x - theta_score) / z_std**2
    else:
        t_xz = None

    return x, r_xz1, r_xz2, t_xz

# %% [markdown]
# Usually the likelihood function `p(x|theta)` is intractable, but in this toy example it is just given by the convolution of two Gaussians, which is again a Gaussian. We will use this to validate the results later:

# %%
def calculate_likelihood_ratio(x, theta0, theta1=0.0):
    combined_std = (z_std**2 + x_std**2) ** 0.5
    r_x = (norm(loc=theta1, scale=combined_std).pdf(x)+(theta0**2)*norm(loc=alpha, scale=combined_std).pdf(x) )/ ((1+theta0**2)*norm(loc=theta1, scale=combined_std).pdf(x))
    return r_x

# %% [markdown]
# Let's now visualize that: we run the simulation and plot the probability distributions $p(x | \theta_i)$. Additionally, we also plot the true log-likelihood ratio $\log\,r(x|\theta_0,\theta_1)$.

# %%
x0, _, _, _ = simulate(100, npoints=10000)
x1, _, _, _ = simulate(0, npoints=10000)

xr = np.linspace(-20.0, 300.0, 100)
rx = np.log(calculate_likelihood_ratio(xr, 100, 0))

fig, ax1 = plt.subplots()
fig.set_size_inches(5, 5)
ax1.set_xlabel("$x$")
ax1.hist(x0, bins=50, range=(-20, 20.0), histtype="step", label=r"$p(x | \theta_0)$", density=True)
ax1.hist(x1, bins=50, range=(-20, 20.0), histtype="step", label=r"$p(x | \theta_1)$", density=True)
ax1.set_ylabel(r"$p(x|\theta)$")
ax1.legend(loc=2)

ax2 = ax1.twinx()
ax2.plot(xr, rx, color="black", label=r"$\log\,r(x|\theta_0,\theta_1)$")
ax2.set_ylabel(r"$\log\,r(x|\theta_0,\theta_1)$")
ax2.legend(loc=1)

plt.show()
# Out:
# /tmp/ipykernel_2976625/413034781.py:3: RuntimeWarning: divide by zero encountered in divide
#   r_x = (norm(loc=theta1, scale=combined_std).pdf(x)+(theta0**2)*norm(loc=alpha, scale=combined_std).pdf(x) )/ ((1+theta0**2)*norm(loc=theta1, scale=combined_std).pdf(x))
# /tmp/ipykernel_2976625/413034781.py:3: RuntimeWarning: invalid value encountered in divide
#   r_x = (norm(loc=theta1, scale=combined_std).pdf(x)+(theta0**2)*norm(loc=alpha, scale=combined_std).pdf(x) )/ ((1+theta0**2)*norm(loc=theta1, scale=combined_std).pdf(x))

# %%
x0.shape
# Out:
# (10000,)

# %% [markdown]
# ## 2. Run the simulation and generate training data

# %% [markdown]
# First, we define the parameter points we want to use for training: `theta0` is uniformly distributed while the reference model `theta1` is fixed at zero.

# %%
# number of parameter points to train
n_param_points = 5000

# numerator, uniform prior
theta00 = np.ones(shape=n_param_points)*(-4)
theta01 = np.ones(shape=n_param_points)*0.
theta02 = np.ones(shape=n_param_points)*4

# %% [markdown]
# We then run the simulator (one sample per parameter point). Remember that `simulate(theta, theta0, theta1, theta_score)` generates data `x` following a theory with `theta` and then evaluates the joint likelihood ratio `r(x,z|theta0,theta1)` and the join score `t(x,z|theta_score)` for each data point.

# %%
# Sample from theta0
x_from_theta00 = []
r_xz_from_theta00 = []
t_xz_from_theta00 = []
x_from_theta01 = []
r_xz_from_theta001 = []
r_xz_from_theta002 = []
t_xz_from_theta01 = []
x_from_theta02 = []
r_xz_from_theta02 = []
t_xz_from_theta02 = []
for t in theta00:
    out = simulate(t, t, t, 0., t)
    x_from_theta00.append(out[0])
    r_xz_from_theta00.append(out[1])
print("Done first sim")
for t in theta01:
    out = simulate(t, -4, 4, 0., t)
    x_from_theta01.append(out[0])
    r_xz_from_theta001.append(out[1])
    r_xz_from_theta002.append(out[2])
    #t_xz_from_theta01.append(out[2])
print("Done first sim")
for t in theta02:
    out = simulate(t, t,t, 0., t)
    x_from_theta02.append(out[0])
    r_xz_from_theta02.append(out[2])
    #t_xz_from_theta02.append(out[2])
print("Done first sim")
# Out:
# Done first sim
# Done first sim
# Done first sim

# %%
r_xz_from_theta02
# Out:
# [2840.8833747670083,
#  160585.39855758278,
#  49583.46229839058,
#  1402859.7352437705,
#  10621975.20424206,
#  14008234838.45456,
#  0.05882411005877037,
#  2176738.718800204,
#  510703716.9919584,
#  161117.52595612034,
#  311640147.1571503,
#  358737.80840994423,
#  427715.60096062854,
#  19036.102589956678,
#  14047.929559044604,
#  2492.762696707014,
#  1168890.9558519654,
#  333508289.7787665,
#  12587.153324970639,
#  0.058832028372171975,
#  5319.349700506768,
#  261045.51323132304,
#  1887358.871205474,
#  33361794.69598693,
#  1009917.685890563,
#  5100.8449921515285,
#  108582519.93471265,
#  74426.17218703122,
#  2844.9123432592655,
#  71420.3362609101,
#  50191737.788025916,
#  237.5783543791511,
#  196.95018081220255,
#  52473.88494276785,
#  50679.5159537208,
#  16442194167.193401,
#  ...]

# %% [markdown]
# Now we combine and reshape the results (nothing interesting happening here) and save everything to files, so that we can load it later.

# %%
plt.hist(x_from_theta02)
# Out:
# (array([  28.,   82.,  107.,   91.,  303., 1283., 1867., 1029.,  196.,
#           14.]),
#  array([-5.1180113 , -2.75673045, -0.3954496 ,  1.96583125,  4.3271121 ,
#          6.68839295,  9.04967381, 11.41095466, 13.77223551, 16.13351636,
#         18.49479721]),
#  <BarContainer object of 10 artists>)

# %%
# Combine results and reshape
x_train0 = np.hstack((x_from_theta00, x_from_theta01)).reshape(-1, 1)
x_train1 = np.hstack((x_from_theta02, x_from_theta01)).reshape(-1, 1)
r_xz_train0 = np.hstack((r_xz_from_theta00, r_xz_from_theta001)).reshape(-1, 1)
r_xz_train1 = np.hstack((r_xz_from_theta02, r_xz_from_theta002)).reshape(-1, 1)
#t_xz_train0 = np.hstack((t_xz_from_theta0, t_xz_from_theta1)).reshape(-1, 1)
y_train0 = np.hstack((np.zeros_like(x_from_theta00), np.ones_like(np.ones_like(x_from_theta01)))).reshape(-1, 1)
y_train1 = np.hstack((np.zeros_like(x_from_theta02), np.ones_like(np.ones_like(x_from_theta01)))).reshape(-1, 1)
#theta0_train = np.hstack((theta0, theta0)).reshape(-1, 1)

# Save to file
#np.save("data/theta0_train.npy", theta0_train)
shuf = np.random.permutation(np.shape(x_train0)[0])
np.save("data_far_morph/x_train0.npy", x_train0[shuf])
np.save("data_far_morph/x_train1.npy", x_train1[shuf])
np.save("data_far_morph/y_train0.npy", y_train0[shuf])
np.save("data_far_morph/y_train1.npy", y_train1[shuf])
np.save("data_far_morph/r_xz_train0.npy", r_xz_train0[shuf])
np.save("data_far_morph/r_xz_train1.npy", r_xz_train1[shuf])
#np.save("data/t_xz_train.npy", t_xz_train)

# %%
plt.plot(r_xz_train0)

# %%
r_xz_train0
# Out:
# array([[3.99732148e+04],
#        [6.96912064e+05],
#        [1.57088999e+05],
#        ...,
#        [5.88235301e-02],
#        [5.88335751e-02],
#        [5.88283355e-02]])

# %%
np.shape(x_train0)[0]
# Out:
# 10000

# %% [markdown]
# ## 3. Model training

# %% [markdown]
# Let's train two neural networks to estimate the likelihood ratio. For one we use the CARL method introduced in ["Approximating Likelihood Ratios with Calibrated Discriminative Classifiers"](https://arxiv.org/abs/1506.02169), for the other the new ALICES method introduced in ["Likelihood-free inference with an improved cross-entropy estimator"](https://arxiv.org/abs/1808.00973).

# %%
"""nn = MorphParameterizedRatioEstimator(n_hidden=(20, 20))

loss = nn.train(
    method="carl",
    x="data_far_morph/x_train0.npy",
    y="data_far_morph/y_train0.npy",
    n_epochs=20,
)

nn.save("models_far_morph/carl0")"""
# Out:
# 'nn = MorphParameterizedRatioEstimator(n_hidden=(20, 20))\n\nloss = nn.train(\n    method="carl",\n    x="data_far_morph/x_train0.npy",\n    y="data_far_morph/y_train0.npy",\n    n_epochs=20,\n)\n\nnn.save("models_far_morph/carl0")'

# %%
nn = MorphParameterizedRatioEstimator(n_hidden=(20, 20))

loss = nn.train(
    method="alice",
    x="data_far_morph/x_train0.npy",
    y="data_far_morph/y_train0.npy",
    r_xz="data_far_morph/r_xz_train0.npy",
    n_epochs=20,
)

nn.save("models_far_morph/alice0")
# Out:
# 15:01 madminer.ml.paramete INFO    Starting training
# 15:01 madminer.ml.paramete INFO      Method:                 alice
# 15:01 madminer.ml.paramete INFO      Batch size:             128
# 15:01 madminer.ml.paramete INFO      Optimizer:              amsgrad
# 15:01 madminer.ml.paramete INFO      Epochs:                 20
# 15:01 madminer.ml.paramete INFO      Learning rate:          0.001 initially, decaying to 0.0001
# 15:01 madminer.ml.paramete INFO      Validation split:       0.25
# 15:01 madminer.ml.paramete INFO      Early stopping:         True
# 15:01 madminer.ml.paramete INFO      Scale inputs:           True
# 15:01 madminer.ml.paramete INFO      Scale parameters:       True
# 15:01 madminer.ml.paramete INFO      Shuffle labels          False
# 15:01 madminer.ml.paramete INFO      Samples:                all
# 15:01 madminer.ml.paramete INFO    Loading training data
# 15:01 madminer.utils.vario INFO      Loading data_far_morph/x_train0.npy into RAM
# 15:01 madminer.utils.vario INFO      Loading data_far_morph/y_train0.npy into RAM
# 15:01 madminer.utils.vario INFO      Loading data_far_morph/r_xz_train0.npy into RAM
# 15:01 madminer.utils.vario WARNING Warning: file data_far_morph/r_xz_train0.npy has some large numbers, ranging from 0.05882352941177471 to 5763732989518.9795
# 15:01 madminer.ml.paramete INFO    Found 10000 samples with 1 observables
# 15:01 madminer.ml.base     INFO    Setting up input rescaling
# 15:01 madminer.ml.paramete INFO    Creating model
# 15:01 madminer.ml.paramete INFO    Training model
# 15:01 madminer.utils.ml.tr INFO    Training on CPU with single precision
# 15:01 madminer.utils.ml.tr INFO      Epoch   1: train loss  0.61639 (improved_xe:  0.616)
# 15:01 madminer.utils.ml.tr INFO                 val. loss   0.37178 (improved_xe:  0.372)
# 15:01 madminer.utils.ml.tr INFO      Epoch   2: train loss  0.23137 (improved_xe:  0.231)
# 15:01 madminer.utils.ml.tr INFO                 val. loss   0.13247 (improved_xe:  0.132)
# 15:01 madminer.utils.ml.tr INFO      Epoch   3: train loss  0.09403 (improved_xe:  0.094)
# 15:01 madminer.utils.ml.tr INFO                 val. loss   0.06801 (improved_xe:  0.068)
# 15:01 madminer.utils.ml.tr INFO      Epoch   4: train loss  0.05448 (improved_xe:  0.054)
# 15:01 madminer.utils.ml.tr INFO      Epoch  20: train loss  0.01472 (improved_xe:  0.015)
# 15:01 madminer.utils.ml.tr INFO                 val. loss   0.01553 (improved_xe:  0.016)
# 15:01 madminer.utils.ml.tr INFO    Early stopping did not improve performance
# 15:01 madminer.utils.ml.tr INFO    Training time spend on:
# 15:01 madminer.utils.ml.tr INFO                      initialize model:   0.00h
# 15:01 madminer.utils.ml.tr INFO                                   ALL:   0.00h
# 15:01 madminer.utils.ml.tr INFO                            check data:   0.00h
# 15:01 madminer.utils.ml.tr INFO                          make dataset:   0.00h
# 15:01 madminer.utils.ml.tr INFO                       make dataloader:   0.00h
# 15:01 madminer.utils.ml.tr INFO                       setup optimizer:   0.00h
# 15:01 madminer.utils.ml.tr INFO                   initialize training:   0.00h
# 15:01 madminer.utils.ml.tr INFO                                set lr:   0.00h
# 15:01 madminer.utils.ml.tr INFO                   load training batch:   0.00h
# 15:01 madminer.utils.ml.tr INFO                        fwd: move data:   0.00h
# 15:01 madminer.utils.ml.tr INFO                   fwd: check for nans:   0.00h
# 15:01 madminer.utils.ml.tr INFO                    fwd: model.forward:   0.00h
# 15:01 madminer.utils.ml.tr INFO                 fwd: calculate losses:   0.00h
# 15:01 madminer.utils.ml.tr INFO                 training forward pass:   0.00h
# 15:01 madminer.utils.ml.tr INFO                   training sum losses:   0.00h
# 15:01 madminer.utils.ml.tr INFO                        opt: zero grad:   0.00h
# 15:01 madminer.utils.ml.tr INFO                         opt: backward:   0.00h
# 15:01 madminer.utils.ml.tr INFO                   opt: clip grad norm:   0.00h
# 15:01 madminer.utils.ml.tr INFO                             opt: step:   0.00h
# 15:01 madminer.utils.ml.tr INFO                        optimizer step:   0.00h
# 15:01 madminer.utils.ml.tr INFO                 load validation batch:   0.00h
# 15:01 madminer.utils.ml.tr INFO               validation forward pass:   0.00h
# 15:01 madminer.utils.ml.tr INFO                 validation sum losses:   0.00h
# 15:01 madminer.utils.ml.tr INFO                        early stopping:   0.00h
# 15:01 madminer.utils.ml.tr INFO                          report epoch:   0.00h
# 15:01 madminer.ml.base     INFO    Saving model to models_far_morph/alice0

# %%
plt.plot(loss[0])
plt.plot(loss[1])

# %%
"""nn = MorphParameterizedRatioEstimator(n_hidden=(20, 20))

loss = nn.train(
    method="carl",
    x="data_far_morph/x_train1.npy",
    y="data_far_morph/y_train1.npy",
    n_epochs=20,
)

nn.save("models_far_morph/carl1")"""
# Out:
# 'nn = MorphParameterizedRatioEstimator(n_hidden=(20, 20))\n\nloss = nn.train(\n    method="carl",\n    x="data_far_morph/x_train1.npy",\n    y="data_far_morph/y_train1.npy",\n    n_epochs=20,\n)\n\nnn.save("models_far_morph/carl1")'

# %%
nn = MorphParameterizedRatioEstimator(n_hidden=(20, 20))

loss = nn.train(
    method="alice",
    x="data_far_morph/x_train1.npy",
    y="data_far_morph/y_train1.npy",
    r_xz="data_far_morph/r_xz_train1.npy",
    n_epochs=20,
)

nn.save("models_far_morph/alice1")
# Out:
# 15:01 madminer.ml.paramete INFO    Starting training
# 15:01 madminer.ml.paramete INFO      Method:                 alice
# 15:01 madminer.ml.paramete INFO      Batch size:             128
# 15:01 madminer.ml.paramete INFO      Optimizer:              amsgrad
# 15:01 madminer.ml.paramete INFO      Epochs:                 20
# 15:01 madminer.ml.paramete INFO      Learning rate:          0.001 initially, decaying to 0.0001
# 15:01 madminer.ml.paramete INFO      Validation split:       0.25
# 15:01 madminer.ml.paramete INFO      Early stopping:         True
# 15:01 madminer.ml.paramete INFO      Scale inputs:           True
# 15:01 madminer.ml.paramete INFO      Scale parameters:       True
# 15:01 madminer.ml.paramete INFO      Shuffle labels          False
# 15:01 madminer.ml.paramete INFO      Samples:                all
# 15:01 madminer.ml.paramete INFO    Loading training data
# 15:01 madminer.utils.vario INFO      Loading data_far_morph/x_train1.npy into RAM
# 15:01 madminer.utils.vario INFO      Loading data_far_morph/y_train1.npy into RAM
# 15:01 madminer.utils.vario INFO      Loading data_far_morph/r_xz_train1.npy into RAM
# 15:01 madminer.utils.vario WARNING Warning: file data_far_morph/r_xz_train1.npy has some large numbers, ranging from 0.05882352941177471 to 54782650023060.59
# 15:01 madminer.ml.paramete INFO    Found 10000 samples with 1 observables
# 15:01 madminer.ml.base     INFO    Setting up input rescaling
# 15:01 madminer.ml.paramete INFO    Creating model
# 15:01 madminer.ml.paramete INFO    Training model
# 15:01 madminer.utils.ml.tr INFO    Training on CPU with single precision
# 15:01 madminer.utils.ml.tr INFO      Epoch   1: train loss  0.45105 (improved_xe:  0.451)
# 15:01 madminer.utils.ml.tr INFO                 val. loss   0.25118 (improved_xe:  0.251)
# 15:01 madminer.utils.ml.tr INFO      Epoch   2: train loss  0.15974 (improved_xe:  0.160)
# 15:01 madminer.utils.ml.tr INFO                 val. loss   0.09362 (improved_xe:  0.094)
# 15:01 madminer.utils.ml.tr INFO      Epoch   3: train loss  0.06905 (improved_xe:  0.069)
# 15:01 madminer.utils.ml.tr INFO                 val. loss   0.04966 (improved_xe:  0.050)
# 15:01 madminer.utils.ml.tr INFO      Epoch   4: train loss  0.04103 (improved_xe:  0.041)
# 15:01 madminer.utils.ml.tr INFO                 val. loss   0.03304 (improved_xe:  0.033)
# 15:01 madminer.utils.ml.tr INFO      Epoch   5: train loss  0.02915 (improved_xe:  0.029)
# 15:01 madminer.utils.ml.tr INFO                 val. loss   0.02493 (improved_xe:  0.025)
# 15:01 madminer.utils.ml.tr INFO      Epoch   6: train loss  0.02291 (improved_xe:  0.023)
# 15:01 madminer.utils.ml.tr INFO                 val. loss   0.02027 (improved_xe:  0.020)
# 15:01 madminer.utils.ml.tr INFO      Epoch   7: train loss  0.01917 (improved_xe:  0.019)
# 15:01 madminer.utils.ml.tr INFO                 val. loss   0.01733 (improved_xe:  0.017)
# 15:01 madminer.utils.ml.tr INFO      Epoch   8: train loss  0.01674 (improved_xe:  0.017)
# 15:01 madminer.utils.ml.tr INFO                 val. loss   0.01537 (improved_xe:  0.015)
# 15:01 madminer.utils.ml.tr INFO      Epoch   9: train loss  0.01508 (improved_xe:  0.015)
# 15:01 madminer.utils.ml.tr INFO                 val. loss   0.01390 (improved_xe:  0.014)
# 15:01 madminer.utils.ml.tr INFO      Epoch  10: train loss  0.01382 (improved_xe:  0.014)
# 15:01 madminer.utils.ml.tr INFO                 val. loss   0.01290 (improved_xe:  0.013)
# 15:01 madminer.utils.ml.tr INFO      Epoch  11: train loss  0.01290 (improved_xe:  0.013)
# 15:01 madminer.utils.ml.tr INFO                 val. loss   0.01209 (improved_xe:  0.012)
# 15:01 madminer.utils.ml.tr INFO      Epoch  12: train loss  0.01220 (improved_xe:  0.012)
# 15:01 madminer.utils.ml.tr INFO                 val. loss   0.01144 (improved_xe:  0.011)
# 15:01 madminer.utils.ml.tr INFO      Epoch  13: train loss  0.01163 (improved_xe:  0.012)
# 15:01 madminer.utils.ml.tr INFO                 val. loss   0.01095 (improved_xe:  0.011)
# 15:01 madminer.utils.ml.tr INFO      Epoch  14: train loss  0.01119 (improved_xe:  0.011)
# 15:01 madminer.utils.ml.tr INFO                 val. loss   0.01064 (improved_xe:  0.011)
# 15:01 madminer.utils.ml.tr INFO      Epoch  15: train loss  0.01082 (improved_xe:  0.011)
# 15:01 madminer.utils.ml.tr INFO                 val. loss   0.01022 (improved_xe:  0.010)
# 15:01 madminer.utils.ml.tr INFO      Epoch  16: train loss  0.01053 (improved_xe:  0.011)
# 15:01 madminer.utils.ml.tr INFO                 val. loss   0.00994 (improved_xe:  0.010)
# 15:01 madminer.utils.ml.tr INFO      Epoch  17: train loss  0.01026 (improved_xe:  0.010)
# 15:01 madminer.utils.ml.tr INFO                 val. loss   0.00972 (improved_xe:  0.010)
# 15:01 madminer.utils.ml.tr INFO      Epoch  18: train loss  0.01007 (improved_xe:  0.010)
# 15:01 madminer.utils.ml.tr INFO                 val. loss   0.00953 (improved_xe:  0.010)
# 15:01 madminer.utils.ml.tr INFO      Epoch  19: train loss  0.00987 (improved_xe:  0.010)
# 15:01 madminer.utils.ml.tr INFO                 val. loss   0.00934 (improved_xe:  0.009)
# 15:01 madminer.utils.ml.tr INFO      Epoch  20: train loss  0.00972 (improved_xe:  0.010)
# 15:01 madminer.utils.ml.tr INFO                 val. loss   0.00919 (improved_xe:  0.009)
# 15:01 madminer.utils.ml.tr INFO    Early stopping did not improve performance
# 15:01 madminer.utils.ml.tr INFO    Training time spend on:
# 15:01 madminer.utils.ml.tr INFO                      initialize model:   0.00h
# 15:01 madminer.utils.ml.tr INFO                                   ALL:   0.00h
# 15:01 madminer.utils.ml.tr INFO                            check data:   0.00h
# 15:01 madminer.utils.ml.tr INFO                          make dataset:   0.00h
# 15:01 madminer.utils.ml.tr INFO                       make dataloader:   0.00h
# 15:01 madminer.utils.ml.tr INFO                       setup optimizer:   0.00h
# 15:01 madminer.utils.ml.tr INFO                   initialize training:   0.00h
# 15:01 madminer.utils.ml.tr INFO                                set lr:   0.00h
# 15:01 madminer.utils.ml.tr INFO                   load training batch:   0.00h
# 15:01 madminer.utils.ml.tr INFO                        fwd: move data:   0.00h
# 15:01 madminer.utils.ml.tr INFO                   fwd: check for nans:   0.00h
# 15:01 madminer.utils.ml.tr INFO                    fwd: model.forward:   0.00h
# 15:01 madminer.utils.ml.tr INFO                 fwd: calculate losses:   0.00h
# 15:01 madminer.utils.ml.tr INFO                 training forward pass:   0.00h
# 15:01 madminer.utils.ml.tr INFO                   training sum losses:   0.00h
# 15:01 madminer.utils.ml.tr INFO                        opt: zero grad:   0.00h
# 15:01 madminer.utils.ml.tr INFO                         opt: backward:   0.00h
# 15:01 madminer.utils.ml.tr INFO                   opt: clip grad norm:   0.00h
# 15:01 madminer.utils.ml.tr INFO                             opt: step:   0.00h
# 15:01 madminer.utils.ml.tr INFO                        optimizer step:   0.00h
# 15:01 madminer.utils.ml.tr INFO                 load validation batch:   0.00h
# 15:01 madminer.utils.ml.tr INFO               validation forward pass:   0.00h
# 15:01 madminer.utils.ml.tr INFO                 validation sum losses:   0.00h
# 15:01 madminer.utils.ml.tr INFO                        early stopping:   0.00h
# 15:01 madminer.utils.ml.tr INFO                          report epoch:   0.00h
# 15:01 madminer.ml.base     INFO    Saving model to models_far_morph/alice1

# %%
plt.plot(loss[0])
plt.plot(loss[1])

# %%
np.exp(nn.evaluate_log_likelihood_ratio(np.asarray([10,20,30])).detach().numpy())
# Out:
# array([[0.00721299],
#        [0.01972148],
#        [0.05844095]], dtype=float32)

# %% [markdown]
# ## 4. Generate evaluation data

# %% [markdown]
# Let us now generate some test data, which is sampled corresponding to `theta=1`

# %%
n_param_points_test = 1000  # number of parameter points to test
theta_test = 1.0 * np.ones(shape=n_param_points_test)

# %% [markdown]
# Run the simulator to get observations:

# %%
x_test = []
for t in theta_test:
    x_test.append(simulate(t)[0])
np.save("data_far_morph/x_test.npy", x_test)

# %% [markdown]
# We want to evaluate the expected likelihood ratio on a range of parameter points:

# %%
theta_grid = np.linspace(-5.0, 5.0, 1000).reshape(-1, 1)
np.save("data_far_morph/theta_grid.npy", theta_grid)

# %% [markdown]
# In this toy example, we can calculate the true likelihood ratio. We will save the expected log likelihood ratio (multiplied with a conventional factor of -2):

# %%
all_log_r_test_true = []
nllr_test_true = []

for theta in theta_grid:
    log_r = np.log(calculate_likelihood_ratio(x_test, theta))
    nllr_test_true.append(-2.0 * np.mean(log_r))
    all_log_r_test_true.append(log_r)

all_log_r_test_true = np.asarray(all_log_r_test_true).reshape((1000, n_param_points_test))
nllr_test_true = np.asarray(nllr_test_true)

# %% [markdown]
# ## 5. Evaluation

# %% [markdown]
# It's time to evaluate our likelihood ratio estimators!

# %%
x_test
# Out:
# [14.442187474146142,
#  7.324053834543883,
#  10.501485355821647,
#  13.395279741083051,
#  11.017474281092573,
#  11.736983932656159,
#  14.18389989089411,
#  8.743921753996004,
#  2.1408832782511755,
#  8.69130737333199,
#  0.6666176829762869,
#  6.4670338864068375,
#  5.293793450301735,
#  -3.7532687340622686,
#  8.069300437820802,
#  -0.8000641777082832,
#  0.604004785643057,
#  12.682691357636743,
#  1.2137661359352148,
#  1.8897830098080273,
#  10.602341925768462,
#  -2.1765883876254177,
#  13.092462436737247,
#  0.5815706186212037,
#  0.11316014224305415,
#  0.25748898915564855,
#  0.009420247041488694,
#  11.56612433126111,
#  0.9913476387625667,
#  9.138496710311676,
#  7.224250012398468,
#  9.328689193509382,
#  8.537535326128635,
#  9.335166390618673,
#  1.5531031527426564,
#  -2.7148273957837348,
#  12.370873324346263,
#  11.65725171732994,
#  0.7006092997347408,
#  8.837295815509126,
#  -1.0571056297716437,
#  14.098226156713187,
#  6.50016408087365,
#  -3.307071146759719,
#  -0.7530162894810443,
#  1.9763851801534855,
#  -1.1169537710151844,
#  3.3134501395097056,
#  9.653080245981341,
#  7.584802285855495,
#  13.91773533865705,
#  10.431414272169235,
#  8.688124408101796,
#  -3.2339395501829213,
#  0.26074446036304155,
#  13.159588357449106,
#  7.981589992307566,
#  -0.36084135045932453,
#  13.063572860652396,
#  8.002387348493809,
#  6.838328822399162,
#  -1.1372423042943223,
#  0.1520928846666334,
#  12.070161015682745,
#  -1.2641427564246976,
#  -0.3800552642654398,
#  8.865424372572797,
#  2.5784900204972936,
#  -0.7943606817502669,
#  11.045395483988111]

# %%
np.max(r_xz_train0)
# Out:
# 5763732989518.9795

# %%
loader1 = MorphParameterizedRatioEstimator(n_hidden=(20, 20))
loader2 = MorphParameterizedRatioEstimator(n_hidden=(20, 20))
loader_alice1 = MorphParameterizedRatioEstimator(n_hidden=(20, 20))
loader_alice2 = MorphParameterizedRatioEstimator(n_hidden=(20, 20))
loader1.load("models_far_morph/carl0")
loader2.load("models_far_morph/carl1")
loader_alice1.load("models_far_morph/alice0")
loader_alice2.load("models_far_morph/alice1")

ratio_1 = (np.exp(loader1.evaluate_log_likelihood_ratio(np.asarray(x_test)).detach().numpy()))
ratio_2 = (np.exp(loader2.evaluate_log_likelihood_ratio(np.asarray(x_test)).detach().numpy()))
ratio_alice1 = (np.exp(loader_alice1.evaluate_log_likelihood_ratio(np.asarray(x_test)).detach().numpy()))
ratio_alice2 = (np.exp(loader_alice2.evaluate_log_likelihood_ratio(np.asarray(x_test)).detach().numpy()))
# Out:
# 15:07 madminer.ml.base     INFO    Loading model from models_far_morph/carl0
# 15:07 madminer.ml.base     WARNING Parameter scaling information not found in models_far_morph/carl0
# 15:07 madminer.ml.base     INFO    Loading model from models_far_morph/carl1
# 15:07 madminer.ml.base     WARNING Parameter scaling information not found in models_far_morph/carl1
# 15:07 madminer.ml.base     INFO    Loading model from models_far_morph/alice0
# 15:07 madminer.ml.base     WARNING Parameter scaling information not found in models_far_morph/alice0
# 15:07 madminer.ml.base     INFO    Loading model from models_far_morph/alice1
# 15:07 madminer.ml.base     WARNING Parameter scaling information not found in models_far_morph/alice1

# %%
def ratio(ratios1,ratios2,theta,th0,th1):
    matrix = [[1,0,0],
              [1./(1.+th0**2),th0/(1.+th0**2),th0**2/(1.+th0**2)],
              [1./(1.+th1**2),th1/(1.+th1**2),th1**2/(1.+th1**2)]]
    arr = np.asarray([1/(1+theta**2),theta/(1+theta**2),theta**2/(1+theta**2)])
    sh = np.shape(ratios1)[0]
    #print(sh)
    return arr@np.linalg.inv(matrix)@np.asarray([np.ones(sh),ratios1.flatten(),ratios2.flatten()])

# %%
theta_grid
# Out:
# array([[-5.        ],
#        [-4.98998999],
#        [-4.97997998],
#        [-4.96996997],
#        [-4.95995996],
#        [-4.94994995],
#        [-4.93993994],
#        [-4.92992993],
#        [-4.91991992],
#        [-4.90990991],
#        [-4.8998999 ],
#        [-4.88988989],
#        [-4.87987988],
#        [-4.86986987],
#        [-4.85985986],
#        [-4.84984985],
#        [-4.83983984],
#        [-4.82982983],
#        [-4.81981982],
#        [-4.80980981],
#        [-4.7997998 ],
#        [-4.78978979],
#        [-4.77977978],
#        [-4.76976977],
#        [-4.75975976],
#        [-4.74974975],
#        [-4.73973974],
#        [-4.72972973],
#        [-4.71971972],
#        [-4.70970971],
#        [-4.6996997 ],
#        [-4.68968969],
#        [-4.67967968],
#        [-4.66966967],
#        [-4.65965966],
#        [-4.64964965],
#        [-4.63963964],
#        [-4.62962963],
#        [-4.61961962],
#        [-4.60960961],
#        [-4.5995996 ],
#        [-4.58958959],
#        [-4.57957958],
#        [-4.56956957],
#        [-4.55955956],
#        [-4.54954955],
#        [-4.53953954],
#        [-4.52952953],
#        [-4.51951952],
#        [-4.50950951],
#        [-4.4994995 ],
#        [-4.48948949],
#        [-4.47947948],
#        [-4.46946947],
#        [-4.45945946],
#        [-4.44944945],
#        [-4.43943944],
#        [-4.42942943],
#        [-4.41941942],
#        [-4.40940941],
#        [-4.3993994 ],
#        [-4.38938939],
#        [-4.37937938],
#        [-4.36936937],
#        [-4.35935936],
#        [-4.34934935],
#        [-4.33933934],
#        [-4.32932933],
#        [-4.31931932],
#        [-4.30930931],
#        [-4.2992993 ],
#        [-4.28928929],
#        [-4.27927928],
#        [-4.26926927],
#        [-4.25925926],
#        [-4.24924925],
#        [-4.23923924],
#        [-4.22922923],
#        [-4.21921922],
#        [-4.20920921],
#        [-4.1991992 ],
#        [-4.18918919],
#        [-4.17917918],
#        [-4.16916917],
#        [-4.15915916],
#        [-4.14914915],
#        [-4.13913914],
#        [-4.12912913],
#        [-4.11911912],
#        [-4.10910911],
#        [-4.0990991 ],
#        [-4.08908909],
#        [-4.07907908],
#        [-4.06906907],
#        [-4.05905906],
#        [-4.04904905],
#        [-4.03903904],
#        [-4.02902903],
#        [-4.01901902],
#        [-4.00900901],
#        [-3.998999  ],
#        [-3.98898899],
#        [-3.97897898],
#        [-3.96896897],
#        [-3.95895896],
#        [-3.94894895],
#        [-3.93893894],
#        [-3.92892893],
#        [-3.91891892],
#        [-3.90890891],
#        [-3.8988989 ],
#        [-3.88888889],
#        [-3.87887888],
#        [-3.86886887],
#        [-3.85885886],
#        [-3.84884885],
#        [-3.83883884],
#        [-3.82882883],
#        [-3.81881882],
#        [-3.80880881],
#        [-3.7987988 ],
#        [-3.78878879],
#        [-3.77877878],
#        [-3.76876877],
#        [-3.75875876],
#        [-3.74874875],
#        [-3.73873874],
#        [-3.72872873],
#        [-3.71871872],
#        [-3.70870871],
#        [-3.6986987 ],
#        [-3.68868869],
#        [-3.67867868],
#        [-3.66866867],
#        [-3.65865866],
#        [-3.64864865],
#        [-3.63863864],
#        [-3.62862863],
#        [-3.61861862],
#        [-3.60860861],
#        [-3.5985986 ],
#        [-3.58858859],
#        [-3.57857858],
#        [-3.56856857],
#        [-3.55855856],
#        [-3.54854855],
#        [-3.53853854],
#        [-3.52852853],
#        [-3.51851852],
#        [-3.50850851],
#        [-3.4984985 ],
#        [-3.48848849],
#        [-3.47847848],
#        [-3.46846847],
#        [-3.45845846],
#        [-3.44844845],
#        [-3.43843844],
#        [-3.42842843],
#        [-3.41841842],
#        [-3.40840841],
#        [-3.3983984 ],
#        [-3.38838839],
#        [-3.37837838],
#        [-3.36836837],
#        [-3.35835836],
#        [-3.34834835],
#        [-3.33833834],
#        [-3.32832833],
#        [-3.31831832],
#        [-3.30830831],
#        [-3.2982983 ],
#        [-3.28828829],
#        [-3.27827828],
#        [-3.26826827],
#        [-3.25825826],
#        [-3.24824825],
#        [-3.23823824],
#        [-3.22822823],
#        [-3.21821822],
#        [-3.20820821],
#        [-3.1981982 ],
#        [-3.18818819],
#        [-3.17817818],
#        [-3.16816817],
#        [-3.15815816],
#        [-3.14814815],
#        [-3.13813814],
#        [-3.12812813],
#        [-3.11811812],
#        [-3.10810811],
#        [-3.0980981 ],
#        [-3.08808809],
#        [-3.07807808],
#        [-3.06806807],
#        [-3.05805806],
#        [-3.04804805],
#        [-3.03803804],
#        [-3.02802803],
#        [-3.01801802],
#        [-3.00800801],
#        [-2.997998  ],
#        [-2.98798799],
#        [-2.97797798],
#        [-2.96796797],
#        [-2.95795796],
#        [-2.94794795],
#        [-2.93793794],
#        [-2.92792793],
#        [-2.91791792],
#        [-2.90790791],
#        [-2.8978979 ],
#        [-2.88788789],
#        [-2.87787788],
#        [-2.86786787],
#        [-2.85785786],
#        [-2.84784785],
#        [-2.83783784],
#        [-2.82782783],
#        [-2.81781782],
#        [-2.80780781],
#        [-2.7977978 ],
#        [-2.78778779],
#        [-2.77777778],
#        [-2.76776777],
#        [-2.75775776],
#        [-2.74774775],
#        [-2.73773774],
#        [-2.72772773],
#        [-2.71771772],
#        [-2.70770771],
#        [-2.6976977 ],
#        [-2.68768769],
#        [-2.67767768],
#        [-2.66766767],
#        [-2.65765766],
#        [-2.64764765],
#        [-2.63763764],
#        [-2.62762763],
#        [-2.61761762],
#        [-2.60760761],
#        [-2.5975976 ],
#        [-2.58758759],
#        [-2.57757758],
#        [-2.56756757],
#        [-2.55755756],
#        [-2.54754755],
#        [-2.53753754],
#        [-2.52752753],
#        [-2.51751752],
#        [-2.50750751],
#        [-2.4974975 ],
#        [-2.48748749],
#        [-2.47747748],
#        [-2.46746747],
#        [-2.45745746],
#        [-2.44744745],
#        [-2.43743744],
#        [-2.42742743],
#        [-2.41741742],
#        [-2.40740741],
#        [-2.3973974 ],
#        [-2.38738739],
#        [-2.37737738],
#        [-2.36736737],
#        [-2.35735736],
#        [-2.34734735],
#        [-2.33733734],
#        [-2.32732733],
#        [-2.31731732],
#        [-2.30730731],
#        [-2.2972973 ],
#        [-2.28728729],
#        [-2.27727728],
#        [-2.26726727],
#        [-2.25725726],
#        [-2.24724725],
#        [-2.23723724],
#        [-2.22722723],
#        [-2.21721722],
#        [-2.20720721],
#        [-2.1971972 ],
#        [-2.18718719],
#        [-2.17717718],
#        [-2.16716717],
#        [-2.15715716],
#        [-2.14714715],
#        [-2.13713714],
#        [-2.12712713],
#        [-2.11711712],
#        [-2.10710711],
#        [-2.0970971 ],
#        [-2.08708709],
#        [-2.07707708],
#        [-2.06706707],
#        [-2.05705706],
#        [-2.04704705],
#        [-2.03703704],
#        [-2.02702703],
#        [-2.01701702],
#        [-2.00700701],
#        [-1.996997  ],
#        [-1.98698699],
#        [-1.97697698],
#        [-1.96696697],
#        [-1.95695696],
#        [-1.94694695],
#        [-1.93693694],
#        [-1.92692693],
#        [-1.91691692],
#        [-1.90690691],
#        [-1.8968969 ],
#        [-1.88688689],
#        [-1.87687688],
#        [-1.86686687],
#        [-1.85685686],
#        [-1.84684685],
#        [-1.83683684],
#        [-1.82682683],
#        [-1.81681682],
#        [-1.80680681],
#        [-1.7967968 ],
#        [-1.78678679],
#        [-1.77677678],
#        [-1.76676677],
#        [-1.75675676],
#        [-1.74674675],
#        [-1.73673674],
#        [-1.72672673],
#        [-1.71671672],
#        [-1.70670671],
#        [-1.6966967 ],
#        [-1.68668669],
#        [-1.67667668],
#        [-1.66666667],
#        [-1.65665666],
#        [-1.64664665],
#        [-1.63663664],
#        [-1.62662663],
#        [-1.61661662],
#        [-1.60660661],
#        [-1.5965966 ],
#        [-1.58658659],
#        [-1.57657658],
#        [-1.56656657],
#        [-1.55655656],
#        [-1.54654655],
#        [-1.53653654],
#        [-1.52652653],
#        [-1.51651652],
#        [-1.50650651],
#        [-1.4964965 ],
#        [-1.48648649],
#        [-1.47647648],
#        [-1.46646647],
#        [-1.45645646],
#        [-1.44644645],
#        [-1.43643644],
#        [-1.42642643],
#        [-1.41641642],
#        [-1.40640641],
#        [-1.3963964 ],
#        [-1.38638639],
#        [-1.37637638],
#        [-1.36636637],
#        [-1.35635636],
#        [-1.34634635],
#        [-1.33633634],
#        [-1.32632633],
#        [-1.31631632],
#        [-1.30630631],
#        [-1.2962963 ],
#        [-1.28628629],
#        [-1.27627628],
#        [-1.26626627],
#        [-1.25625626],
#        [-1.24624625],
#        [-1.23623624],
#        [-1.22622623],
#        [-1.21621622],
#        [-1.20620621],
#        [-1.1961962 ],
#        [-1.18618619],
#        [-1.17617618],
#        [-1.16616617],
#        [-1.15615616],
#        [-1.14614615],
#        [-1.13613614],
#        [-1.12612613],
#        [-1.11611612],
#        [-1.10610611],
#        [-1.0960961 ],
#        [-1.08608609],
#        [-1.07607608],
#        [-1.06606607],
#        [-1.05605606],
#        [-1.04604605],
#        [-1.03603604],
#        [-1.02602603],
#        [-1.01601602],
#        [-1.00600601],
#        [-0.995996  ],
#        [-0.98598599],
#        [-0.97597598],
#        [-0.96596597],
#        [-0.95595596],
#        [-0.94594595],
#        [-0.93593594],
#        [-0.92592593],
#        [-0.91591592],
#        [-0.90590591],
#        [ 2.96796797],
#        [ 2.97797798],
#        [ 2.98798799],
#        [ 2.997998  ],
#        [ 3.00800801],
#        [ 3.01801802],
#        [ 3.02802803],
#        [ 3.03803804],
#        [ 3.04804805],
#        [ 3.05805806],
#        [ 3.06806807],
#        [ 3.07807808],
#        [ 3.08808809],
#        [ 3.0980981 ],
#        [ 3.10810811],
#        [ 3.11811812],
#        [ 3.12812813],
#        [ 3.13813814],
#        [ 3.14814815],
#        [ 3.15815816],
#        [ 3.16816817],
#        [ 3.17817818],
#        [ 3.18818819],
#        [ 3.1981982 ],
#        [ 3.20820821],
#        [ 3.21821822],
#        [ 3.22822823],
#        [ 3.23823824],
#        [ 3.24824825],
#        [ 3.25825826],
#        [ 3.26826827],
#        [ 3.27827828],
#        [ 3.28828829],
#        [ 3.2982983 ],
#        [ 3.30830831],
#        [ 3.31831832],
#        [ 3.32832833],
#        [ 3.33833834],
#        [ 3.34834835],
#        [ 3.35835836],
#        [ 3.36836837],
#        [ 3.37837838],
#        [ 3.38838839],
#        [ 3.3983984 ],
#        [ 3.40840841],
#        [ 3.41841842],
#        [ 3.42842843],
#        [ 3.43843844],
#        [ 3.44844845],
#        [ 3.45845846],
#        [ 3.46846847],
#        [ 3.47847848],
#        [ 3.48848849],
#        [ 3.4984985 ],
#        [ 3.50850851],
#        [ 3.51851852],
#        [ 3.52852853],
#        [ 3.53853854],
#        [ 3.54854855],
#        [ 3.55855856],
#        [ 3.56856857],
#        [ 3.57857858],
#        [ 3.58858859],
#        [ 3.5985986 ],
#        [ 3.60860861],
#        [ 3.61861862],
#        [ 3.62862863],
#        [ 3.63863864],
#        [ 3.64864865],
#        [ 3.65865866],
#        [ 3.66866867],
#        [ 3.67867868],
#        [ 3.68868869],
#        [ 3.6986987 ],
#        [ 3.70870871],
#        [ 3.71871872],
#        [ 3.72872873],
#        [ 3.73873874],
#        [ 3.74874875],
#        [ 3.75875876],
#        [ 3.76876877],
#        [ 3.77877878],
#        [ 3.78878879],
#        [ 3.7987988 ],
#        [ 3.80880881],
#        [ 3.81881882],
#        [ 3.82882883],
#        [ 3.83883884],
#        [ 3.84884885],
#        [ 3.85885886],
#        [ 3.86886887],
#        [ 3.87887888],
#        [ 3.88888889],
#        [ 3.8988989 ],
#        [ 3.90890891],
#        [ 3.91891892],
#        [ 3.92892893],
#        [ 3.93893894],
#        [ 3.94894895],
#        [ 3.95895896],
#        [ 3.96896897],
#        [ 3.97897898],
#        [ 3.98898899],
#        [ 3.998999  ],
#        [ 4.00900901],
#        [ 4.01901902],
#        [ 4.02902903],
#        [ 4.03903904],
#        [ 4.04904905],
#        [ 4.05905906],
#        [ 4.06906907],
#        [ 4.07907908],
#        [ 4.08908909],
#        [ 4.0990991 ],
#        [ 4.10910911],
#        [ 4.11911912],
#        [ 4.12912913],
#        [ 4.13913914],
#        [ 4.14914915],
#        [ 4.15915916],
#        [ 4.16916917],
#        [ 4.17917918],
#        [ 4.18918919],
#        [ 4.1991992 ],
#        [ 4.20920921],
#        [ 4.21921922],
#        [ 4.22922923],
#        [ 4.23923924],
#        [ 4.24924925],
#        [ 4.25925926],
#        [ 4.26926927],
#        [ 4.27927928],
#        [ 4.28928929],
#        [ 4.2992993 ],
#        [ 4.30930931],
#        [ 4.31931932],
#        [ 4.32932933],
#        [ 4.33933934],
#        [ 4.34934935],
#        [ 4.35935936],
#        [ 4.36936937],
#        [ 4.37937938],
#        [ 4.38938939],
#        [ 4.3993994 ],
#        [ 4.40940941],
#        [ 4.41941942],
#        [ 4.42942943],
#        [ 4.43943944],
#        [ 4.44944945],
#        [ 4.45945946],
#        [ 4.46946947],
#        [ 4.47947948],
#        [ 4.48948949],
#        [ 4.4994995 ],
#        [ 4.50950951],
#        [ 4.51951952],
#        [ 4.52952953],
#        [ 4.53953954],
#        [ 4.54954955],
#        [ 4.55955956],
#        [ 4.56956957],
#        [ 4.57957958],
#        [ 4.58958959],
#        [ 4.5995996 ],
#        [ 4.60960961],
#        [ 4.61961962],
#        [ 4.62962963],
#        [ 4.63963964],
#        [ 4.64964965],
#        [ 4.65965966],
#        [ 4.66966967],
#        [ 4.67967968],
#        [ 4.68968969],
#        [ 4.6996997 ],
#        [ 4.70970971],
#        [ 4.71971972],
#        [ 4.72972973],
#        [ 4.73973974],
#        [ 4.74974975],
#        [ 4.75975976],
#        [ 4.76976977],
#        [ 4.77977978],
#        [ 4.78978979],
#        [ 4.7997998 ],
#        [ 4.80980981],
#        [ 4.81981982],
#        [ 4.82982983],
#        [ 4.83983984],
#        [ 4.84984985],
#        [ 4.85985986],
#        [ 4.86986987],
#        [ 4.87987988],
#        [ 4.88988989],
#        [ 4.8998999 ],
#        [ 4.90990991],
#        [ 4.91991992],
#        [ 4.92992993],
#        [ 4.93993994],
#        [ 4.94994995],
#        [ 4.95995996],
#        [ 4.96996997],
#        [ 4.97997998],
#        [ 4.98998999],
#        [ 5.        ]])

# %%
thetas = np.linspace(-5.0, 5.0, 1000)
means_alice = []
means_carl = []
for t in thetas:
    rs_carl = (ratio(ratio_1,ratio_2,t,-4,4))
    mask_carl = rs_carl > 0
    rs_carl = rs_carl[mask_carl]
    rs_alice = (ratio(ratio_alice1,ratio_alice2,t,-4,4))
    mask_alice = rs_alice > 0
    rs_alice = rs_alice[mask_alice]
    means_alice.append(-2*np.mean(np.log(rs_alice)))
    means_carl.append(-2*np.mean(np.log(rs_carl)))

# %% [markdown]
# This is the expected log likelihood ratio over parameter space:

# %%
fig = plt.figure(figsize=(5, 5))

plt.plot(
    theta_grid,
    nllr_test_true,
    ls="--",
    c="black",
    label=r"Ground truth ($\theta = 1.0$)",
)
plt.plot(
    theta_grid,
    means_carl,
    c="red",
    label=r"morph carl",
)
plt.plot(
    theta_grid,
    means_alice,
    c="blue",
    label=r"morph alice",
)
plt.xlabel(r"$\theta$")
plt.ylabel(r"$\mathbb{E}_x [ -2\, \log \,r(x | \theta, \theta_{1}) ]$")

plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# You should see that the new ALICES approach leads to a better approximation of the true likelihood ratio than the CARL estimate. Note that we only trained in the parameter range (-4, 4), so the deviations at the left and right of the plot are to be expected.
