# %% [markdown]
# # Toy example
#
# Original notebook by Alexander Held, edited for the MadMiner repository by Johann Brehmer, Irina Espejo, Felix Kling, and Kyle Cranmer 2018-2019.

# %% [markdown]
# In this notebook, we use a simple toy example to demonstrate the machine learning and inference algorithms in MadMiner. This allows us to skip many of the more technical steps, and there's no dependency on MadGraph, Pythia, or Delphes.
#
# What this tutorial does not do, is explaining the inference methods. To understand what's happening, please have a look at ["Constraining Effective Field Theories With Machine Learning"](https://arxiv.org/abs/1805.00013), which will explain the basic idea in just a few pages. If you really want to get down to the dirty details, ["A Guide to Constraining Effective Field Theories With Machine Learning"](https://arxiv.org/abs/1805.00020) has you covered.

# %% [markdown]
# ## Preparations

# %%
import os
import logging
import numpy as np
from scipy.stats import norm
from matplotlib import pyplot as plt

# %matplotlib inline
import sys
sys.path.append('/remote/gpu02/crescenzo/MadMiner')

from madminer.ml import ParameterizedRatioEstimator, MorphParameterizedRatioEstimator

# %%
if not os.path.exists("data_close_morph"):
    os.makedirs("data_close_morph")

# %% [markdown]
# MadMiner uses the Python `logging` module to provide additional information and debugging output. You can choose how much of this output you want to see by switching the level in the following lines to `logging.DEBUG` or `logging.WARNING`.

# %%
# MadMiner output
logging.basicConfig(
    format="%(asctime)-5.5s %(name)-20.20s %(levelname)-7.7s %(message)s",
    datefmt="%H:%M",
    level=logging.INFO,
)

# Output of all other modules (e.g. matplotlib)
for key in logging.Logger.manager.loggerDict:
    if "madminer" not in key:
        logging.getLogger(key).setLevel(logging.WARNING)

# %% [markdown]
# ## 1. A toy simulator

# %% [markdown]
# Our simulator depends on just one parameter `theta` and produces one-dimensional observables `x`. It is characterized by one latent variable `z`. "Running" the simulator consists of two steps:
# - "Hard process": a value of `z` is drawn from a normal distribution, where the mean depends on `theta`.
# - "Detector": a value for `x` is drawn from a normal distribution with mean equal to `z`. There is no explicit dependence on `theta`.
#
# As in the particle physics case, we assume that we can calculate the joint likelihood ratio `r(x, z | theta0, theta1)` as well as the joint score `t(x, z | theta)`, which depend explicitly on `z` (and where the "detector" part cancels).
#
# Here are some general settings (feel free to play with them):

# %%
z_std = 2.0
x_std = 1.0

# %% [markdown]
# The following function runs the simulator for a value of `theta` and calculates the joint likelihood ratio between `theta0` and `theta1` as well as the joint score at `theta_score`:

# %%
alpha=1

# %%
npoints = 100

# %%
theta = 100

# %%
z1 = np.random.normal(loc=0, scale=z_std, size=npoints)
z2 = np.random.normal(loc=alpha, scale=z_std, size=npoints)
mask = np.random.choice([True, False],p=[1./(1+theta**2),theta**2/(1+theta**2)],size=npoints)

# %%
z1[mask].flatten()
# Out:
# array([], dtype=float64)

# %%
np.concatenate((z1[mask],z2[~mask]))
# Out:
# array([ 3.0521191 ,  0.03476796, -0.18913942, -2.34146218,  1.21252335,
#        -1.39343576, -1.01463042, -0.44492294, -1.77670105, -0.35258828,
#        -0.32290093,  0.62487594,  2.31600192,  3.22501766,  1.28765596,
#         3.5900482 ,  1.43352872,  0.15290518,  4.46267283, -1.9161587 ,
#        -0.96783711, -0.12817236,  1.00860895, -0.19497636,  2.61427947,
#        -0.63063988, -0.2210344 ,  1.05668957,  2.67309631,  2.57564349,
#         4.07904971, -1.81650852,  3.66784624,  0.41482381,  2.16915403,
#        -3.39528194, -0.46638216,  3.93115781,  6.05583536,  3.23131323,
#         1.89873255, -5.56304916,  2.18648419,  3.39502955,  0.32367038,
#         2.12575106, -0.5250543 ,  0.60783062,  0.8695897 ,  2.60212939,
#         0.4136557 , -1.22153206,  1.77611225,  3.28226598,  1.07680892,
#         1.18024012,  2.59671032, -1.02288464,  3.01485545,  2.59504073,
#         2.91356258,  0.69746867,  0.57870015, -1.05773933,  2.21626191,
#         0.63286175,  2.91056713,  4.51304657, -3.90461207, -3.07825438,
#        -0.48537377,  1.20738475,  5.09719656, -1.62229521, -0.58065818,
#         0.38033022,  4.39942438, -0.64063581, -1.51000485, -0.57648944,
#         1.12038575,  0.9856994 ,  1.23061505,  0.30435444,  1.90727564,
#        -0.2362645 ,  2.8987758 ,  1.32109641,  2.35952254,  2.5708296 ,
#         1.78848521, -1.91183549,  1.27280117, -1.21900156,  1.91086524,
#        -1.02188609, -0.35604062,  1.99388732,  0.80826032,  1.14945353])

# %%
np.random.choice([True,False],p = [0.5,0.5],size = None)
# Out:
# True

# %%
def simulate(theta, theta00=None, theta01=None, theta1=None, theta_score=None, npoints=None):
    # Draw latent variables z
    z1 = np.random.normal(loc=0, scale=z_std, size=npoints)
    z2 = np.random.normal(loc=alpha, scale=z_std, size=npoints)
    mask = np.random.choice([True, False],p=[1./(1+theta**2),theta**2/(1+theta**2)],size=npoints)
    try:
        z = np.concatenate((z1[mask],z2[~mask]))
    except:
        if mask:
            z = z1
        else:
            z = z2
    # Draw observables x
    x = np.random.normal(loc=z, scale=x_std, size=None)

    # Calculate joint likelihood ratio and joint score
    if theta00 is not None and theta01 is not None and theta1 is not None:
        r_xz1 = (norm(loc=theta1, scale=z_std).pdf(z)+(theta00**2)*norm(loc=alpha, scale=z_std).pdf(z) )/ ((1+theta00**2)*norm(loc=theta1, scale=z_std).pdf(z))
        r_xz2 = (norm(loc=theta1, scale=z_std).pdf(z)+(theta01**2)*norm(loc=alpha, scale=z_std).pdf(z) )/ ((1+theta01**2)*norm(loc=theta1, scale=z_std).pdf(z))
    else:
        r_xz1 = None
        r_xz2 = None

    if theta_score is not None:
        t_xz = (x - theta_score) / z_std**2
    else:
        t_xz = None

    return x, r_xz1, r_xz2, t_xz

# %% [markdown]
# Usually the likelihood function `p(x|theta)` is intractable, but in this toy example it is just given by the convolution of two Gaussians, which is again a Gaussian. We will use this to validate the results later:

# %%
def calculate_likelihood_ratio(x, theta0, theta1=0.0):
    combined_std = (z_std**2 + x_std**2) ** 0.5
    r_x = (norm(loc=theta1, scale=combined_std).pdf(x)+(theta0**2)*norm(loc=alpha, scale=combined_std).pdf(x) )/ ((1+theta0**2)*norm(loc=theta1, scale=combined_std).pdf(x))
    return r_x

# %% [markdown]
# Let's now visualize that: we run the simulation and plot the probability distributions $p(x | \theta_i)$. Additionally, we also plot the true log-likelihood ratio $\log\,r(x|\theta_0,\theta_1)$.

# %%
x0, _, _, _ = simulate(100, npoints=10000)
x1, _, _, _ = simulate(0, npoints=10000)

xr = np.linspace(-20.0, 300.0, 100)
rx = np.log(calculate_likelihood_ratio(xr, 100, 0))

fig, ax1 = plt.subplots()
fig.set_size_inches(5, 5)
ax1.set_xlabel("$x$")
ax1.hist(x0, bins=50, range=(-20, 20.0), histtype="step", label=r"$p(x | \theta_0)$", density=True)
ax1.hist(x1, bins=50, range=(-20, 20.0), histtype="step", label=r"$p(x | \theta_1)$", density=True)
ax1.set_ylabel(r"$p(x|\theta)$")
ax1.legend(loc=2)

ax2 = ax1.twinx()
ax2.plot(xr, rx, color="black", label=r"$\log\,r(x|\theta_0,\theta_1)$")
ax2.set_ylabel(r"$\log\,r(x|\theta_0,\theta_1)$")
ax2.legend(loc=1)

plt.show()
# Out:
# /tmp/ipykernel_2952330/413034781.py:3: RuntimeWarning: divide by zero encountered in divide
#   r_x = (norm(loc=theta1, scale=combined_std).pdf(x)+(theta0**2)*norm(loc=alpha, scale=combined_std).pdf(x) )/ ((1+theta0**2)*norm(loc=theta1, scale=combined_std).pdf(x))
# /tmp/ipykernel_2952330/413034781.py:3: RuntimeWarning: invalid value encountered in divide
#   r_x = (norm(loc=theta1, scale=combined_std).pdf(x)+(theta0**2)*norm(loc=alpha, scale=combined_std).pdf(x) )/ ((1+theta0**2)*norm(loc=theta1, scale=combined_std).pdf(x))

# %%
x0.shape
# Out:
# (10000,)

# %% [markdown]
# ## 2. Run the simulation and generate training data

# %% [markdown]
# First, we define the parameter points we want to use for training: `theta0` is uniformly distributed while the reference model `theta1` is fixed at zero.

# %%
# number of parameter points to train
n_param_points = 10000

# numerator, uniform prior
theta00 = np.ones(shape=n_param_points)*(-4)
theta01 = np.ones(shape=n_param_points)*0.
theta02 = np.ones(shape=n_param_points)*4

# %% [markdown]
# We then run the simulator (one sample per parameter point). Remember that `simulate(theta, theta0, theta1, theta_score)` generates data `x` following a theory with `theta` and then evaluates the joint likelihood ratio `r(x,z|theta0,theta1)` and the join score `t(x,z|theta_score)` for each data point.

# %%
# Sample from theta0
x_from_theta00 = []
r_xz_from_theta00 = []
t_xz_from_theta00 = []
x_from_theta01 = []
r_xz_from_theta001 = []
r_xz_from_theta002 = []
t_xz_from_theta01 = []
x_from_theta02 = []
r_xz_from_theta02 = []
t_xz_from_theta02 = []
for t in theta00:
    out = simulate(t, t, t, 0., t)
    x_from_theta00.append(out[0])
    r_xz_from_theta00.append(out[1])
print("Done first sim")
for t in theta01:
    out = simulate(t, -4, 4, 0., t)
    x_from_theta01.append(out[0])
    r_xz_from_theta001.append(out[1])
    r_xz_from_theta002.append(out[2])
    #t_xz_from_theta01.append(out[2])
print("Done first sim")
for t in theta02:
    out = simulate(t, t,t, 0., t)
    x_from_theta02.append(out[0])
    r_xz_from_theta02.append(out[2])
    #t_xz_from_theta02.append(out[2])
print("Done first sim")
# Out:
# Done first sim
# Done first sim
# Done first sim

# %%
r_xz_from_theta02
# Out:
#  2.8531364362812774,
#  1.3673881395345098,
#  1.8761632359244151,
#  3.4213852819146133,
#  0.4754585487750068,
#  0.8373309522787494,
#  1.0051081540550766,
#  1.568937197379738,
#  1.4876781907945138,
#  0.3806173082375221,
#  1.3102831341879424,
#  0.961094783543762,
#  1.087410449777605,
#  1.557927927350583,
#  1.0518688194254853,
#  1.5767160372508864,
#  0.8592355193230476,
#  1.4416116244531403,
#  1.3959121529861986,
#  1.7713602581773131,
#  0.9656138287579183,
#  1.2477909060766335,
#  0.7487780091870997,
#  0.8211974660235238,
#  2.6505857310673386,
#  0.823800788442102,
#  1.2394903080219826,
#  1.356832554838581,
#  0.6553607457296251,
#  0.517172163309265,
#  0.44243148692719314,
#  1.0228945012532795,
#  1.0254953763865389,
#  1.4742950313926313,
#  1.372138930392232,
#  0.6788186760551275,
#  0.9682442087208418,
#  1.3947589657409867,
#  0.9867966233701788,
#  0.6172138905410931,
#  2.2532720798330144,
#  0.6640557845524897,
#  1.8775378793556843,
#  1.4939589302068366,
#  1.0008797717250064,
#  0.8378504314795887,
#  1.8678468621750843,
#  0.9472452702542167,
#  1.0190435005272818,
#  0.6761562220303694,
#  1.0611770032696572,
#  1.0772747859628384,
#  1.3720189861449428,
#  1.3086495963797151,
#  1.621891738261405,
#  0.712938026355529,
#  0.9024532699577176,
#  0.6055112859083324,
#  1.5054892986742112,
#  0.6668915109946737,
#  1.7292417290522615,
#  1.076752034348418,
#  0.5186943050934826,
#  1.1015375041703446,
#  0.6702044455621257,
#  1.0226390896832611,
#  1.6400863181969842,
#  0.916184546355721,
#  0.4617116307206669,
#  0.5500751543490314,
#  0.7376592553199588,
#  1.304858851414522,
#  1.3089720940554355,
#  1.3514476170518295,
#  1.138651386676207,
#  1.2955537653684346,
#  1.1285858541561595,
#  0.6691555339954982,
#  2.150781398175807,
#  0.9969676031014246,
#  1.2105263375070643,
#  0.9524033908041373,
#  1.4691894725627928,
#  1.4096290943131242,
#  0.732904580843026,
#  1.979077080053312,
#  1.1215078499583209,
#  ...]

# %% [markdown]
# Now we combine and reshape the results (nothing interesting happening here) and save everything to files, so that we can load it later.

# %%
plt.hist(x_from_theta02)
# Out:
# (array([  13.,   83.,  459., 1445., 2740., 2807., 1776.,  543.,  119.,
#           15.]),
#  array([-7.73139638, -6.0188494 , -4.30630243, -2.59375545, -0.88120847,
#          0.83133851,  2.54388549,  4.25643247,  5.96897944,  7.68152642,
#          9.3940734 ]),
#  <BarContainer object of 10 artists>)

# %%
# Combine results and reshape
x_train0 = np.hstack((x_from_theta00, x_from_theta01)).reshape(-1, 1)
x_train1 = np.hstack((x_from_theta02, x_from_theta01)).reshape(-1, 1)
r_xz_train0 = np.hstack((r_xz_from_theta00, r_xz_from_theta001)).reshape(-1, 1)
r_xz_train1 = np.hstack((r_xz_from_theta02, r_xz_from_theta002)).reshape(-1, 1)
#t_xz_train0 = np.hstack((t_xz_from_theta0, t_xz_from_theta1)).reshape(-1, 1)
y_train0 = np.hstack((np.zeros_like(x_from_theta00), np.ones_like(np.ones_like(x_from_theta01)))).reshape(-1, 1)
y_train1 = np.hstack((np.zeros_like(x_from_theta02), np.ones_like(np.ones_like(x_from_theta01)))).reshape(-1, 1)
#theta0_train = np.hstack((theta0, theta0)).reshape(-1, 1)

shuf = np.random.permutation(np.shape(x_train0)[0])

# Save to file
#np.save("data/theta0_train.npy", theta0_train)
np.save("data_close_morph/x_train0.npy", x_train0[shuf])
np.save("data_close_morph/x_train1.npy", x_train1[shuf])
np.save("data_close_morph/y_train0.npy", y_train0[shuf])
np.save("data_close_morph/y_train1.npy", y_train1[shuf])
np.save("data_close_morph/r_xz_train0.npy", r_xz_train0[shuf])
np.save("data_close_morph/r_xz_train1.npy", r_xz_train1[shuf])
#np.save("data/t_xz_train.npy", t_xz_train)

# %% [markdown]
# ## 3. Model training

# %% [markdown]
# Let's train two neural networks to estimate the likelihood ratio. For one we use the CARL method introduced in ["Approximating Likelihood Ratios with Calibrated Discriminative Classifiers"](https://arxiv.org/abs/1506.02169), for the other the new ALICES method introduced in ["Likelihood-free inference with an improved cross-entropy estimator"](https://arxiv.org/abs/1808.00973).

# %%
nn = MorphParameterizedRatioEstimator(n_hidden=(20, 20))

loss = nn.train(
    method="carl",
    x="data_close_morph/x_train0.npy",
    y="data_close_morph/y_train0.npy",
    n_epochs=100,
)

nn.save("models_close_morph/carl0")
# Out:
# 13:16 madminer.ml.paramete INFO    Starting training
# 13:16 madminer.ml.paramete INFO      Method:                 carl
# 13:16 madminer.ml.paramete INFO      Batch size:             128
# 13:16 madminer.ml.paramete INFO      Optimizer:              amsgrad
# 13:16 madminer.ml.paramete INFO      Epochs:                 100
# 13:16 madminer.ml.paramete INFO      Learning rate:          0.001 initially, decaying to 0.0001
# 13:16 madminer.ml.paramete INFO      Validation split:       0.25
# 13:16 madminer.ml.paramete INFO      Early stopping:         True
# 13:16 madminer.ml.paramete INFO      Scale inputs:           True
# 13:16 madminer.ml.paramete INFO      Scale parameters:       True
# 13:16 madminer.ml.paramete INFO      Shuffle labels          False
# 13:16 madminer.ml.paramete INFO      Samples:                all
# 13:16 madminer.ml.paramete INFO    Loading training data
# 13:16 madminer.utils.vario INFO      Loading data_close_morph/x_train0.npy into RAM
# 13:16 madminer.utils.vario INFO      Loading data_close_morph/y_train0.npy into RAM
# 13:16 madminer.ml.paramete INFO    Found 20000 samples with 1 observables
# 13:16 madminer.ml.base     INFO    Setting up input rescaling
# 13:16 madminer.ml.paramete INFO    Creating model
# 13:16 madminer.ml.paramete INFO    Training model
# 13:16 madminer.utils.ml.tr INFO    Training on CPU with single precision
# 13:16 madminer.utils.ml.tr INFO      Epoch   5: train loss  0.67466 (xe:  0.675)
# 13:16 madminer.utils.ml.tr INFO                 val. loss   0.67195 (xe:  0.672)
# 13:16 madminer.utils.ml.tr INFO      Epoch  10: train loss  0.67360 (xe:  0.674)
# 13:16 madminer.utils.ml.tr INFO                 val. loss   0.67410 (xe:  0.674)
# 13:16 madminer.utils.ml.tr INFO      Epoch  15: train loss  0.67381 (xe:  0.674)
# 13:17 madminer.utils.ml.tr INFO                 val. loss   0.67355 (xe:  0.674)
# 13:17 madminer.utils.ml.tr INFO    Early stopping after epoch 32, with loss  0.67051 compared to final loss  0.67355
# 13:17 madminer.utils.ml.tr INFO    Training time spend on:
# 13:17 madminer.utils.ml.tr INFO                      initialize model:   0.00h
# 13:17 madminer.utils.ml.tr INFO                                   ALL:   0.01h
# 13:17 madminer.utils.ml.tr INFO                            check data:   0.00h
# 13:17 madminer.utils.ml.tr INFO                          make dataset:   0.00h
# 13:17 madminer.utils.ml.tr INFO                       make dataloader:   0.00h
# 13:17 madminer.utils.ml.tr INFO                       setup optimizer:   0.00h
# 13:17 madminer.utils.ml.tr INFO                   initialize training:   0.00h
# 13:17 madminer.utils.ml.tr INFO                                set lr:   0.00h
# 13:17 madminer.utils.ml.tr INFO                   load training batch:   0.01h
# 13:17 madminer.utils.ml.tr INFO                        fwd: move data:   0.00h
# 13:17 madminer.utils.ml.tr INFO                   fwd: check for nans:   0.00h
# 13:17 madminer.utils.ml.tr INFO                    fwd: model.forward:   0.00h
# 13:17 madminer.utils.ml.tr INFO                 fwd: calculate losses:   0.00h
# 13:17 madminer.utils.ml.tr INFO                 training forward pass:   0.00h
# 13:17 madminer.utils.ml.tr INFO                   training sum losses:   0.00h
# 13:17 madminer.utils.ml.tr INFO                        opt: zero grad:   0.00h
# 13:17 madminer.utils.ml.tr INFO                         opt: backward:   0.00h
# 13:17 madminer.utils.ml.tr INFO                   opt: clip grad norm:   0.00h
# 13:17 madminer.utils.ml.tr INFO                             opt: step:   0.00h
# 13:17 madminer.utils.ml.tr INFO                        optimizer step:   0.00h
# 13:17 madminer.utils.ml.tr INFO                 load validation batch:   0.00h
# 13:17 madminer.utils.ml.tr INFO               validation forward pass:   0.00h
# 13:17 madminer.utils.ml.tr INFO                 validation sum losses:   0.00h
# 13:17 madminer.utils.ml.tr INFO                        early stopping:   0.00h
# 13:17 madminer.utils.ml.tr INFO                          report epoch:   0.00h
# 13:17 madminer.ml.base     INFO    Saving model to models_close_morph/carl0

# %%
nn = MorphParameterizedRatioEstimator(n_hidden=(20, 20))

loss = nn.train(
    method="alice",
    x="data_close_morph/x_train0.npy",
    y="data_close_morph/y_train0.npy",
    r_xz="data_close_morph/r_xz_train0.npy",
    n_epochs=100,
)

nn.save("models_close_morph/alice0")
# Out:
# 13:17 madminer.ml.paramete INFO    Starting training
# 13:17 madminer.ml.paramete INFO      Method:                 alice
# 13:17 madminer.ml.paramete INFO      Batch size:             128
# 13:17 madminer.ml.paramete INFO      Optimizer:              amsgrad
# 13:17 madminer.ml.paramete INFO      Epochs:                 100
# 13:17 madminer.ml.paramete INFO      Learning rate:          0.001 initially, decaying to 0.0001
# 13:17 madminer.ml.paramete INFO      Validation split:       0.25
# 13:17 madminer.ml.paramete INFO      Early stopping:         True
# 13:17 madminer.ml.paramete INFO      Scale inputs:           True
# 13:17 madminer.ml.paramete INFO      Scale parameters:       True
# 13:17 madminer.ml.paramete INFO      Shuffle labels          False
# 13:17 madminer.ml.paramete INFO      Samples:                all
# 13:17 madminer.ml.paramete INFO    Loading training data
# 13:17 madminer.utils.vario INFO      Loading data_close_morph/x_train0.npy into RAM
# 13:17 madminer.utils.vario INFO      Loading data_close_morph/y_train0.npy into RAM
# 13:17 madminer.utils.vario INFO      Loading data_close_morph/r_xz_train0.npy into RAM
# 13:17 madminer.ml.paramete INFO    Found 20000 samples with 1 observables
# 13:17 madminer.ml.base     INFO    Setting up input rescaling
# 13:17 madminer.ml.paramete INFO    Creating model
# 13:17 madminer.ml.paramete INFO    Training model
# 13:17 madminer.utils.ml.tr INFO    Training on CPU with single precision
# 13:17 madminer.utils.ml.tr INFO      Epoch   5: train loss  0.67158 (improved_xe:  0.672)
# 13:17 madminer.utils.ml.tr INFO                 val. loss   0.67195 (improved_xe:  0.672)
# 13:17 madminer.utils.ml.tr INFO      Epoch  10: train loss  0.67152 (improved_xe:  0.672)
# 13:17 madminer.utils.ml.tr INFO                 val. loss   0.67207 (improved_xe:  0.672)
# 13:17 madminer.utils.ml.tr INFO      Epoch  15: train loss  0.67151 (improved_xe:  0.672)
# 13:17 madminer.utils.ml.tr INFO                 val. loss   0.67208 (improved_xe:  0.672)
# 13:17 madminer.utils.ml.tr INFO      Epoch  20: train loss  0.67156 (improved_xe:  0.672)
# 13:17 madminer.utils.ml.tr INFO                 val. loss   0.67222 (improved_xe:  0.672)
# 13:17 madminer.utils.ml.tr INFO      Epoch  25: train loss  0.67144 (improved_xe:  0.671)
# 13:17 madminer.utils.ml.tr INFO                 val. loss   0.67203 (improved_xe:  0.672)
# 13:17 madminer.utils.ml.tr INFO      Epoch  30: train loss  0.67141 (improved_xe:  0.671)
# 13:17 madminer.utils.ml.tr INFO                 val. loss   0.67157 (improved_xe:  0.672)
# 13:17 madminer.utils.ml.tr INFO      Epoch  35: train loss  0.67154 (improved_xe:  0.672)
# 13:17 madminer.utils.ml.tr INFO                 val. loss   0.67215 (improved_xe:  0.672)
# 13:17 madminer.utils.ml.tr INFO      Epoch  40: train loss  0.67153 (improved_xe:  0.672)
# 13:17 madminer.utils.ml.tr INFO                 val. loss   0.67121 (improved_xe:  0.671)
# 13:17 madminer.utils.ml.tr INFO      Epoch  45: train loss  0.67150 (improved_xe:  0.671)
# 13:17 madminer.utils.ml.tr INFO                 val. loss   0.67166 (improved_xe:  0.672)
# 13:17 madminer.utils.ml.tr INFO      Epoch  50: train loss  0.67157 (improved_xe:  0.672)
# 13:17 madminer.utils.ml.tr INFO                 val. loss   0.67215 (improved_xe:  0.672)
# 13:17 madminer.utils.ml.tr INFO      Epoch  55: train loss  0.67159 (improved_xe:  0.672)
# 13:17 madminer.utils.ml.tr INFO                 val. loss   0.67152 (improved_xe:  0.672)
# 13:17 madminer.utils.ml.tr INFO      Epoch  60: train loss  0.67153 (improved_xe:  0.672)
# 13:17 madminer.utils.ml.tr INFO                 val. loss   0.67132 (improved_xe:  0.671)
# 13:18 madminer.utils.ml.tr INFO      Epoch  65: train loss  0.67145 (improved_xe:  0.671)
# 13:18 madminer.utils.ml.tr INFO                 val. loss   0.67199 (improved_xe:  0.672)
# 13:18 madminer.utils.ml.tr INFO      Epoch  70: train loss  0.67144 (improved_xe:  0.671)
# 13:18 madminer.utils.ml.tr INFO                 val. loss   0.67235 (improved_xe:  0.672)
# 13:18 madminer.utils.ml.tr INFO      Epoch  75: train loss  0.67157 (improved_xe:  0.672)
# 13:18 madminer.utils.ml.tr INFO                 val. loss   0.67210 (improved_xe:  0.672)
# 13:18 madminer.utils.ml.tr INFO      Epoch  80: train loss  0.67148 (improved_xe:  0.671)
# 13:18 madminer.utils.ml.tr INFO                 val. loss   0.67163 (improved_xe:  0.672)
# 13:18 madminer.utils.ml.tr INFO      Epoch  85: train loss  0.67137 (improved_xe:  0.671)
# 13:18 madminer.utils.ml.tr INFO                 val. loss   0.67189 (improved_xe:  0.672)
# 13:18 madminer.utils.ml.tr INFO      Epoch  90: train loss  0.67159 (improved_xe:  0.672)
# 13:18 madminer.utils.ml.tr INFO                 val. loss   0.67199 (improved_xe:  0.672)
# 13:18 madminer.utils.ml.tr INFO      Epoch  95: train loss  0.67149 (improved_xe:  0.671)
# 13:18 madminer.utils.ml.tr INFO                 val. loss   0.67234 (improved_xe:  0.672)
# 13:18 madminer.utils.ml.tr INFO      Epoch 100: train loss  0.67152 (improved_xe:  0.672)
# 13:18 madminer.utils.ml.tr INFO                 val. loss   0.67188 (improved_xe:  0.672)
# 13:18 madminer.utils.ml.tr INFO    Early stopping after epoch 88, with loss  0.67062 compared to final loss  0.67188
# 13:18 madminer.utils.ml.tr INFO    Training time spend on:
# 13:18 madminer.utils.ml.tr INFO                      initialize model:   0.00h
# 13:18 madminer.utils.ml.tr INFO                                   ALL:   0.02h
# 13:18 madminer.utils.ml.tr INFO                            check data:   0.00h
# 13:18 madminer.utils.ml.tr INFO                          make dataset:   0.00h
# 13:18 madminer.utils.ml.tr INFO                       make dataloader:   0.00h
# 13:18 madminer.utils.ml.tr INFO                       setup optimizer:   0.00h
# 13:18 madminer.utils.ml.tr INFO                   initialize training:   0.00h
# 13:18 madminer.utils.ml.tr INFO                                set lr:   0.00h
# 13:18 madminer.utils.ml.tr INFO                   load training batch:   0.01h
# 13:18 madminer.utils.ml.tr INFO                        fwd: move data:   0.00h
# 13:18 madminer.utils.ml.tr INFO                   fwd: check for nans:   0.00h
# 13:18 madminer.utils.ml.tr INFO                    fwd: model.forward:   0.00h
# 13:18 madminer.utils.ml.tr INFO                 fwd: calculate losses:   0.00h
# 13:18 madminer.utils.ml.tr INFO                 training forward pass:   0.00h
# 13:18 madminer.utils.ml.tr INFO                   training sum losses:   0.00h
# 13:18 madminer.utils.ml.tr INFO                        opt: zero grad:   0.00h
# 13:18 madminer.utils.ml.tr INFO                         opt: backward:   0.00h
# 13:18 madminer.utils.ml.tr INFO                   opt: clip grad norm:   0.00h
# 13:18 madminer.utils.ml.tr INFO                             opt: step:   0.00h
# 13:18 madminer.utils.ml.tr INFO                        optimizer step:   0.00h
# 13:18 madminer.utils.ml.tr INFO                 load validation batch:   0.00h
# 13:18 madminer.utils.ml.tr INFO               validation forward pass:   0.00h
# 13:18 madminer.utils.ml.tr INFO                 validation sum losses:   0.00h
# 13:18 madminer.utils.ml.tr INFO                        early stopping:   0.00h
# 13:18 madminer.utils.ml.tr INFO                          report epoch:   0.00h
# 13:18 madminer.ml.base     INFO    Saving model to models_close_morph/alice0

# %%
plt.plot(loss[0])
plt.plot(loss[1])

# %%
nn = MorphParameterizedRatioEstimator(n_hidden=(20, 20))

loss = nn.train(
    method="carl",
    x="data_close_morph/x_train1.npy",
    y="data_close_morph/y_train1.npy",
    n_epochs=100,
)

nn.save("models_close_morph/carl1")
# Out:
# 13:18 madminer.ml.paramete INFO    Starting training
# 13:18 madminer.ml.paramete INFO      Method:                 carl
# 13:18 madminer.ml.paramete INFO      Batch size:             128
# 13:18 madminer.ml.paramete INFO      Optimizer:              amsgrad
# 13:18 madminer.ml.paramete INFO      Epochs:                 100
# 13:18 madminer.ml.paramete INFO      Learning rate:          0.001 initially, decaying to 0.0001
# 13:18 madminer.ml.paramete INFO      Validation split:       0.25
# 13:18 madminer.ml.paramete INFO      Early stopping:         True
# 13:18 madminer.ml.paramete INFO      Scale inputs:           True
# 13:18 madminer.ml.paramete INFO      Scale parameters:       True
# 13:18 madminer.ml.paramete INFO      Shuffle labels          False
# 13:18 madminer.ml.paramete INFO      Samples:                all
# 13:18 madminer.ml.paramete INFO    Loading training data
# 13:18 madminer.utils.vario INFO      Loading data_close_morph/x_train1.npy into RAM
# 13:18 madminer.utils.vario INFO      Loading data_close_morph/y_train1.npy into RAM
# 13:18 madminer.ml.paramete INFO    Found 20000 samples with 1 observables
# 13:18 madminer.ml.base     INFO    Setting up input rescaling
# 13:18 madminer.ml.paramete INFO    Creating model
# 13:18 madminer.ml.paramete INFO    Training model
# 13:18 madminer.utils.ml.tr INFO    Training on CPU with single precision
# 13:18 madminer.utils.ml.tr INFO      Epoch   5: train loss  0.66957 (xe:  0.670)
# 13:18 madminer.utils.ml.tr INFO                 val. loss   0.67426 (xe:  0.674)
# 13:18 madminer.utils.ml.tr INFO      Epoch  10: train loss  0.66927 (xe:  0.669)
# 13:18 madminer.utils.ml.tr INFO                 val. loss   0.67647 (xe:  0.676)
# 13:18 madminer.utils.ml.tr INFO      Epoch  15: train loss  0.66946 (xe:  0.669)
# 13:18 madminer.utils.ml.tr INFO                 val. loss   0.67848 (xe:  0.678)
# 13:18 madminer.utils.ml.tr INFO      Epoch  20: train loss  0.66959 (xe:  0.670)
# 13:18 madminer.utils.ml.tr INFO                 val. loss   0.67258 (xe:  0.673)
# 13:18 madminer.utils.ml.tr INFO      Epoch  25: train loss  0.66939 (xe:  0.669)
# 13:18 madminer.utils.ml.tr INFO                 val. loss   0.67831 (xe:  0.678)
# 13:18 madminer.utils.ml.tr INFO      Epoch  30: train loss  0.66965 (xe:  0.670)
# 13:18 madminer.utils.ml.tr INFO                 val. loss   0.67341 (xe:  0.673)
# 13:18 madminer.utils.ml.tr INFO      Epoch  35: train loss  0.66928 (xe:  0.669)
# 13:18 madminer.utils.ml.tr INFO                 val. loss   0.67582 (xe:  0.676)
# 13:18 madminer.utils.ml.tr INFO      Epoch  40: train loss  0.66933 (xe:  0.669)
# 13:18 madminer.utils.ml.tr INFO                 val. loss   0.67503 (xe:  0.675)
# 13:18 madminer.utils.ml.tr INFO      Epoch  45: train loss  0.66935 (xe:  0.669)
# 13:18 madminer.utils.ml.tr INFO                 val. loss   0.67461 (xe:  0.675)
# 13:18 madminer.utils.ml.tr INFO      Epoch  50: train loss  0.66907 (xe:  0.669)
# 13:18 madminer.utils.ml.tr INFO                 val. loss   0.67599 (xe:  0.676)
# 13:18 madminer.utils.ml.tr INFO      Epoch  55: train loss  0.66912 (xe:  0.669)
# 13:18 madminer.utils.ml.tr INFO                 val. loss   0.67605 (xe:  0.676)
# 13:18 madminer.utils.ml.tr INFO      Epoch  60: train loss  0.66908 (xe:  0.669)
# 13:18 madminer.utils.ml.tr INFO                 val. loss   0.67546 (xe:  0.675)
# 13:18 madminer.utils.ml.tr INFO      Epoch  65: train loss  0.66917 (xe:  0.669)
# 13:18 madminer.utils.ml.tr INFO                 val. loss   0.67389 (xe:  0.674)
# 13:18 madminer.utils.ml.tr INFO      Epoch  70: train loss  0.66872 (xe:  0.669)
# 13:18 madminer.utils.ml.tr INFO                 val. loss   0.67634 (xe:  0.676)
# 13:19 madminer.utils.ml.tr INFO      Epoch  75: train loss  0.66894 (xe:  0.669)
# 13:19 madminer.utils.ml.tr INFO                 val. loss   0.67263 (xe:  0.673)
# 13:19 madminer.utils.ml.tr INFO      Epoch  80: train loss  0.66935 (xe:  0.669)
# 13:19 madminer.utils.ml.tr INFO                 val. loss   0.67659 (xe:  0.677)
# 13:19 madminer.utils.ml.tr INFO      Epoch  85: train loss  0.66889 (xe:  0.669)
# 13:19 madminer.utils.ml.tr INFO                 val. loss   0.67668 (xe:  0.677)
# 13:19 madminer.utils.ml.tr INFO      Epoch  90: train loss  0.66924 (xe:  0.669)
# 13:19 madminer.utils.ml.tr INFO                 val. loss   0.67450 (xe:  0.675)
# 13:19 madminer.utils.ml.tr INFO      Epoch  95: train loss  0.66998 (xe:  0.670)
# 13:19 madminer.utils.ml.tr INFO                 val. loss   0.67350 (xe:  0.673)
# 13:19 madminer.utils.ml.tr INFO      Epoch 100: train loss  0.66949 (xe:  0.669)
# 13:19 madminer.utils.ml.tr INFO                 val. loss   0.67154 (xe:  0.672)
# 13:19 madminer.utils.ml.tr INFO    Early stopping after epoch 62, with loss  0.67015 compared to final loss  0.67154
# 13:19 madminer.utils.ml.tr INFO    Training time spend on:
# 13:19 madminer.utils.ml.tr INFO                      initialize model:   0.00h
# 13:19 madminer.utils.ml.tr INFO                                   ALL:   0.01h
# 13:19 madminer.utils.ml.tr INFO                            check data:   0.00h
# 13:19 madminer.utils.ml.tr INFO                          make dataset:   0.00h
# 13:19 madminer.utils.ml.tr INFO                       make dataloader:   0.00h
# 13:19 madminer.utils.ml.tr INFO                       setup optimizer:   0.00h
# 13:19 madminer.utils.ml.tr INFO                   initialize training:   0.00h
# 13:19 madminer.utils.ml.tr INFO                                set lr:   0.00h
# 13:19 madminer.utils.ml.tr INFO                   load training batch:   0.01h
# 13:19 madminer.utils.ml.tr INFO                        fwd: move data:   0.00h
# 13:19 madminer.utils.ml.tr INFO                   fwd: check for nans:   0.00h
# 13:19 madminer.utils.ml.tr INFO                    fwd: model.forward:   0.00h
# 13:19 madminer.utils.ml.tr INFO                 fwd: calculate losses:   0.00h
# 13:19 madminer.utils.ml.tr INFO                 training forward pass:   0.00h
# 13:19 madminer.utils.ml.tr INFO                   training sum losses:   0.00h
# 13:19 madminer.utils.ml.tr INFO                        opt: zero grad:   0.00h
# 13:19 madminer.utils.ml.tr INFO                         opt: backward:   0.00h
# 13:19 madminer.utils.ml.tr INFO                   opt: clip grad norm:   0.00h
# 13:19 madminer.utils.ml.tr INFO                             opt: step:   0.00h
# 13:19 madminer.utils.ml.tr INFO                        optimizer step:   0.00h
# 13:19 madminer.utils.ml.tr INFO                 load validation batch:   0.00h
# 13:19 madminer.utils.ml.tr INFO               validation forward pass:   0.00h
# 13:19 madminer.utils.ml.tr INFO                 validation sum losses:   0.00h
# 13:19 madminer.utils.ml.tr INFO                        early stopping:   0.00h
# 13:19 madminer.utils.ml.tr INFO                          report epoch:   0.00h
# 13:19 madminer.ml.base     INFO    Saving model to models_close_morph/carl1

# %%
nn = MorphParameterizedRatioEstimator(n_hidden=(20, 20))

loss = nn.train(
    method="alice",
    x="data_close_morph/x_train1.npy",
    y="data_close_morph/y_train1.npy",
    r_xz="data_close_morph/r_xz_train1.npy",
    n_epochs=100,
)

nn.save("models_close_morph/alice1")
# Out:
# 13:19 madminer.ml.paramete INFO    Starting training
# 13:19 madminer.ml.paramete INFO      Method:                 alice
# 13:19 madminer.ml.paramete INFO      Batch size:             128
# 13:19 madminer.ml.paramete INFO      Optimizer:              amsgrad
# 13:19 madminer.ml.paramete INFO      Epochs:                 100
# 13:19 madminer.ml.paramete INFO      Learning rate:          0.001 initially, decaying to 0.0001
# 13:19 madminer.ml.paramete INFO      Validation split:       0.25
# 13:19 madminer.ml.paramete INFO      Early stopping:         True
# 13:19 madminer.ml.paramete INFO      Scale inputs:           True
# 13:19 madminer.ml.paramete INFO      Scale parameters:       True
# 13:19 madminer.ml.paramete INFO      Shuffle labels          False
# 13:19 madminer.ml.paramete INFO      Samples:                all
# 13:19 madminer.ml.paramete INFO    Loading training data
# 13:19 madminer.utils.vario INFO      Loading data_close_morph/x_train1.npy into RAM
# 13:19 madminer.utils.vario INFO      Loading data_close_morph/y_train1.npy into RAM
# 13:19 madminer.utils.vario INFO      Loading data_close_morph/r_xz_train1.npy into RAM
# 13:19 madminer.ml.paramete INFO    Found 20000 samples with 1 observables
# 13:19 madminer.ml.base     INFO    Setting up input rescaling
# 13:19 madminer.ml.paramete INFO    Creating model
# 13:19 madminer.ml.paramete INFO    Training model
# 13:19 madminer.utils.ml.tr INFO    Training on CPU with single precision
# 13:19 madminer.utils.ml.tr INFO      Epoch   5: train loss  0.67174 (improved_xe:  0.672)
# 13:20 madminer.utils.ml.tr INFO                 val. loss   0.67099 (improved_xe:  0.671)
# 13:20 madminer.utils.ml.tr INFO      Epoch  90: train loss  0.67167 (improved_xe:  0.672)
# 13:20 madminer.utils.ml.tr INFO                 val. loss   0.67075 (improved_xe:  0.671)
# 13:20 madminer.utils.ml.tr INFO      Epoch  95: train loss  0.67169 (improved_xe:  0.672)
# 13:20 madminer.utils.ml.tr INFO                 val. loss   0.67084 (improved_xe:  0.671)
# 13:20 madminer.utils.ml.tr INFO      Epoch 100: train loss  0.67170 (improved_xe:  0.672)
# 13:20 madminer.utils.ml.tr INFO                 val. loss   0.67121 (improved_xe:  0.671)
# 13:20 madminer.utils.ml.tr INFO    Early stopping after epoch 8, with loss  0.66956 compared to final loss  0.67121
# 13:20 madminer.utils.ml.tr INFO    Training time spend on:
# 13:20 madminer.utils.ml.tr INFO                      initialize model:   0.00h
# 13:20 madminer.utils.ml.tr INFO                                   ALL:   0.02h
# 13:20 madminer.utils.ml.tr INFO                            check data:   0.00h
# 13:20 madminer.utils.ml.tr INFO                          make dataset:   0.00h
# 13:20 madminer.utils.ml.tr INFO                       make dataloader:   0.00h
# 13:20 madminer.utils.ml.tr INFO                       setup optimizer:   0.00h
# 13:20 madminer.utils.ml.tr INFO                   initialize training:   0.00h
# 13:20 madminer.utils.ml.tr INFO                                set lr:   0.00h
# 13:20 madminer.utils.ml.tr INFO                   load training batch:   0.01h
# 13:20 madminer.utils.ml.tr INFO                        fwd: move data:   0.00h
# 13:20 madminer.utils.ml.tr INFO                   fwd: check for nans:   0.00h
# 13:20 madminer.utils.ml.tr INFO                    fwd: model.forward:   0.00h
# 13:20 madminer.utils.ml.tr INFO                 fwd: calculate losses:   0.00h
# 13:20 madminer.utils.ml.tr INFO                 training forward pass:   0.00h
# 13:20 madminer.utils.ml.tr INFO                   training sum losses:   0.00h
# 13:20 madminer.utils.ml.tr INFO                        opt: zero grad:   0.00h
# 13:20 madminer.utils.ml.tr INFO                         opt: backward:   0.00h
# 13:20 madminer.utils.ml.tr INFO                   opt: clip grad norm:   0.00h
# 13:20 madminer.utils.ml.tr INFO                             opt: step:   0.00h
# 13:20 madminer.utils.ml.tr INFO                        optimizer step:   0.01h
# 13:20 madminer.utils.ml.tr INFO                 load validation batch:   0.00h
# 13:20 madminer.utils.ml.tr INFO               validation forward pass:   0.00h
# 13:20 madminer.utils.ml.tr INFO                 validation sum losses:   0.00h
# 13:20 madminer.utils.ml.tr INFO                        early stopping:   0.00h
# 13:20 madminer.utils.ml.tr INFO                          report epoch:   0.00h
# 13:20 madminer.ml.base     INFO    Saving model to models_close_morph/alice1

# %%
plt.plot(loss[0])
plt.plot(loss[1])

# %%
np.exp(nn.evaluate_log_likelihood_ratio(np.asarray([10,20,30])).detach().numpy())
# Out:
# array([[4.4106297],
#        [5.240001 ],
#        [5.2822943]], dtype=float32)

# %% [markdown]
# ## 4. Generate evaluation data

# %% [markdown]
# Let us now generate some test data, which is sampled corresponding to `theta=1`

# %%
n_param_points_test = 1000  # number of parameter points to test
theta_test = 1.0 * np.ones(shape=n_param_points_test)

# %% [markdown]
# Run the simulator to get observations:

# %%
x_test = []
for t in theta_test:
    x_test.append(simulate(t)[0])
np.save("data_close_morph/x_test.npy", x_test)

# %% [markdown]
# We want to evaluate the expected likelihood ratio on a range of parameter points:

# %%
theta_grid = np.linspace(-5.0, 5.0, 1000).reshape(-1, 1)
np.save("data_close_morph/theta_grid.npy", theta_grid)

# %% [markdown]
# In this toy example, we can calculate the true likelihood ratio. We will save the expected log likelihood ratio (multiplied with a conventional factor of -2):

# %%
all_log_r_test_true = []
nllr_test_true = []

for theta in theta_grid:
    log_r = np.log(calculate_likelihood_ratio(x_test, theta))
    nllr_test_true.append(-2.0 * np.mean(log_r))
    all_log_r_test_true.append(log_r)

all_log_r_test_true = np.asarray(all_log_r_test_true).reshape((1000, n_param_points_test))
nllr_test_true = np.asarray(nllr_test_true)

# %% [markdown]
# ## 5. Evaluation

# %% [markdown]
# It's time to evaluate our likelihood ratio estimators!

# %%
x_test
# Out:
# [1.9432557884079251,
#  2.756629977639294,
#  2.362240685063166,
#  1.751139916612618,
#  -3.9814309522637066,
#  1.8929125835962577,
#  -3.5762103041288684,
#  2.47603294838768,
#  -0.7725077090828305,
#  5.070835000054987,
#  -1.79344689577761,
#  1.297655479871602,
#  -0.7312144704780102,
#  4.929322842299883,
#  1.617791733630684,
#  0.698332142256525,
#  2.3488125548220435,
#  -4.15443643648079,
#  -1.8285171608952069,
#  -2.4664166341273264,
#  4.8216382138268035,
#  6.014779283538511,
#  3.6279782598087786,
#  2.6835135077178633,
#  1.6216094214607681,
#  2.165013065246688,
#  0.7087336071940848,
#  1.1064424099882975,
#  1.924931703100238,
#  2.0889598835392107,
#  0.439852406271785,
#  1.6233412121248043,
#  2.6853331374041884,
#  -3.9678299910370933,
#  4.117533377720212,
#  0.9144643303157014,
#  -1.5956723055946553,
#  4.566076695402833,
#  2.696870838633017,
#  -3.422681079124123,
#  0.4589983350306096,
#  -2.219830880385527,
#  2.2684636218936878,
#  -4.083113785554582,
#  -0.9167339593478759,
#  1.2131505676745946,
#  -0.3688989214177112,
#  -5.214129197576086,
#  1.7098324730528074,
#  1.3739124338777395,
#  -1.2190376289273988,
#  2.30478201373868,
#  4.662014094540284,
#  1.6339135743620796,
#  5.328374196574802,
#  -3.1797397311664017,
#  8.025558219526799,
#  -0.42277244740376774,
#  -0.27222885526773777,
#  2.9248883113007182,
#  0.4103373965220025,
#  -4.301386051217117,
#  -0.7882652249200452,
#  1.3542685438487296,
#  -1.1094327165919957,
#  0.435617941634334,
#  0.9220955242398124,
#  -2.2633874990673615,
#  1.1326094247651524,
#  1.8395668786841242,
#  3.4834775632993367,
#  -0.5582864568538239,
#  -1.7904829289367301,
#  -1.090090094567782,
#  0.36809749178644463,
#  0.12035682631479527,
#  -0.9010784020256843,
#  1.6510155114994376,
#  -2.7084360341475433,
#  3.241840492032872,
#  1.205462097174909,
#  1.433587661455106,
#  0.40994440129485654,
#  -0.5222996982211925,
#  1.4074419676088852,
#  1.0430274357723635,
#  1.6899686036581483,
#  0.6290041848193434,
#  -1.766304938424197,
#  0.21118423668715947,
#  1.3980926168355134,
#  -0.16252619733432683,
#  2.8122514119017303,
#  -0.15241280488326148,
#  -0.6623607771409596,
#  1.620460540849623,
#  -0.20913590519795666,
#  -0.17355725065656746,
#  0.5338385569763364,
#  -5.0605171200855725,
#  4.776996625556018,
#  4.315885796968857,
#  2.026439476671185,
#  2.947404873377255,
#  2.983954162893635,
#  -0.767435289598751,
#  3.206603172803165,
#  5.084968861680417]

# %%
loader1 = MorphParameterizedRatioEstimator(n_hidden=(20, 20))
loader2 = MorphParameterizedRatioEstimator(n_hidden=(20, 20))
loader_alice1 = MorphParameterizedRatioEstimator(n_hidden=(20, 20))
loader_alice2 = MorphParameterizedRatioEstimator(n_hidden=(20, 20))
loader1.load("models_close_morph/carl0")
loader2.load("models_close_morph/carl1")
loader_alice1.load("models_close_morph/alice0")
loader_alice2.load("models_close_morph/alice1")

ratio_1 = np.exp(loader1.evaluate_log_likelihood_ratio(np.asarray(x_test)).detach().numpy())
ratio_2 = np.exp(loader2.evaluate_log_likelihood_ratio(np.asarray(x_test)).detach().numpy())
ratio_alice1 = np.exp(loader_alice1.evaluate_log_likelihood_ratio(np.asarray(x_test)).detach().numpy())
ratio_alice2 = np.exp(loader_alice2.evaluate_log_likelihood_ratio(np.asarray(x_test)).detach().numpy())
# Out:
# 13:20 madminer.ml.base     INFO    Loading model from models_close_morph/carl0
# 13:20 madminer.ml.base     WARNING Parameter scaling information not found in models_close_morph/carl0
# 13:20 madminer.ml.base     INFO    Loading model from models_close_morph/carl1
# 13:20 madminer.ml.base     WARNING Parameter scaling information not found in models_close_morph/carl1
# 13:20 madminer.ml.base     INFO    Loading model from models_close_morph/alice0
# 13:20 madminer.ml.base     WARNING Parameter scaling information not found in models_close_morph/alice0
# 13:20 madminer.ml.base     INFO    Loading model from models_close_morph/alice1
# 13:20 madminer.ml.base     WARNING Parameter scaling information not found in models_close_morph/alice1

# %%
plt.scatter(x_test,ratio_alice1)
plt.hist(x_test,histtype="step",density="True")
plt.hist(x1,histtype="step",density="True")
# Out:
# (array([0.00102551, 0.0070504 , 0.03352145, 0.08704039, 0.15472422,
#         0.16811998, 0.12203601, 0.05063469, 0.01429308, 0.00249969]),
#  array([-8.11111524, -6.55091999, -4.99072474, -3.4305295 , -1.87033425,
#         -0.310139  ,  1.25005625,  2.81025149,  4.37044674,  5.93064199,
#          7.49083723]),
#  [<matplotlib.patches.Polygon at 0x7fdecfb9ebd0>])

# %%
def ratio(ratios1,ratios2,theta,th0,th1):
    matrix = [[1,0,0],
              [1./(1.+th0**2),th0/(1.+th0**2),th0**2/(1.+th0**2)],
              [1./(1.+th1**2),th1/(1.+th1**2),th1**2/(1.+th1**2)]]
    arr = np.asarray([1/(1+theta**2),theta/(1+theta**2),theta**2/(1+theta**2)])
    sh = np.shape(ratios1)[0]
    #print(sh)
    return arr@np.linalg.inv(matrix)@np.asarray([np.ones(sh),ratios1.flatten(),ratios2.flatten()])

# %%
theta_grid
# Out:
# array([[-5.        ],
#        [-4.98998999],
#        [-4.97997998],
#        [-4.96996997],
#        [-4.95995996],
#        [-4.94994995],
#        [-4.93993994],
#        [-4.92992993],
#        [-4.91991992],
#        [-4.90990991],
#        [-4.8998999 ],
#        [-4.88988989],
#        [-4.87987988],
#        [-4.86986987],
#        [-4.85985986],
#        [-4.84984985],
#        [-4.83983984],
#        [-4.82982983],
#        [-4.81981982],
#        [-4.80980981],
#        [-4.7997998 ],
#        [-4.78978979],
#        [-4.77977978],
#        [-4.76976977],
#        [-4.75975976],
#        [-4.74974975],
#        [-4.73973974],
#        [-4.72972973],
#        [-4.71971972],
#        [-4.70970971],
#        [-4.6996997 ],
#        [-4.68968969],
#        [-4.67967968],
#        [-4.66966967],
#        [-4.65965966],
#        [-4.64964965],
#        [-4.63963964],
#        [-4.62962963],
#        [-4.61961962],
#        [-4.60960961],
#        [-4.5995996 ],
#        [-4.58958959],
#        [-4.57957958],
#        [-4.56956957],
#        [-4.55955956],
#        [-4.54954955],
#        [-4.53953954],
#        [-4.52952953],
#        [-4.51951952],
#        [-4.50950951],
#        [-4.4994995 ],
#        [-4.48948949],
#        [-4.47947948],
#        [-4.46946947],
#        [-4.45945946],
#        [-4.44944945],
#        [-4.43943944],
#        [-4.42942943],
#        [-4.41941942],
#        [-4.40940941],
#        [-4.3993994 ],
#        [-4.38938939],
#        [-4.37937938],
#        [-4.36936937],
#        [-4.35935936],
#        [-4.34934935],
#        [-4.33933934],
#        [-4.32932933],
#        [-4.31931932],
#        [-4.30930931],
#        [-4.2992993 ],
#        [-4.28928929],
#        [-4.27927928],
#        [-4.26926927],
#        [-4.25925926],
#        [-4.24924925],
#        [-4.23923924],
#        [-4.22922923],
#        [-4.21921922],
#        [-4.20920921],
#        [-4.1991992 ],
#        [-4.18918919],
#        [-4.17917918],
#        [-4.16916917],
#        [-4.15915916],
#        [-4.14914915],
#        [-4.13913914],
#        [-4.12912913],
#        [-4.11911912],
#        [-4.10910911],
#        [-4.0990991 ],
#        [-4.08908909],
#        [-4.07907908],
#        [-4.06906907],
#        [-4.05905906],
#        [-4.04904905],
#        [-4.03903904],
#        [-4.02902903],
#        [-4.01901902],
#        [-4.00900901],
#        [-3.998999  ],
#        [-3.98898899],
#        [-3.97897898],
#        [-3.96896897],
#        [-3.95895896],
#        [-3.94894895],
#        [-3.93893894],
#        [-3.92892893],
#        [-3.91891892],
#        [-3.90890891],
#        [-3.8988989 ],
#        [-3.88888889],
#        [-3.87887888],
#        [-3.86886887],
#        [-3.85885886],
#        [-3.84884885],
#        [-3.83883884],
#        [-3.82882883],
#        [-3.81881882],
#        [-3.80880881],
#        [-3.7987988 ],
#        [-3.78878879],
#        [-3.77877878],
#        [-3.76876877],
#        [-3.75875876],
#        [-3.74874875],
#        [-3.73873874],
#        [-3.72872873],
#        [-3.71871872],
#        [-3.70870871],
#        [-3.6986987 ],
#        [-3.68868869],
#        [-3.67867868],
#        [-3.66866867],
#        [-3.65865866],
#        [-3.64864865],
#        [-3.63863864],
#        [-3.62862863],
#        [-3.61861862],
#        [-3.60860861],
#        [-3.5985986 ],
#        [-3.58858859],
#        [-3.57857858],
#        [-3.56856857],
#        [-3.55855856],
#        [-3.54854855],
#        [-3.53853854],
#        [-3.52852853],
#        [-3.51851852],
#        [-3.50850851],
#        [-3.4984985 ],
#        [-3.48848849],
#        [-3.47847848],
#        [-3.46846847],
#        [-3.45845846],
#        [-3.44844845],
#        [-3.43843844],
#        [-3.42842843],
#        [-3.41841842],
#        [-3.40840841],
#        [-3.3983984 ],
#        [-3.38838839],
#        [-3.37837838],
#        [-3.36836837],
#        [-3.35835836],
#        [-3.34834835],
#        [-3.33833834],
#        [-3.32832833],
#        [-3.31831832],
#        [-3.30830831],
#        [-3.2982983 ],
#        [-3.28828829],
#        [-3.27827828],
#        [-3.26826827],
#        [-3.25825826],
#        [-3.24824825],
#        [-3.23823824],
#        [-3.22822823],
#        [-3.21821822],
#        [-3.20820821],
#        [-3.1981982 ],
#        [-3.18818819],
#        [-3.17817818],
#        [-3.16816817],
#        [-3.15815816],
#        [-3.14814815],
#        [-3.13813814],
#        [-3.12812813],
#        [-3.11811812],
#        [-3.10810811],
#        [-3.0980981 ],
#        [-3.08808809],
#        [-3.07807808],
#        [-3.06806807],
#        [-3.05805806],
#        [-3.04804805],
#        [-3.03803804],
#        [-3.02802803],
#        [-3.01801802],
#        [-3.00800801],
#        [-2.997998  ],
#        [-2.98798799],
#        [-2.97797798],
#        [-2.96796797],
#        [-2.95795796],
#        [-2.94794795],
#        [-2.93793794],
#        [-2.92792793],
#        [-2.91791792],
#        [-2.90790791],
#        [-2.8978979 ],
#        [-2.88788789],
#        [-2.87787788],
#        [-2.86786787],
#        [-2.85785786],
#        [-2.84784785],
#        [-2.83783784],
#        [-2.82782783],
#        [-2.81781782],
#        [-2.80780781],
#        [-2.7977978 ],
#        [-2.78778779],
#        [-2.77777778],
#        [-2.76776777],
#        [-2.75775776],
#        [-2.74774775],
#        [-2.73773774],
#        [-2.72772773],
#        [-2.71771772],
#        [-2.70770771],
#        [-2.6976977 ],
#        [-2.68768769],
#        [-2.67767768],
#        [-2.66766767],
#        [-2.65765766],
#        [-2.64764765],
#        [-2.63763764],
#        [-2.62762763],
#        [-2.61761762],
#        [-2.60760761],
#        [-2.5975976 ],
#        [-2.58758759],
#        [-2.57757758],
#        [-2.56756757],
#        [-2.55755756],
#        [-2.54754755],
#        [-2.53753754],
#        [-2.52752753],
#        [-2.51751752],
#        [-2.50750751],
#        [-2.4974975 ],
#        [-2.48748749],
#        [-2.47747748],
#        [-2.46746747],
#        [-2.45745746],
#        [-2.44744745],
#        [-2.43743744],
#        [-2.42742743],
#        [-2.41741742],
#        [-2.40740741],
#        [-2.3973974 ],
#        [-2.38738739],
#        [-2.37737738],
#        [-2.36736737],
#        [-2.35735736],
#        [-2.34734735],
#        [-2.33733734],
#        [-2.32732733],
#        [-2.31731732],
#        [-2.30730731],
#        [-2.2972973 ],
#        [-2.28728729],
#        [-2.27727728],
#        [-2.26726727],
#        [-2.25725726],
#        [-2.24724725],
#        [-2.23723724],
#        [-2.22722723],
#        [-2.21721722],
#        [-2.20720721],
#        [-2.1971972 ],
#        [-2.18718719],
#        [-2.17717718],
#        [-2.16716717],
#        [-2.15715716],
#        [-2.14714715],
#        [-2.13713714],
#        [-2.12712713],
#        [-2.11711712],
#        [-2.10710711],
#        [-2.0970971 ],
#        [-2.08708709],
#        [-2.07707708],
#        [-2.06706707],
#        [-2.05705706],
#        [-2.04704705],
#        [-2.03703704],
#        [-2.02702703],
#        [-2.01701702],
#        [-2.00700701],
#        [-1.996997  ],
#        [-1.98698699],
#        [-1.97697698],
#        [-1.96696697],
#        [-1.95695696],
#        [-1.94694695],
#        [-1.93693694],
#        [-1.92692693],
#        [-1.91691692],
#        [-1.90690691],
#        [-1.8968969 ],
#        [-1.88688689],
#        [-1.87687688],
#        [-1.86686687],
#        [-1.85685686],
#        [-1.84684685],
#        [-1.83683684],
#        [-1.82682683],
#        [-1.81681682],
#        [-1.80680681],
#        [-1.7967968 ],
#        [-1.78678679],
#        [-1.77677678],
#        [-1.76676677],
#        [-1.75675676],
#        [-1.74674675],
#        [-1.73673674],
#        [-1.72672673],
#        [-1.71671672],
#        [-1.70670671],
#        [-1.6966967 ],
#        [-1.68668669],
#        [-1.67667668],
#        [-1.66666667],
#        [-1.65665666],
#        [-1.64664665],
#        [-1.63663664],
#        [-1.62662663],
#        [-1.61661662],
#        [-1.60660661],
#        [-1.5965966 ],
#        [-1.58658659],
#        [-1.57657658],
#        [-1.56656657],
#        [-1.55655656],
#        [-1.54654655],
#        [-1.53653654],
#        [-1.52652653],
#        [-1.51651652],
#        [-1.50650651],
#        [-1.4964965 ],
#        [-1.48648649],
#        [-1.47647648],
#        [-1.46646647],
#        [-1.45645646],
#        [-1.44644645],
#        [-1.43643644],
#        [-1.42642643],
#        [-1.41641642],
#        [-1.40640641],
#        [-1.3963964 ],
#        [-1.38638639],
#        [-1.37637638],
#        [-1.36636637],
#        [-1.35635636],
#        [-1.34634635],
#        [-1.33633634],
#        [-1.32632633],
#        [-1.31631632],
#        [-1.30630631],
#        [-1.2962963 ],
#        [-1.28628629],
#        [-1.27627628],
#        [-1.26626627],
#        [-1.25625626],
#        [-1.24624625],
#        [-1.23623624],
#        [-1.22622623],
#        [-1.21621622],
#        [-1.20620621],
#        [-1.1961962 ],
#        [-1.18618619],
#        [-1.17617618],
#        [-1.16616617],
#        [-1.15615616],
#        [-1.14614615],
#        [-1.13613614],
#        [-1.12612613],
#        [-1.11611612],
#        [-1.10610611],
#        [-1.0960961 ],
#        [-1.08608609],
#        [-1.07607608],
#        [-1.06606607],
#        [-1.05605606],
#        [-1.04604605],
#        [-1.03603604],
#        [-1.02602603],
#        [-1.01601602],
#        [-1.00600601],
#        [-0.995996  ],
#        [-0.98598599],
#        [-0.97597598],
#        [-0.96596597],
#        [-0.95595596],
#        [-0.94594595],
#        [-0.93593594],
#        [-0.92592593],
#        [-0.91591592],
#        [-0.90590591],
#        [-0.8958959 ],
#        [-0.88588589],
#        [-0.87587588],
#        [-0.86586587],
#        [-0.85585586],
#        [-0.84584585],
#        [-0.83583584],
#        [-0.82582583],
#        [-0.81581582],
#        [-0.80580581],
#        [-0.7957958 ],
#        [-0.78578579],
#        [-0.77577578],
#        [-0.76576577],
#        [-0.75575576],
#        [-0.74574575],
#        [-0.73573574],
#        [-0.72572573],
#        [-0.71571572],
#        [-0.70570571],
#        [-0.6956957 ],
#        [-0.68568569],
#        [-0.67567568],
#        [-0.66566567],
#        [-0.65565566],
#        [-0.64564565],
#        [-0.63563564],
#        [-0.62562563],
#        [-0.61561562],
#        [-0.60560561],
#        [-0.5955956 ],
#        [-0.58558559],
#        [-0.57557558],
#        [-0.56556557],
#        [-0.55555556],
#        [-0.54554555],
#        [-0.53553554],
#        [-0.52552553],
#        [-0.51551552],
#        [-0.50550551],
#        [-0.4954955 ],
#        [-0.48548549],
#        [-0.47547548],
#        [-0.46546547],
#        [-0.45545546],
#        [-0.44544545],
#        [-0.43543544],
#        [-0.42542543],
#        [-0.41541542],
#        [-0.40540541],
#        [-0.3953954 ],
#        [-0.38538539],
#        [-0.37537538],
#        [-0.36536537],
#        [-0.35535536],
#        [-0.34534535],
#        [-0.33533534],
#        [-0.32532533],
#        [-0.31531532],
#        [-0.30530531],
#        [-0.2952953 ],
#        [-0.28528529],
#        [-0.27527528],
#        [-0.26526527],
#        [-0.25525526],
#        [-0.24524525],
#        [-0.23523524],
#        [-0.22522523],
#        [-0.21521522],
#        [-0.20520521],
#        [-0.1951952 ],
#        [-0.18518519],
#        [-0.17517518],
#        [-0.16516517],
#        [-0.15515516],
#        [-0.14514515],
#        [-0.13513514],
#        [-0.12512513],
#        [-0.11511512],
#        [-0.10510511],
#        [-0.0950951 ],
#        [-0.08508509],
#        [-0.07507508],
#        [-0.06506507],
#        [-0.05505506],
#        [-0.04504505],
#        [-0.03503504],
#        [-0.02502503],
#        [-0.01501502],
#        [-0.00500501],
#        [ 0.00500501],
#        [ 0.01501502],
#        [ 0.02502503],
#        [ 0.03503504],
#        [ 0.04504505],
#        [ 0.05505506],
#        [ 0.06506507],
#        [ 0.07507508],
#        [ 0.08508509],
#        [ 0.0950951 ],
#        [ 0.10510511],
#        [ 0.11511512],
#        [ 0.12512513],
#        [ 0.13513514],
#        [ 0.14514515],
#        [ 0.15515516],
#        [ 0.16516517],
#        [ 0.17517518],
#        [ 0.18518519],
#        [ 0.1951952 ],
#        [ 0.20520521],
#        [ 0.21521522],
#        [ 0.22522523],
#        [ 0.23523524],
#        [ 0.24524525],
#        [ 0.25525526],
#        [ 0.26526527],
#        [ 0.27527528],
#        [ 0.28528529],
#        [ 0.2952953 ],
#        [ 0.30530531],
#        [ 0.31531532],
#        [ 0.32532533],
#        [ 0.33533534],
#        [ 0.34534535],
#        [ 0.35535536],
#        [ 0.36536537],
#        [ 0.37537538],
#        [ 0.38538539],
#        [ 0.3953954 ],
#        [ 0.40540541],
#        [ 0.41541542],
#        [ 0.42542543],
#        [ 0.43543544],
#        [ 0.44544545],
#        [ 0.45545546],
#        [ 0.46546547],
#        [ 0.47547548],
#        [ 0.48548549],
#        [ 0.4954955 ],
#        [ 0.50550551],
#        [ 0.51551552],
#        [ 0.52552553],
#        [ 0.53553554],
#        [ 0.54554555],
#        [ 0.55555556],
#        [ 0.56556557],
#        [ 0.57557558],
#        [ 0.58558559],
#        [ 0.5955956 ],
#        [ 0.60560561],
#        [ 0.61561562],
#        [ 0.62562563],
#        [ 0.63563564],
#        [ 0.64564565],
#        [ 0.65565566],
#        [ 0.66566567],
#        [ 0.67567568],
#        [ 0.68568569],
#        [ 0.6956957 ],
#        [ 0.70570571],
#        [ 0.71571572],
#        [ 0.72572573],
#        [ 0.73573574],
#        [ 0.74574575],
#        [ 0.75575576],
#        [ 0.76576577],
#        [ 0.77577578],
#        [ 0.78578579],
#        [ 0.7957958 ],
#        [ 0.80580581],
#        [ 0.81581582],
#        [ 0.82582583],
#        [ 0.83583584],
#        [ 0.84584585],
#        [ 0.85585586],
#        [ 0.86586587],
#        [ 0.87587588],
#        [ 0.88588589],
#        [ 0.8958959 ],
#        [ 0.90590591],
#        [ 0.91591592],
#        [ 0.92592593],
#        [ 0.93593594],
#        [ 0.94594595],
#        [ 0.95595596],
#        [ 0.96596597],
#        [ 0.97597598],
#        [ 0.98598599],
#        [ 0.995996  ],
#        [ 1.00600601],
#        [ 1.01601602],
#        [ 1.02602603],
#        [ 1.03603604],
#        [ 1.04604605],
#        [ 1.05605606],
#        [ 1.06606607],
#        [ 1.07607608],
#        [ 1.08608609],
#        [ 1.0960961 ],
#        [ 1.10610611],
#        [ 1.11611612],
#        [ 1.12612613],
#        [ 1.13613614],
#        [ 1.14614615],
#        [ 1.15615616],
#        [ 1.16616617],
#        [ 1.17617618],
#        [ 1.18618619],
#        [ 1.1961962 ],
#        [ 1.20620621],
#        [ 1.21621622],
#        [ 1.22622623],
#        [ 1.23623624],
#        [ 1.24624625],
#        [ 1.25625626],
#        [ 1.26626627],
#        [ 1.27627628],
#        [ 1.28628629],
#        [ 1.2962963 ],
#        [ 1.30630631],
#        [ 1.31631632],
#        [ 1.32632633],
#        [ 1.33633634],
#        [ 1.34634635],
#        [ 1.35635636],
#        [ 1.36636637],
#        [ 1.37637638],
#        [ 1.38638639],
#        [ 1.3963964 ],
#        [ 1.40640641],
#        [ 1.41641642],
#        [ 1.42642643],
#        [ 1.43643644],
#        [ 1.44644645],
#        [ 1.45645646],
#        [ 1.46646647],
#        [ 1.47647648],
#        [ 1.48648649],
#        [ 1.4964965 ],
#        [ 1.50650651],
#        [ 1.51651652],
#        [ 1.52652653],
#        [ 1.53653654],
#        [ 1.54654655],
#        [ 1.55655656],
#        [ 1.56656657],
#        [ 1.57657658],
#        [ 1.58658659],
#        [ 1.5965966 ],
#        [ 1.60660661],
#        [ 1.61661662],
#        [ 1.62662663],
#        [ 1.63663664],
#        [ 1.64664665],
#        [ 1.65665666],
#        [ 1.66666667],
#        [ 1.67667668],
#        [ 1.68668669],
#        [ 1.6966967 ],
#        [ 2.96796797],
#        [ 2.97797798],
#        [ 2.98798799],
#        [ 2.997998  ],
#        [ 3.00800801],
#        [ 3.01801802],
#        [ 3.02802803],
#        [ 3.03803804],
#        [ 3.04804805],
#        [ 3.05805806],
#        [ 3.06806807],
#        [ 3.07807808],
#        [ 3.08808809],
#        [ 3.0980981 ],
#        [ 3.10810811],
#        [ 3.11811812],
#        [ 3.12812813],
#        [ 3.13813814],
#        [ 3.14814815],
#        [ 3.15815816],
#        [ 3.16816817],
#        [ 3.17817818],
#        [ 3.18818819],
#        [ 3.1981982 ],
#        [ 3.20820821],
#        [ 3.21821822],
#        [ 3.22822823],
#        [ 3.23823824],
#        [ 3.24824825],
#        [ 3.25825826],
#        [ 3.26826827],
#        [ 3.27827828],
#        [ 3.28828829],
#        [ 3.2982983 ],
#        [ 3.30830831],
#        [ 3.31831832],
#        [ 3.32832833],
#        [ 3.33833834],
#        [ 3.34834835],
#        [ 3.35835836],
#        [ 3.36836837],
#        [ 3.37837838],
#        [ 3.38838839],
#        [ 3.3983984 ],
#        [ 3.40840841],
#        [ 3.41841842],
#        [ 3.42842843],
#        [ 3.43843844],
#        [ 3.44844845],
#        [ 3.45845846],
#        [ 3.46846847],
#        [ 3.47847848],
#        [ 3.48848849],
#        [ 3.4984985 ],
#        [ 3.50850851],
#        [ 3.51851852],
#        [ 3.52852853],
#        [ 3.53853854],
#        [ 3.54854855],
#        [ 3.55855856],
#        [ 3.56856857],
#        [ 3.57857858],
#        [ 3.58858859],
#        [ 3.5985986 ],
#        [ 3.60860861],
#        [ 3.61861862],
#        [ 3.62862863],
#        [ 3.63863864],
#        [ 3.64864865],
#        [ 3.65865866],
#        [ 3.66866867],
#        [ 3.67867868],
#        [ 3.68868869],
#        [ 3.6986987 ],
#        [ 3.70870871],
#        [ 3.71871872],
#        [ 3.72872873],
#        [ 3.73873874],
#        [ 3.74874875],
#        [ 3.75875876],
#        [ 3.76876877],
#        [ 3.77877878],
#        [ 3.78878879],
#        [ 3.7987988 ],
#        [ 3.80880881],
#        [ 3.81881882],
#        [ 3.82882883],
#        [ 3.83883884],
#        [ 3.84884885],
#        [ 3.85885886],
#        [ 3.86886887],
#        [ 3.87887888],
#        [ 3.88888889],
#        [ 3.8988989 ],
#        [ 3.90890891],
#        [ 3.91891892],
#        [ 3.92892893],
#        [ 3.93893894],
#        [ 3.94894895],
#        [ 3.95895896],
#        [ 3.96896897],
#        [ 3.97897898],
#        [ 3.98898899],
#        [ 3.998999  ],
#        [ 4.00900901],
#        [ 4.01901902],
#        [ 4.02902903],
#        [ 4.03903904],
#        [ 4.04904905],
#        [ 4.05905906],
#        [ 4.06906907],
#        [ 4.07907908],
#        [ 4.08908909],
#        [ 4.0990991 ],
#        [ 4.10910911],
#        [ 4.11911912],
#        [ 4.12912913],
#        [ 4.13913914],
#        [ 4.14914915],
#        [ 4.15915916],
#        [ 4.16916917],
#        [ 4.17917918],
#        [ 4.18918919],
#        [ 4.1991992 ],
#        [ 4.20920921],
#        [ 4.21921922],
#        [ 4.22922923],
#        [ 4.23923924],
#        [ 4.24924925],
#        [ 4.25925926],
#        [ 4.26926927],
#        [ 4.27927928],
#        [ 4.28928929],
#        [ 4.2992993 ],
#        [ 4.30930931],
#        [ 4.31931932],
#        [ 4.32932933],
#        [ 4.33933934],
#        [ 4.34934935],
#        [ 4.35935936],
#        [ 4.36936937],
#        [ 4.37937938],
#        [ 4.38938939],
#        [ 4.3993994 ],
#        [ 4.40940941],
#        [ 4.41941942],
#        [ 4.42942943],
#        [ 4.43943944],
#        [ 4.44944945],
#        [ 4.45945946],
#        [ 4.46946947],
#        [ 4.47947948],
#        [ 4.48948949],
#        [ 4.4994995 ],
#        [ 4.50950951],
#        [ 4.51951952],
#        [ 4.52952953],
#        [ 4.53953954],
#        [ 4.54954955],
#        [ 4.55955956],
#        [ 4.56956957],
#        [ 4.57957958],
#        [ 4.58958959],
#        [ 4.5995996 ],
#        [ 4.60960961],
#        [ 4.61961962],
#        [ 4.62962963],
#        [ 4.63963964],
#        [ 4.64964965],
#        [ 4.65965966],
#        [ 4.66966967],
#        [ 4.67967968],
#        [ 4.68968969],
#        [ 4.6996997 ],
#        [ 4.70970971],
#        [ 4.71971972],
#        [ 4.72972973],
#        [ 4.73973974],
#        [ 4.74974975],
#        [ 4.75975976],
#        [ 4.76976977],
#        [ 4.77977978],
#        [ 4.78978979],
#        [ 4.7997998 ],
#        [ 4.80980981],
#        [ 4.81981982],
#        [ 4.82982983],
#        [ 4.83983984],
#        [ 4.84984985],
#        [ 4.85985986],
#        [ 4.86986987],
#        [ 4.87987988],
#        [ 4.88988989],
#        [ 4.8998999 ],
#        [ 4.90990991],
#        [ 4.91991992],
#        [ 4.92992993],
#        [ 4.93993994],
#        [ 4.94994995],
#        [ 4.95995996],
#        [ 4.96996997],
#        [ 4.97997998],
#        [ 4.98998999],
#        [ 5.        ]])

# %%
thetas = np.linspace(-5.0, 5.0, 1000)
means_alice = []
means_carl = []
for t in thetas:
    rs_carl = (ratio(ratio_1,ratio_2,t,-4,4))
    mask_carl = rs_carl > 0
    rs_carl = rs_carl[mask_carl]
    rs_alice = (ratio(ratio_alice1,ratio_alice2,t,-4,4))
    mask_alice = rs_alice > 0
    rs_alice = rs_alice[mask_alice]
    means_alice.append(-2*np.mean(np.log(rs_alice)))
    means_carl.append(-2*np.mean(np.log(rs_carl)))

# %% [markdown]
# This is the expected log likelihood ratio over parameter space:

# %%
fig = plt.figure(figsize=(5, 5))

plt.plot(
    theta_grid,
    nllr_test_true,
    ls="--",
    c="black",
    label=r"Ground truth ($\theta = 1.0$)",
)
plt.plot(
    theta_grid,
    means_carl,
    c="red",
    label=r"morph carl",
)
plt.plot(
    theta_grid,
    means_alice,
    c="blue",
    label=r"morph alice",
)
plt.xlabel(r"$\theta$")
plt.ylabel(r"$\mathbb{E}_x [ -2\, \log \,r(x | \theta, \theta_{1}) ]$")

plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# You should see that the new ALICES approach leads to a better approximation of the true likelihood ratio than the CARL estimate. Note that we only trained in the parameter range (-4, 4), so the deviations at the left and right of the plot are to be expected.
