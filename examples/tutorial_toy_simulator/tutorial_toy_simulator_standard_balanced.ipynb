# %% [markdown]
# # Toy example
#
# Original notebook by Alexander Held, edited for the MadMiner repository by Johann Brehmer, Irina Espejo, Felix Kling, and Kyle Cranmer 2018-2019.

# %% [markdown]
# In this notebook, we use a simple toy example to demonstrate the machine learning and inference algorithms in MadMiner. This allows us to skip many of the more technical steps, and there's no dependency on MadGraph, Pythia, or Delphes.
#
# What this tutorial does not do, is explaining the inference methods. To understand what's happening, please have a look at ["Constraining Effective Field Theories With Machine Learning"](https://arxiv.org/abs/1805.00013), which will explain the basic idea in just a few pages. If you really want to get down to the dirty details, ["A Guide to Constraining Effective Field Theories With Machine Learning"](https://arxiv.org/abs/1805.00020) has you covered.

# %% [markdown]
# ## Preparations

# %%
import os
import logging
import numpy as np
from scipy.stats import norm
from matplotlib import pyplot as plt

# %matplotlib inline
import sys
sys.path.append('/remote/gpu02/crescenzo/MadMiner')

from madminer.ml import ParameterizedRatioEstimator

# %%
if not os.path.exists("data_standard_balanced"):
    os.makedirs("data_standard_balanced")

# %% [markdown]
# MadMiner uses the Python `logging` module to provide additional information and debugging output. You can choose how much of this output you want to see by switching the level in the following lines to `logging.DEBUG` or `logging.WARNING`.

# %%
# MadMiner output
logging.basicConfig(
    format="%(asctime)-5.5s %(name)-20.20s %(levelname)-7.7s %(message)s",
    datefmt="%H:%M",
    level=logging.INFO,
)

# Output of all other modules (e.g. matplotlib)
for key in logging.Logger.manager.loggerDict:
    if "madminer" not in key:
        logging.getLogger(key).setLevel(logging.WARNING)

# %% [markdown]
# ## 1. A toy simulator

# %% [markdown]
# Our simulator depends on just one parameter `theta` and produces one-dimensional observables `x`. It is characterized by one latent variable `z`. "Running" the simulator consists of two steps:
# - "Hard process": a value of `z` is drawn from a normal distribution, where the mean depends on `theta`.
# - "Detector": a value for `x` is drawn from a normal distribution with mean equal to `z`. There is no explicit dependence on `theta`.
#
# As in the particle physics case, we assume that we can calculate the joint likelihood ratio `r(x, z | theta0, theta1)` as well as the joint score `t(x, z | theta)`, which depend explicitly on `z` (and where the "detector" part cancels).
#
# Here are some general settings (feel free to play with them):

# %%
z_std = 2.0
x_std = 1.0

# %% [markdown]
# The following function runs the simulator for a value of `theta` and calculates the joint likelihood ratio between `theta0` and `theta1` as well as the joint score at `theta_score`:

# %%
alpha=2

# %%
npoints = 100

# %%
theta = 100

# %%
z1 = np.random.normal(loc=0, scale=z_std, size=npoints)
z2 = np.random.normal(loc=alpha, scale=z_std, size=npoints)
mask = np.random.choice([True, False],p=[1./(1+theta**2),theta**2/(1+theta**2)],size=npoints)

# %%
z1[mask].flatten()
# Out:
# array([], dtype=float64)

# %%
np.concatenate((z1[mask],z2[~mask]))
# Out:
# array([ 3.64195124,  4.42126917,  1.13755182,  3.61702879,  2.41902341,
#        -0.12712017,  2.29961951,  1.48014508,  1.22900316,  3.58106801,
#         2.11612862,  5.13498608,  1.77612454,  4.80402102,  2.54817377,
#         0.42231255,  0.19276364,  1.14336838,  2.70447866, -0.52725583,
#         4.9208628 ,  0.26185271, -0.92272495,  3.93322407,  2.56012963,
#         4.13359428,  4.44273608,  1.91907588,  0.53726114,  0.88214919,
#         2.12282218,  0.45346303,  2.23370899,  2.1273272 ,  0.7639656 ,
#         1.23843999,  4.02893178, -2.02136713,  4.12468985,  1.11358155,
#         3.06259589,  0.25067458,  4.59243808, -0.44433329,  3.77642293,
#         0.86056733,  3.36723024, -0.10584546,  2.46750314,  2.68610459,
#         3.15328434,  3.79717921,  0.95871687,  1.11602704,  3.65134567,
#         2.01730766,  0.68497083,  2.18194446,  1.48190829, -2.04118243,
#         0.3021329 , -2.86425533,  1.65992946, -0.02840931, -1.54965541,
#         3.2358769 ,  1.46493027,  0.55661881,  2.69931025,  5.02614434,
#        -2.81025384,  3.19741944,  1.36688651, -1.38552927, -0.0363335 ,
#         4.48003613,  2.21051156,  1.393926  ,  3.50039058,  2.75331917,
#         2.90107931, -0.0431197 ,  2.75258034,  1.69011082, -0.46648945,
#         0.1572733 ,  0.94116928,  2.06926074,  4.32693689,  4.45708423,
#         1.39930254,  2.83899234,  2.83914102,  4.32487962,  3.89796913,
#         4.38935333,  0.92533049,  1.48744033,  5.03800937,  2.70925736])

# %%
np.random.choice([True,False],p = [0.5,0.5],size = None)
# Out:
# True

# %%
def simulate(theta, theta0=None, theta1=None, theta_score=None, npoints=None):
    # Draw latent variables z
    z1 = np.random.normal(loc=0, scale=z_std, size=npoints)
    z2 = np.random.normal(loc=alpha, scale=z_std, size=npoints)
    mask = np.random.choice([True, False],p=[1./(1+theta**2),theta**2/(1+theta**2)],size=npoints)
    try:
        z = np.concatenate((z1[mask],z2[~mask]))
    except:
        if mask:
            z = z1
        else:
            z = z2
    # Draw observables x
    x = np.random.normal(loc=z, scale=x_std, size=None)

    # Calculate joint likelihood ratio and joint score
    if theta0 is not None and theta1 is not None:
        r_xz = (norm(loc=theta1, scale=z_std).pdf(z)+(theta0**2)*norm(loc=alpha, scale=z_std).pdf(z) )/ ((1+theta0**2)*norm(loc=theta1, scale=z_std).pdf(z))
    else:
        r_xz = None

    if theta_score is not None:
        t_xz = (x - theta_score) / z_std**2
    else:
        t_xz = None

    return x, r_xz, t_xz

# %% [markdown]
# Usually the likelihood function `p(x|theta)` is intractable, but in this toy example it is just given by the convolution of two Gaussians, which is again a Gaussian. We will use this to validate the results later:

# %%
def calculate_likelihood_ratio(x, theta0, theta1=0.0):
    combined_std = (z_std**2 + x_std**2) ** 0.5
    r_x = (norm(loc=theta1, scale=combined_std).pdf(x)+(theta0**2)*norm(loc=alpha, scale=combined_std).pdf(x) )/ ((1+theta0**2)*norm(loc=theta1, scale=combined_std).pdf(x))
    return r_x

# %% [markdown]
# Let's now visualize that: we run the simulation and plot the probability distributions $p(x | \theta_i)$. Additionally, we also plot the true log-likelihood ratio $\log\,r(x|\theta_0,\theta_1)$.

# %%
x0, _, _ = simulate(100, npoints=10000)
x1, _, _ = simulate(0, npoints=10000)

xr = np.linspace(-20.0, 300.0, 100)
rx = np.log(calculate_likelihood_ratio(xr, 100, 0))

fig, ax1 = plt.subplots()
fig.set_size_inches(5, 5)
ax1.set_xlabel("$x$")
ax1.hist(x0, bins=50, range=(-20, 20.0), histtype="step", label=r"$p(x | \theta_0)$", density=True)
ax1.hist(x1, bins=50, range=(-20, 20.0), histtype="step", label=r"$p(x | \theta_1)$", density=True)
ax1.set_ylabel(r"$p(x|\theta)$")
ax1.legend(loc=2)

ax2 = ax1.twinx()
ax2.plot(xr, rx, color="black", label=r"$\log\,r(x|\theta_0,\theta_1)$")
ax2.set_ylabel(r"$\log\,r(x|\theta_0,\theta_1)$")
ax2.legend(loc=1)

plt.show()
# Out:
# /tmp/ipykernel_2555922/413034781.py:3: RuntimeWarning: divide by zero encountered in divide
#   r_x = (norm(loc=theta1, scale=combined_std).pdf(x)+(theta0**2)*norm(loc=alpha, scale=combined_std).pdf(x) )/ ((1+theta0**2)*norm(loc=theta1, scale=combined_std).pdf(x))
# /tmp/ipykernel_2555922/413034781.py:3: RuntimeWarning: invalid value encountered in divide
#   r_x = (norm(loc=theta1, scale=combined_std).pdf(x)+(theta0**2)*norm(loc=alpha, scale=combined_std).pdf(x) )/ ((1+theta0**2)*norm(loc=theta1, scale=combined_std).pdf(x))

# %%
x0.shape
# Out:
# (10000,)

# %% [markdown]
# ## 2. Run the simulation and generate training data

# %% [markdown]
# First, we define the parameter points we want to use for training: `theta0` is uniformly distributed while the reference model `theta1` is fixed at zero.

# %%
# number of parameter points to train
n_param_points = 50000

# numerator, uniform prior
theta0 = np.random.uniform(low=-4.0, high=4.0, size=n_param_points)

# denominator: fixed at 0
theta1 = np.zeros(shape=n_param_points)

# %% [markdown]
# We then run the simulator (one sample per parameter point). Remember that `simulate(theta, theta0, theta1, theta_score)` generates data `x` following a theory with `theta` and then evaluates the joint likelihood ratio `r(x,z|theta0,theta1)` and the join score `t(x,z|theta_score)` for each data point.

# %%
# Sample from theta0
x_from_theta0 = []
r_xz_from_theta0 = []
t_xz_from_theta0 = []
x_from_theta1 = []
r_xz_from_theta1 = []
t_xz_from_theta1 = []
for t in theta0:
    out = simulate(t, t, 0., t)
    x_from_theta0.append(out[0])
    r_xz_from_theta0.append(out[1])
    t_xz_from_theta0.append(out[2])
print("Done first sim")
for t,_ in zip(theta1,theta0):
    out = simulate(t, _, t, _)
    x_from_theta1.append(out[0])
    r_xz_from_theta1.append(out[1])
    t_xz_from_theta1.append(out[2])
# Out:
# Done first sim

# %%
r_xz_from_theta1
# Out:
# [0.39000173559357737,
#  3.561626246275815,
#  0.32838035275789396,
#  0.6391127675685032,
#  0.23778050795006936,
#  1.6550882240609177,
#  0.952424387786975,
#  0.8844797366324934,
#  0.5973082472539044,
#  5.264756541613628,
#  0.7288325205284368,
#  1.1779832361220073,
#  0.9927408631426728,
#  1.037916974887204,
#  1.160332706210927,
#  1.1410938033595937,
#  1.7030233940365047,
#  0.5849387130558106,
#  0.2570099858936402,
#  0.3955746607646469,
#  2.434264712743606,
#  0.7214831964927514,
#  0.2420767217065161,
#  0.2118423648453777,
#  0.48645503895109465,
#  0.8375588109933026,
#  0.6946582999119022,
#  1.0322552299889463,
#  1.097008505050144,
#  0.3387309134124022,
#  1.297073257506119,
#  0.9986992374900052,
#  0.4370559605326078,
#  1.1250803779489316,
#  0.4867875441379993,
#  0.9953602266970748,
#  0.5375166190272676,
#  1.682429190528112,
#  0.7291963848128541,
#  0.8775758805524532,
#  0.21709851834898936,
#  1.2480341469367675,
#  0.4790369183745298,
#  1.1648604593133145,
#  0.7380576478590612,
#  0.9995702273121014,
#  0.9894482116544318,
#  0.9742179991668649,
#  0.5544133288879276,
#  0.4343349949608051,
#  1.104172600281797,
#  0.21642656280428524,
#  0.41861931113673384,
#  0.7069749015320361,
#  0.6853474493099593,
#  1.0208749501382737,
#  1.0318280956062882,
#  2.1331761676761514,
#  15.897994416826323,
#  0.8024351576095857,
#  1.325483017454597,
#  0.2811748312472409,
#  1.0904002424988852,
#  0.2986715352042944,
#  1.228514811491882,
#  0.661417641929898,
#  1.0179325801328087,
#  0.1629389870686902,
#  1.5794491019938905,
#  1.051970157021238,
#  2.325987712458429,
#  2.539295543828407,
#  0.8025300407869157,
#  0.3556899144239943,
#  0.7648708849762368,
#  6.843258979502936,
#  0.9902238875795923,
#  2.2574331495664604,
#  0.42729160547600464,
#  1.0373148648137018,
#  1.1990447182906994,
#  0.9156482710424809,
#  0.3417625816039037,
#  0.8738846035845034,
#  0.9105251476984471,
#  0.45249603662001886,
#  0.49926926886870965,
#  0.5707571568106823,
#  0.45238389870442847,
#  0.3094289332311075,
#  0.1676515671899288,
#  0.7360997547610916,
#  0.8711165576858174,
#  0.43402735325871555,
#  0.28157821814446987,
#  1.6049936354689904,
#  0.5613913469313119,
#  1.2305635949137586,
#  0.8593411567741466,
#  0.9970909985376796,
#  0.20312025109722398,
#  0.45157200171667217,
#  0.7600546192889508,
#  0.30518832789295,
#  0.9684727960126159,
#  1.0281526558080516,
#  1.0198327268568226,
#  0.3953095968135313,
#  1.9485300435561952,
#  0.3644970914340197,
#  0.9062523931110208,
#  0.31922154515248935,
#  1.181184585888461,
#  0.7666405492643644,
#  0.8656820382515251,
#  0.6841115891467985,
#  0.4253404025361009,
#  1.1716496110751644,
#  0.8104151467450683,
#  0.8673716478805461,
#  2.4371099581009283,
#  0.21458752890528937,
#  0.61512734541887,
#  0.9435543257691847,
#  0.21708180936382807,
#  0.968769658912744,
#  0.8626293965784055,
#  0.7876794065708312,
#  3.241662402788346,
#  1.5694322738986655,
#  1.0695288402583787,
#  1.0050980542154366,
#  1.1602394774195255,
#  0.7709413017548961,
#  0.47556581109711066,
#  2.0595439223682313,
#  0.8658752336710038,
#  1.0136291043159684,
#  0.9044711672709642,
#  1.4395166943332565,
#  1.194421322310587,
#  0.3877755058561949,
#  1.2844402978682217,
#  0.9323697633369293,
#  0.3339728872697429,
#  2.0850767014555753,
#  0.415068206451979,
#  0.33897210323236787,
#  3.0302097140034623,
#  1.1251113804268338,
#  2.565997687987213,
#  1.01271521057308,
#  1.0020855116011678,
#  1.3514911672204704,
#  0.8328302676147015,
#  1.13468735025103,
#  0.5510833692258607,
#  0.7662533448331385,
#  1.6500230645303813,
#  1.5226719021684447,
#  0.9673606988353707,
#  0.7384028025162058,
#  0.40389298601008117,
#  0.7579676505093292,
#  0.8215018879556045,
#  0.3492954682347087,
#  0.7669140656611002,
#  0.45015982520786757,
#  0.284807297657586,
#  0.7973347386698016,
#  0.8152373090505608,
#  1.089153424365967,
#  1.1282579946693685,
#  0.534121352675935,
#  0.8006773189408317,
#  0.8015921744183456,
#  0.9303038023960978,
#  0.3394983030246918,
#  0.835049533281644,
#  0.9999337237814614,
#  2.343563983594214,
#  0.6609881952158793,
#  0.3740378560691265,
#  0.9910318413161354,
#  4.405829709491576,
#  0.6729378692446002,
#  0.9899804281775769,
#  0.6055629351896803,
#  0.19035623493252235,
#  0.9940195549202939,
#  1.0580065174695352,
#  0.3353791551462202,
#  0.5837833336302573,
#  0.8859814495699585,
#  0.39276530722068886,
#  1.719107091174856,
#  1.114502567069139,
#  0.7107672666040548,
#  1.1275890280154865,
#  0.3072167494689358,
#  0.8910255520598845,
#  0.3172232881969508,
#  1.371997357334868,
#  2.526431345128674,
#  1.0974532130514179,
#  0.8016547756414087,
#  0.5539779671397539,
#  1.667644709599521,
#  0.8324034261840129,
#  0.46070888133176946,
#  1.4030980334272498,
#  0.6571579254181796,
#  0.4671317632703932,
#  0.823497422189927,
#  0.3312003393071728,
#  1.8604955111397479,
#  0.4136550756883866,
#  1.0311184771862345,
#  0.4075303724770234,
#  0.8785417637466556,
#  0.4977654869149214,
#  0.9310880598231875,
#  0.29787398729218323,
#  0.6992832509679664,
#  1.1956643551680328,
#  3.5463937464425395,
#  0.43631928381805507,
#  0.09911439214282373,
#  0.7756212259819636,
#  0.9773654885007966,
#  1.3334375528805928,
#  0.19093230222770438,
#  1.047394106446033,
#  0.5083515667364316,
#  0.8265658260258654,
#  0.9992083425993151,
#  0.4906810443425934,
#  4.081867125386584,
#  0.9914816909321691,
#  0.8212270718762893,
#  1.3097827463871357,
#  0.8487778790927045,
#  0.42727882470007045,
#  0.8307026104726221,
#  0.6134449756215453,
#  0.9544453709841478,
#  2.1123901963668943,
#  0.8267541788141445,
#  1.4965159267599517,
#  0.735733050106967,
#  0.5497125621116148,
#  5.177173817585657,
#  0.9678906221095036,
#  1.3733936052621414,
#  0.5609353468789251,
#  1.087153120620982,
#  0.5412058812375808,
#  2.9340070527652578,
#  0.40558905725004696,
#  0.9395431263656724,
#  0.9505152613571527,
#  1.0973250685459808,
#  0.26445884144031606,
#  1.028812985679482,
#  0.9932851178318083,
#  3.4268458682047824,
#  0.30744960746883276,
#  4.537502193469365,
#  0.8406625781922007,
#  1.527339161471317,
#  1.0056332034971391,
#  0.31419048244218056,
#  1.5693871554556513,
#  0.9747729065300574,
#  0.7799042970473643,
#  0.9621200273758737,
#  0.8324226454902168,
#  0.9756908989081275,
#  1.0050961315951934,
#  0.6548266265272288,
#  1.0012305055898842,
#  0.6700609897137064,
#  0.7189952306448186,
#  0.9085924328002902,
#  0.17444437658172476,
#  0.9977714092712159,
#  0.6718995721782706,
#  0.4966878262396784,
#  0.34900254748356146,
#  0.9872003286116631,
#  2.983049190590502,
#  1.0066838587738571,
#  0.38525895654426434,
#  0.21004983005826044,
#  0.8606739915910326,
#  1.1278293749776824,
#  0.8685508718078693,
#  1.6138551865393023,
#  0.5684725844857824,
#  0.315536263040925,
#  0.6135981282487432,
#  0.9386275872572633,
#  0.399235752365831,
#  2.7666911057805037,
#  0.6602973443012444,
#  0.42018404226741185,
#  0.9549058895224214,
#  0.7992737211110984,
#  0.23172019458868856,
#  2.5957965257637596,
#  0.9533878842536774,
#  0.6156530489409175,
#  0.29054858919797155,
#  0.7881791847583863,
#  0.6581384811021758,
#  1.0708884782114076,
#  0.5077278283819184,
#  0.7085679375768453,
#  0.29111953609627994,
#  0.6508072152592446,
#  0.927605971053745,
#  0.6742199975373314,
#  1.5901712709028204,
#  0.5964790961088055,
#  0.8757208367781968,
#  0.9947769349445049,
#  1.2793705503567425,
#  0.6031770974471775,
#  0.5307028871404633,
#  1.4034378754317174,
#  1.180274050812991,
#  0.8446273842624348,
#  1.001295159831853,
#  0.6788342001115959,
#  0.6855750420878293,
#  0.3646726368496243,
#  0.7450221165549642,
#  0.9755115154338547,
#  1.2353056515570642,
#  0.9156649268837185,
#  0.9784098070110778,
#  0.43384074423930724,
#  0.9341273141555473,
#  1.026963356728607,
#  0.7053159792206802,
#  1.1092918253788526,
#  0.5914389770000796,
#  1.0470422461289721,
#  1.6641522572141032,
#  0.706579067651717,
#  0.7748534594280283,
#  0.7614648634471081,
#  0.9061083026315376,
#  0.8436234197248527,
#  1.0763940486711685,
#  0.6386553088635235,
#  0.41439048121421374,
#  0.7235698340190619,
#  2.579374937726705,
#  1.079858884745678,
#  0.9531660665709232,
#  0.3025434752325932,
#  0.8896055822706979,
#  0.3785262926734352,
#  0.8562588856946962,
#  0.18097861276635194,
#  1.0160126602754316,
#  0.854682207855298,
#  2.2387852430952777,
#  0.5529679556903586,
#  0.8535284284993979,
#  0.672937611300154,
#  0.38108369357684324,
#  0.5023359438808235,
#  0.6233329557862851,
#  0.8299729238233927,
#  1.0143028268624714,
#  1.4205830006660023,
#  1.0192419194589808,
#  0.9574843065527129,
#  0.38878104767041216,
#  0.855865861629531,
#  0.5254369915584236,
#  3.767240719508706,
#  1.3023890903707376,
#  2.6601905192621507,
#  0.5636690888458956,
#  2.165849453375738,
#  0.9238625775329351,
#  0.4670221593241714,
#  0.18054985369188348,
#  0.6257914570013366,
#  0.981421648236988,
#  0.36549734597132477,
#  0.7335279786223051,
#  0.4047023190215167,
#  2.372877879953218,
#  2.490851498477631,
#  0.617611508198008,
#  0.7827311499998619,
#  0.9485698238057053,
#  0.5821886282563767,
#  0.40480737257570026,
#  0.5398915789005481,
#  1.1907148601773336,
#  0.4392515965689288,
#  0.9999999072122912,
#  0.9760872283961357,
#  0.3672473193465793,
#  1.0083301104182043,
#  0.6204077018299036,
#  0.9894606420944972,
#  0.4147857762865492,
#  0.44587507993769937,
#  0.821646063880665,
#  0.4999765194840875,
#  1.383461173407446,
#  0.9861288882726994,
#  0.38586572123704616,
#  0.31061582184470293,
#  0.9483522945214498,
#  0.8471214396011328,
#  0.9209038605092562,
#  0.6751718008631932,
#  1.0000338504312944,
#  0.3903327905732817,
#  0.9138560674204954,
#  0.4520823434504945,
#  0.8002349136557088,
#  0.8564328097733416,
#  0.8930593111022647,
#  0.3196030319142352,
#  1.1445159846413064,
#  2.59156229580609,
#  0.8833773060556012,
#  0.26720264610002087,
#  0.5732052218269446,
#  4.3201224804083305,
#  0.978750772309126,
#  2.0513481547553996,
#  0.5650884204802781,
#  0.9766325088538302,
#  1.701852498557648,
#  0.8730411828902613,
#  1.2177711292000106,
#  0.501113595333921,
#  1.106649727743654,
#  0.7478627306656954,
#  0.4140421691644392,
#  0.8265934439967646,
#  0.746618023367329,
#  0.4762070623254177,
#  1.7181255065557883,
#  0.9698460761683078,
#  0.43295705336553086,
#  0.24942111008495133,
#  0.9941470650594503,
#  1.0747539643153718,
#  1.0156105800582997,
#  0.9941980090431746,
#  0.8939004473880598,
#  0.9536800554080781,
#  1.26934426470169,
#  0.575369556432278,
#  0.5230515955715134,
#  0.14865026731007655,
#  0.17721426767322623,
#  0.618338965835454,
#  0.42862915547900804,
#  1.9175455253008533,
#  3.112791895654231,
#  0.18401846730671065,
#  0.9733516982284587,
#  0.7151175316903132,
#  1.2267728866428964,
#  0.25171336566261543,
#  1.1921191771792734,
#  1.4340737779823391,
#  0.8462128166143248,
#  0.7061274879949853,
#  0.496900595414023,
#  0.6078876045176558,
#  0.42565877272716923,
#  0.8116769918162601,
#  0.16749430463351037,
#  0.6681764053993718,
#  1.0228968701952852,
#  0.4227417816092941,
#  0.36119930673186756,
#  0.7517863413988851,
#  1.7888859617471695,
#  0.9997443360824334,
#  0.3254932809294385,
#  0.2278919423263881,
#  0.6636840222627067,
#  0.8655257745500446,
#  0.9766437658558433,
#  0.8755432971193938,
#  2.9224005605923247,
#  1.40786995610397,
#  0.4004569637817442,
#  0.938107652905374,
#  1.316677029996464,
#  0.7651104413017735,
#  0.5580933946657594,
#  1.0079988885114315,
#  1.7754458807248996,
#  0.36936874474696435,
#  0.8785369106496554,
#  0.5953046353390291,
#  3.1845399806678167,
#  1.0434681112567172,
#  0.3249985264883114,
#  0.9063553115279459,
#  0.5233380032469733,
#  0.17153137019546125,
#  0.35254678956410956,
#  2.312143427565695,
#  1.2677991195028855,
#  0.9551092805100467,
#  0.526213827336824,
#  0.9986983969387975,
#  1.3177540012930118,
#  0.5996368109537891,
#  0.39047233566312683,
#  0.576980881323259,
#  0.9506749040666743,
#  0.8362175358199091,
#  2.155231317700537,
#  0.44432694147930235,
#  0.5287505204098565,
#  1.4197171709676841,
#  0.814374127898178,
#  0.559351584402311,
#  0.31374541594968364,
#  0.8557017082268643,
#  0.5382840374129443,
#  3.7329243791069904,
#  0.4149154377470883,
#  0.685739045961904,
#  0.5792033802647512,
#  1.1533298295901404,
#  1.3269084809748966,
#  0.1999227249732671,
#  1.0800553627583547,
#  0.5249079669540405,
#  1.021117263284383,
#  0.8924835832017853,
#  1.3916210813432606,
#  2.282106081332618,
#  0.6183238323693253,
#  0.24606957176637975,
#  0.6475616932890692,
#  0.9747183185124294,
#  0.9153876399198402,
#  0.16690011525027662,
#  0.4152808033998885,
#  0.41967005635221305,
#  0.883734820878233,
#  0.8467777062787528,
#  0.8072463875516404,
#  1.1185065251200756,
#  1.2096634454504407,
#  0.5828624591964638,
#  2.345793587196378,
#  0.3584171485990526,
#  0.4043739604241775,
#  0.3485424714820424,
#  0.17433911771740285,
#  1.4081765904043217,
#  0.26278966099879014,
#  0.9488239945065579,
#  0.1581026477163646,
#  1.6623919879450955,
#  0.21997488678867996,
#  0.2599869361276558,
#  2.262545262857709,
#  1.190260170400301,
#  0.8475305885862519,
#  1.3215318654834052,
#  0.4474418867016021,
#  0.7476669302575552,
#  0.30462209215673447,
#  0.24970258122659544,
#  0.24344136396613253,
#  0.5200819725769685,
#  0.3949761591954002,
#  1.9757062480674819,
#  0.9374518116508807,
#  0.9981759034902279,
#  1.020237104524313,
#  0.6440485556344069,
#  1.6123805780227976,
#  3.5986385143132233,
#  0.8773989013734089,
#  1.9204551280537754,
#  0.5153341832229463,
#  0.2134395273567558,
#  0.12762047771118323,
#  0.33831685702917497,
#  0.5503746784021397,
#  1.171539509599252,
#  0.699370172395581,
#  0.36928257703507744,
#  0.9092095354557854,
#  1.7382959238798286,
#  0.1393001123894064,
#  0.7653017856212209,
#  0.4205238692789024,
#  0.7249069402610882,
#  0.8304603471800394,
#  0.26761098726241866,
#  0.17823765331463085,
#  1.1708764770289959,
#  3.597478513518131,
#  0.9935160698861281,
#  0.9994283914805242,
#  0.8020312595630928,
#  0.527090337436411,
#  0.20292465465356058,
#  1.0104801399447045,
#  1.0778082868244376,
#  0.6124629703191409,
#  0.1628448985722844,
#  0.29501304273268364,
#  0.4686403720836431,
#  0.563504346135824,
#  0.592139923054737,
#  0.591048054693327,
#  0.6771846478704557,
#  0.7412633896202393,
#  0.9140071549430286,
#  0.548891075802292,
#  0.9107004105264965,
#  1.0014596634200843,
#  0.7516267958695031,
#  0.7187827184856939,
#  3.006412847622946,
#  1.0922934891084506,
#  1.7283792002698528,
#  1.243645134534032,
#  1.1707029693415711,
#  1.2230503965833557,
#  1.0515432917546519,
#  0.9174848106553674,
#  0.6580330559668985,
#  0.4627263311234843,
#  2.1934168286791813,
#  1.1147201072165123,
#  0.883802470945528,
#  0.29765718160542604,
#  0.9980018553233676,
#  0.18335461876559128,
#  0.5552799759507553,
#  1.343714157472655,
#  1.94033503941565,
#  0.7150394803656859,
#  1.8749487217690834,
#  0.40735719298074785,
#  0.3352519579171042,
#  0.7638772913073254,
#  2.160990687017033,
#  2.26022138685145,
#  0.45685472914116054,
#  0.9351787326491788,
#  0.8792958709864519,
#  0.4128495973478178,
#  0.8806996923877218,
#  0.2065991285807969,
#  1.3558173278364194,
#  1.7859771510417257,
#  0.22854635436150492,
#  0.7261504489208311,
#  0.2848962513769109,
#  0.2358923078842095,
#  0.4923689363054307,
#  0.7894763571340458,
#  0.6315364982901156,
#  0.9070013820285869,
#  0.9963572047073557,
#  0.41898861319388114,
#  0.25923939462799656,
#  1.2004638620970574,
#  0.5016833182289163,
#  1.4447044783197787,
#  0.8057025974188244,
#  0.7015902154323809,
#  0.4841590299122297,
#  0.7930465100706514,
#  0.2044421990581534,
#  0.5776618494415972,
#  0.4919824694459046,
#  0.3912669699502258,
#  0.4834720446901504,
#  1.003052866917816,
#  0.8670119656057852,
#  1.4085433415037454,
#  0.44223851055869207,
#  0.9467714665611197,
#  0.7132873226947796,
#  0.7802018395261738,
#  0.9720953623789305,
#  0.9965241218669179,
#  0.3228079211170911,
#  0.5401129612620736,
#  0.2817900503659256,
#  1.3603551442734407,
#  1.047587963179936,
#  0.6788303133088232,
#  0.461608851132301,
#  0.7835241921653504,
#  0.49398057375871646,
#  0.4858075134979839,
#  0.3239850420513582,
#  2.177313279431832,
#  1.5811796331280927,
#  0.352673069304042,
#  0.3298430597553654,
#  0.26228026306152985,
#  0.5951244344122242,
#  1.6846879323235422,
#  0.40042049497989307,
#  3.154017177282739,
#  1.1459875862040816,
#  1.042192465691122,
#  0.22993641888921343,
#  1.2175691109825124,
#  2.535861526132533,
#  1.0079154594671058,
#  0.7859735684943185,
#  0.8557812969889206,
#  3.4213377453945117,
#  0.5298195002429283,
#  0.7330494177182282,
#  1.259377336695041,
#  1.5018686910110193,
#  0.5494793069004583,
#  0.5246416405414059,
#  0.3725581939921808,
#  0.6978628438331569,
#  0.27524389566050783,
#  0.6845142933478104,
#  0.9548177826201728,
#  0.9919463523986564,
#  0.8463093374430136,
#  1.216214092209406,
#  0.25742561303842315,
#  1.060346645703664,
#  0.7819180351872427,
#  0.6423491269388948,
#  0.6698994890002224,
#  0.5043911197903269,
#  0.5390692046636436,
#  0.6160857524288842,
#  0.5115711501203521,
#  1.0243010920964268,
#  1.797450565785358,
#  0.39112237093348,
#  0.7914991330086599,
#  1.3139530801410326,
#  0.29736610344887404,
#  0.4222896673693761,
#  0.45897521791278817,
#  1.8912623781572113,
#  0.35108528098617015,
#  0.8885299031898348,
#  0.40802128517294806,
#  1.2622504978380997,
#  0.39499643178713006,
#  1.8816648535546006,
#  0.5219756421442311,
#  0.9989853583391345,
#  0.6696412086289972,
#  0.9405135370513438,
#  0.5235665835341663,
#  0.858646214723163,
#  0.8482553526253825,
#  0.9200280458674852,
#  0.4310996243170111,
#  1.1555257892059034,
#  0.6121652380492002,
#  0.5663040766170335,
#  0.5415564256603517,
#  0.5004019603119123,
#  0.6689706564986598,
#  0.9451407938091312,
#  0.609444805100275,
#  0.28114799777166954,
#  0.6441917284457865,
#  0.39180128524190044,
#  0.18016432643763813,
#  0.3800679144134852,
#  1.2615482973174301,
#  1.0407758636891362,
#  0.876325833444656,
#  0.5222838989911477,
#  0.9882436374484533,
#  0.8568791352098928,
#  1.8143843078022341,
#  0.8756828327347089,
#  0.20161677026585223,
#  0.497527838063601,
#  0.3090802883289905,
#  0.6043246238897924,
#  0.3912156108493575,
#  0.6697887694095956,
#  0.9234403815500101,
#  5.641779009891056,
#  0.2922572590001162,
#  0.7885640596624033,
#  0.34165478047133724,
#  0.2990830897534381,
#  0.8898258649072612,
#  0.9708263743475702,
#  1.0202916805102682,
#  0.5914991126638599,
#  1.3628736474596508,
#  1.4371651295843852,
#  1.9235133876924755,
#  1.6068872466831288,
#  1.722460898197365,
#  0.5860519120714206,
#  1.014013029296508,
#  1.5440986043592932,
#  3.0569386835256864,
#  0.4047435912965326,
#  0.6179045666632231,
#  0.3438760661397851,
#  1.307661336396204,
#  1.4110751343658425,
#  0.5375392512578917,
#  0.9842120908514518,
#  0.5559455060087379,
#  1.3216671317856983,
#  0.5152422254112596,
#  0.6431796435162873,
#  0.8964861732929277,
#  0.8662451019133324,
#  2.2504950543328697,
#  0.43536241261231035,
#  0.6149398320327657,
#  0.641939425711818,
#  0.47515190103000976,
#  0.5623071067913951,
#  0.7325422001548632,
#  1.469496858692522,
#  0.2342651886133014,
#  0.29516695431360995,
#  0.7307872335941723,
#  3.2315595714979284,
#  0.48747090008105476,
#  0.8774904435951195,
#  1.0196185227913757,
#  1.1690433347298437,
#  0.4253871889392291,
#  0.43578814379017633,
#  0.2399335737858049,
#  1.6510127367992073,
#  0.5702647018567228,
#  0.6432349283982751,
#  0.5182357909958198,
#  0.23277759712050822,
#  0.4633380788083788,
#  1.1259506717485896,
#  0.8950997199301669,
#  0.9958096503014576,
#  0.42918229786982526,
#  2.486441227244123,
#  1.625988510555455,
#  1.236470544394412,
#  1.10729218099122,
#  0.9295616730593168,
#  0.18451086566472222,
#  0.8898112808053307,
#  0.6063279000002002,
#  0.8778136350970523,
#  1.083819307463205,
#  0.7690868194408043,
#  1.2945821707544813,
#  0.6844014894913903,
#  0.6980666027609347,
#  0.9030099005382003,
#  0.4666673188275946,
#  0.46631310491152345,
#  0.8188845273202824,
#  0.5902163876842942,
#  0.4835697992876901,
#  0.9124663214270057,
#  1.4756523389967187,
#  1.7423388736202825,
#  0.27385633907913093,
#  0.4593961693981937,
#  0.34011298049899574,
#  0.6474917195703743,
#  0.8737774653242352,
#  0.912585150775965,
#  0.5234794093999403,
#  0.9867540781785465,
#  1.796315309364816,
#  0.5838423303075523,
#  1.2511075448608735,
#  0.8339626999569972,
#  0.4197610822722734,
#  1.0060206133152028,
#  0.24076065844829367,
#  0.544943040538672,
#  1.1303541314789407,
#  0.7393111371384173,
#  0.8950667545926115,
#  2.117353171747815,
#  0.4915503146315146,
#  1.0105666118111034,
#  2.735507028766238,
#  0.9992432556544041,
#  0.583449379244662,
#  1.977998969671988,
#  0.63405658055227,
#  0.5448094187593567,
#  0.21326002850913642,
#  0.6202626090553409,
#  1.3020849296762846,
#  0.38510447644051754,
#  1.3914620253018066,
#  0.9949323901458232,
#  0.6867572299623809,
#  0.9923775012078212,
#  2.1404358970792305,
#  0.8227205756913619,
#  0.1812432427199143,
#  0.6222538948542292,
#  0.35058477118010495,
#  0.49275138648345834,
#  0.709583087427667,
#  0.6318974532668015,
#  0.3653161908631954,
#  0.6168449080181314,
#  0.5268841377709133,
#  0.811325052992853,
#  0.7206835900262296,
#  1.1630947016964983,
#  2.5899624115989544,
#  1.8880187605503762,
#  0.5010415511741021,
#  0.3826152608634869,
#  0.8743039793655882,
#  0.29153825577352294,
#  0.7436570738003723,
#  0.6757583111833798,
#  1.4584637543741132,
#  0.6633451792638627,
#  0.9543301957453134,
#  1.5472388553125227,
#  0.5122170576237557,
#  1.10550770716664,
#  0.5487379702886235,
#  3.3795049515382876,
#  1.0788673474159953,
#  0.29114370997828487,
#  0.3951609743233781,
#  1.110986948711624,
#  4.081612122304319,
#  0.20652562994530976,
#  0.4468246742009183,
#  0.6791637839696144,
#  0.7049839524172519,
#  0.8521957697802665,
#  0.9001948799058604,
#  0.7006292369557394,
#  0.3390300834332097,
#  0.5241199473993945,
#  0.18013006030668388,
#  1.0424098927216268,
#  1.6563481724236446,
#  2.925243041186511,
#  1.4422084235618913,
#  1.7407441327017596,
#  0.6664975183816494,
#  0.4775077128333626,
#  0.3607474064397963,
#  0.5828980023976836,
#  1.0072248681192622,
#  1.1647755341012271,
#  0.31780541810704904,
#  1.072245133191957,
#  0.9306716460214137,
#  0.8103869870160367,
#  1.0490165680047316,
#  0.30291702072348936,
#  0.6834469908771417,
#  0.587453904134897,
#  1.7210808958129402,
#  0.785413323653792,
#  1.0516172193500664,
#  1.9957751321651345,
#  2.4992370540760787,
#  1.1588682737462503,
#  0.9747332312966493,
#  0.18772222030963498,
#  1.1844375856587452,
#  2.0188002806189673,
#  ...]

# %% [markdown]
# Now we combine and reshape the results (nothing interesting happening here) and save everything to files, so that we can load it later.

# %%
# Combine results and reshape
x_train = np.hstack((x_from_theta0, x_from_theta1)).reshape(-1, 1)
r_xz_train = np.hstack((r_xz_from_theta0, r_xz_from_theta1)).reshape(-1, 1)
t_xz_train = np.hstack((t_xz_from_theta0, t_xz_from_theta1)).reshape(-1, 1)
y_train = np.hstack((np.zeros_like(x_from_theta0), np.ones_like(np.ones_like(x_from_theta1)))).reshape(-1, 1)
theta0_train = np.hstack((theta0, theta0)).reshape(-1, 1)

# Save to file
np.save("data_standard_balanced/theta0_train.npy", theta0_train)
np.save("data_standard_balanced/x_train.npy", x_train)
np.save("data_standard_balanced/y_train.npy", y_train)
np.save("data_standard_balanced/r_xz_train.npy", r_xz_train)
np.save("data_standard_balanced/t_xz_train.npy", t_xz_train)

# %%
theta0_train.shape
# Out:
# (100000, 1)

# %% [markdown]
# ## 3. Model training

# %% [markdown]
# Let's train two neural networks to estimate the likelihood ratio. For one we use the CARL method introduced in ["Approximating Likelihood Ratios with Calibrated Discriminative Classifiers"](https://arxiv.org/abs/1506.02169), for the other the new ALICES method introduced in ["Likelihood-free inference with an improved cross-entropy estimator"](https://arxiv.org/abs/1808.00973).

# %%
carl = ParameterizedRatioEstimator(n_hidden=(20, 20))

carl.train(
    method="carl",
    x="data_standard_balanced/x_train.npy",
    y="data_standard_balanced/y_train.npy",
    theta="data_standard_balanced/theta0_train.npy",
    n_epochs=20,
)

carl.save("models_standard_balancedcarl")
# Out:
# 11:56 madminer.ml.paramete INFO    Starting training
# 11:56 madminer.ml.paramete INFO      Method:                 carl
# 11:56 madminer.ml.paramete INFO      Batch size:             128
# 11:56 madminer.ml.paramete INFO      Optimizer:              amsgrad
# 11:56 madminer.ml.paramete INFO      Epochs:                 20
# 11:56 madminer.ml.paramete INFO      Learning rate:          0.001 initially, decaying to 0.0001
# 11:56 madminer.ml.paramete INFO      Validation split:       0.25
# 11:56 madminer.ml.paramete INFO      Early stopping:         True
# 11:56 madminer.ml.paramete INFO      Scale inputs:           True
# 11:56 madminer.ml.paramete INFO      Scale parameters:       True
# 11:56 madminer.ml.paramete INFO      Shuffle labels          False
# 11:56 madminer.ml.paramete INFO      Samples:                all
# 11:56 madminer.ml.paramete INFO    Loading training data
# 11:56 madminer.utils.vario INFO      Loading data/theta0_train.npy into RAM
# 11:56 madminer.utils.vario INFO      Loading data/x_train.npy into RAM
# 11:56 madminer.utils.vario INFO      Loading data/y_train.npy into RAM
# 11:56 madminer.ml.paramete INFO    Found 100000 samples with 1 parameters and 1 observables
# 11:56 madminer.ml.base     INFO    Setting up input rescaling
# 11:56 madminer.ml.paramete INFO    Rescaling parameters
# 11:56 madminer.ml.base     INFO    Setting up parameter rescaling
# 11:56 madminer.ml.paramete INFO    Creating model
# 11:56 madminer.ml.paramete INFO    Training model
# 11:56 madminer.utils.ml.tr INFO    Training on CPU with single precision
# 11:56 madminer.utils.ml.tr INFO      Epoch   1: train loss  0.65814 (xe:  0.658)
# 11:56 madminer.utils.ml.tr INFO                 val. loss   0.65471 (xe:  0.655)
# 11:56 madminer.utils.ml.tr INFO      Epoch   2: train loss  0.65468 (xe:  0.655)
# 11:56 madminer.utils.ml.tr INFO                 val. loss   0.65370 (xe:  0.654)
# 11:56 madminer.utils.ml.tr INFO      Epoch   3: train loss  0.65354 (xe:  0.654)
# 11:56 madminer.utils.ml.tr INFO                 val. loss   0.65388 (xe:  0.654)
# 11:56 madminer.utils.ml.tr INFO      Epoch   4: train loss  0.65227 (xe:  0.652)
# 11:56 madminer.utils.ml.tr INFO                 val. loss   0.65147 (xe:  0.651)
# 11:56 madminer.utils.ml.tr INFO      Epoch   5: train loss  0.65065 (xe:  0.651)
# 11:56 madminer.utils.ml.tr INFO                 val. loss   0.65039 (xe:  0.650)
# 11:56 madminer.utils.ml.tr INFO      Epoch   6: train loss  0.64944 (xe:  0.649)
# 11:56 madminer.utils.ml.tr INFO                 val. loss   0.64828 (xe:  0.648)
# 11:56 madminer.utils.ml.tr INFO      Epoch   7: train loss  0.64860 (xe:  0.649)
# 11:56 madminer.utils.ml.tr INFO                 val. loss   0.64823 (xe:  0.648)
# 11:56 madminer.utils.ml.tr INFO      Epoch   8: train loss  0.64828 (xe:  0.648)
# 11:56 madminer.utils.ml.tr INFO                 val. loss   0.64821 (xe:  0.648)
# 11:56 madminer.utils.ml.tr INFO      Epoch   9: train loss  0.64803 (xe:  0.648)
# 11:56 madminer.utils.ml.tr INFO                 val. loss   0.64774 (xe:  0.648)
# 11:56 madminer.utils.ml.tr INFO      Epoch  10: train loss  0.64787 (xe:  0.648)
# 11:56 madminer.utils.ml.tr INFO                 val. loss   0.64765 (xe:  0.648)
# 11:56 madminer.utils.ml.tr INFO      Epoch  11: train loss  0.64766 (xe:  0.648)
# 11:56 madminer.utils.ml.tr INFO                 val. loss   0.64726 (xe:  0.647)
# 11:56 madminer.utils.ml.tr INFO      Epoch  12: train loss  0.64758 (xe:  0.648)
# 11:56 madminer.utils.ml.tr INFO                 val. loss   0.64785 (xe:  0.648)
# 11:56 madminer.utils.ml.tr INFO      Epoch  13: train loss  0.64752 (xe:  0.648)
# 11:56 madminer.utils.ml.tr INFO                 val. loss   0.64745 (xe:  0.647)
# 11:56 madminer.utils.ml.tr INFO      Epoch  14: train loss  0.64743 (xe:  0.647)
# 11:56 madminer.utils.ml.tr INFO                 val. loss   0.64746 (xe:  0.647)
# 11:56 madminer.utils.ml.tr INFO      Epoch  15: train loss  0.64740 (xe:  0.647)
# 11:56 madminer.utils.ml.tr INFO                 val. loss   0.64709 (xe:  0.647)
# 11:56 madminer.utils.ml.tr INFO      Epoch  16: train loss  0.64735 (xe:  0.647)
# 11:56 madminer.utils.ml.tr INFO                 val. loss   0.64749 (xe:  0.647)
# 11:56 madminer.utils.ml.tr INFO      Epoch  17: train loss  0.64728 (xe:  0.647)
# 11:56 madminer.utils.ml.tr INFO                 val. loss   0.64707 (xe:  0.647)
# 11:56 madminer.utils.ml.tr INFO      Epoch  18: train loss  0.64722 (xe:  0.647)
# 11:56 madminer.utils.ml.tr INFO                 val. loss   0.64739 (xe:  0.647)
# 11:56 madminer.utils.ml.tr INFO      Epoch  19: train loss  0.64719 (xe:  0.647)
# 11:56 madminer.utils.ml.tr INFO                 val. loss   0.64719 (xe:  0.647)
# 11:56 madminer.utils.ml.tr INFO      Epoch  20: train loss  0.64717 (xe:  0.647)
# 11:56 madminer.utils.ml.tr INFO                 val. loss   0.64719 (xe:  0.647)
# 11:56 madminer.utils.ml.tr INFO    Early stopping after epoch 17, with loss  0.64707 compared to final loss  0.64719
# 11:56 madminer.utils.ml.tr INFO    Training time spend on:
# 11:56 madminer.utils.ml.tr INFO                      initialize model:   0.00h
# 11:56 madminer.utils.ml.tr INFO                                   ALL:   0.02h
# 11:56 madminer.utils.ml.tr INFO                            check data:   0.00h
# 11:56 madminer.utils.ml.tr INFO                          make dataset:   0.00h
# 11:56 madminer.utils.ml.tr INFO                       make dataloader:   0.00h
# 11:56 madminer.utils.ml.tr INFO                       setup optimizer:   0.00h
# 11:56 madminer.utils.ml.tr INFO                   initialize training:   0.00h
# 11:56 madminer.utils.ml.tr INFO                                set lr:   0.00h
# 11:56 madminer.utils.ml.tr INFO                   load training batch:   0.01h
# 11:56 madminer.utils.ml.tr INFO                        fwd: move data:   0.00h
# 11:56 madminer.utils.ml.tr INFO                   fwd: check for nans:   0.00h
# 11:56 madminer.utils.ml.tr INFO                    fwd: model.forward:   0.00h
# 11:56 madminer.utils.ml.tr INFO                 fwd: calculate losses:   0.00h
# 11:56 madminer.utils.ml.tr INFO                 training forward pass:   0.00h
# 11:56 madminer.utils.ml.tr INFO                   training sum losses:   0.00h
# 11:56 madminer.utils.ml.tr INFO                        opt: zero grad:   0.00h
# 11:56 madminer.utils.ml.tr INFO                         opt: backward:   0.00h
# 11:56 madminer.utils.ml.tr INFO                   opt: clip grad norm:   0.00h
# 11:56 madminer.utils.ml.tr INFO                             opt: step:   0.00h
# 11:56 madminer.utils.ml.tr INFO                        optimizer step:   0.00h
# 11:56 madminer.utils.ml.tr INFO                 load validation batch:   0.00h
# 11:56 madminer.utils.ml.tr INFO               validation forward pass:   0.00h
# 11:56 madminer.utils.ml.tr INFO                 validation sum losses:   0.00h
# 11:56 madminer.utils.ml.tr INFO                        early stopping:   0.00h
# 11:56 madminer.utils.ml.tr INFO                          report epoch:   0.00h
# 11:56 madminer.ml.base     INFO    Saving model to models/carl

# %%
alices = ParameterizedRatioEstimator(n_hidden=(20, 20))

alices.train(
    method="alice",
    x="data_standard_balanced/x_train.npy",
    y="data_standard_balanced/y_train.npy",
    theta="data_standard_balanced/theta0_train.npy",
    r_xz="data_standard_balanced/r_xz_train.npy",
    t_xz="data_standard_balanced/t_xz_train.npy",
    alpha=0.1,
    n_epochs=20,
)

alices.save("models_standard_balancedalices")
# Out:
# 11:56 madminer.ml.paramete INFO    Starting training
# 11:56 madminer.ml.paramete INFO      Method:                 alice
# 11:56 madminer.ml.paramete INFO      Batch size:             128
# 11:56 madminer.ml.paramete INFO      Optimizer:              amsgrad
# 11:56 madminer.ml.paramete INFO      Epochs:                 20
# 11:56 madminer.ml.paramete INFO      Learning rate:          0.001 initially, decaying to 0.0001
# 11:56 madminer.ml.paramete INFO      Validation split:       0.25
# 11:56 madminer.ml.paramete INFO      Early stopping:         True
# 11:56 madminer.ml.paramete INFO      Scale inputs:           True
# 11:56 madminer.ml.paramete INFO      Scale parameters:       True
# 11:56 madminer.ml.paramete INFO      Shuffle labels          False
# 11:56 madminer.ml.paramete INFO      Samples:                all
# 11:56 madminer.ml.paramete INFO    Loading training data
# 11:56 madminer.utils.vario INFO      Loading data/theta0_train.npy into RAM
# 11:56 madminer.utils.vario INFO      Loading data/x_train.npy into RAM
# 11:56 madminer.utils.vario INFO      Loading data/y_train.npy into RAM
# 11:56 madminer.utils.vario INFO      Loading data/r_xz_train.npy into RAM
# 11:56 madminer.utils.vario INFO      Loading data/t_xz_train.npy into RAM
# 11:56 madminer.ml.paramete INFO    Found 100000 samples with 1 parameters and 1 observables
# 11:56 madminer.ml.base     INFO    Setting up input rescaling
# 11:56 madminer.ml.paramete INFO    Rescaling parameters
# 11:56 madminer.ml.base     INFO    Setting up parameter rescaling
# 11:56 madminer.ml.paramete INFO    Creating model
# 11:56 madminer.ml.paramete INFO    Training model
# 11:56 madminer.utils.ml.tr INFO    Training on CPU with single precision
# 11:57 madminer.utils.ml.tr INFO      Epoch   1: train loss  0.65445 (improved_xe:  0.654)
# 11:57 madminer.utils.ml.tr INFO                 val. loss   0.64769 (improved_xe:  0.648)
# 11:57 madminer.utils.ml.tr INFO      Epoch   2: train loss  0.64647 (improved_xe:  0.646)
# 11:57 madminer.utils.ml.tr INFO                 val. loss   0.64597 (improved_xe:  0.646)
# 11:57 madminer.utils.ml.tr INFO      Epoch   3: train loss  0.64548 (improved_xe:  0.645)
# 11:57 madminer.utils.ml.tr INFO                 val. loss   0.64502 (improved_xe:  0.645)
# 11:57 madminer.utils.ml.tr INFO      Epoch   4: train loss  0.64525 (improved_xe:  0.645)
# 11:57 madminer.utils.ml.tr INFO                 val. loss   0.64487 (improved_xe:  0.645)
# 11:57 madminer.utils.ml.tr INFO      Epoch   5: train loss  0.64511 (improved_xe:  0.645)
# 11:57 madminer.utils.ml.tr INFO                 val. loss   0.64494 (improved_xe:  0.645)
# 11:57 madminer.utils.ml.tr INFO      Epoch   6: train loss  0.64505 (improved_xe:  0.645)
# 11:57 madminer.utils.ml.tr INFO                 val. loss   0.64484 (improved_xe:  0.645)
# 11:57 madminer.utils.ml.tr INFO      Epoch   7: train loss  0.64500 (improved_xe:  0.645)
# 11:57 madminer.utils.ml.tr INFO                 val. loss   0.64480 (improved_xe:  0.645)
# 11:57 madminer.utils.ml.tr INFO      Epoch   8: train loss  0.64498 (improved_xe:  0.645)
# 11:57 madminer.utils.ml.tr INFO                 val. loss   0.64476 (improved_xe:  0.645)
# 11:57 madminer.utils.ml.tr INFO      Epoch   9: train loss  0.64495 (improved_xe:  0.645)
# 11:57 madminer.utils.ml.tr INFO                 val. loss   0.64462 (improved_xe:  0.645)
# 11:57 madminer.utils.ml.tr INFO      Epoch  10: train loss  0.64493 (improved_xe:  0.645)
# 11:57 madminer.utils.ml.tr INFO                 val. loss   0.64468 (improved_xe:  0.645)
# 11:57 madminer.utils.ml.tr INFO      Epoch  11: train loss  0.64493 (improved_xe:  0.645)
# 11:57 madminer.utils.ml.tr INFO                 val. loss   0.64464 (improved_xe:  0.645)
# 11:57 madminer.utils.ml.tr INFO      Epoch  12: train loss  0.64492 (improved_xe:  0.645)
# 11:57 madminer.utils.ml.tr INFO                 val. loss   0.64468 (improved_xe:  0.645)
# 11:57 madminer.utils.ml.tr INFO      Epoch  13: train loss  0.64491 (improved_xe:  0.645)
# 11:57 madminer.utils.ml.tr INFO                 val. loss   0.64464 (improved_xe:  0.645)
# 11:57 madminer.utils.ml.tr INFO      Epoch  14: train loss  0.64490 (improved_xe:  0.645)
# 11:57 madminer.utils.ml.tr INFO                 val. loss   0.64464 (improved_xe:  0.645)
# 11:57 madminer.utils.ml.tr INFO      Epoch  15: train loss  0.64490 (improved_xe:  0.645)
# 11:57 madminer.utils.ml.tr INFO                 val. loss   0.64462 (improved_xe:  0.645)
# 11:57 madminer.utils.ml.tr INFO      Epoch  16: train loss  0.64489 (improved_xe:  0.645)
# 11:57 madminer.utils.ml.tr INFO                 val. loss   0.64466 (improved_xe:  0.645)
# 11:57 madminer.utils.ml.tr INFO      Epoch  17: train loss  0.64489 (improved_xe:  0.645)
# 11:57 madminer.utils.ml.tr INFO                 val. loss   0.64464 (improved_xe:  0.645)
# 11:57 madminer.utils.ml.tr INFO      Epoch  18: train loss  0.64489 (improved_xe:  0.645)
# 11:57 madminer.utils.ml.tr INFO                 val. loss   0.64474 (improved_xe:  0.645)
# 11:57 madminer.utils.ml.tr INFO      Epoch  19: train loss  0.64489 (improved_xe:  0.645)
# 11:57 madminer.utils.ml.tr INFO                 val. loss   0.64465 (improved_xe:  0.645)
# 11:58 madminer.utils.ml.tr INFO      Epoch  20: train loss  0.64488 (improved_xe:  0.645)
# 11:58 madminer.utils.ml.tr INFO                 val. loss   0.64454 (improved_xe:  0.645)
# 11:58 madminer.utils.ml.tr INFO    Early stopping did not improve performance
# 11:58 madminer.utils.ml.tr INFO    Training time spend on:
# 11:58 madminer.utils.ml.tr INFO                      initialize model:   0.00h
# 11:58 madminer.utils.ml.tr INFO                                   ALL:   0.02h
# 11:58 madminer.utils.ml.tr INFO                            check data:   0.00h
# 11:58 madminer.utils.ml.tr INFO                          make dataset:   0.00h
# 11:58 madminer.utils.ml.tr INFO                       make dataloader:   0.00h
# 11:58 madminer.utils.ml.tr INFO                       setup optimizer:   0.00h
# 11:58 madminer.utils.ml.tr INFO                   initialize training:   0.00h
# 11:58 madminer.utils.ml.tr INFO                                set lr:   0.00h
# 11:58 madminer.utils.ml.tr INFO                   load training batch:   0.01h
# 11:58 madminer.utils.ml.tr INFO                        fwd: move data:   0.00h
# 11:58 madminer.utils.ml.tr INFO                   fwd: check for nans:   0.00h
# 11:58 madminer.utils.ml.tr INFO                    fwd: model.forward:   0.00h
# 11:58 madminer.utils.ml.tr INFO                 fwd: calculate losses:   0.00h
# 11:58 madminer.utils.ml.tr INFO                 training forward pass:   0.00h
# 11:58 madminer.utils.ml.tr INFO                   training sum losses:   0.00h
# 11:58 madminer.utils.ml.tr INFO                        opt: zero grad:   0.00h
# 11:58 madminer.utils.ml.tr INFO                         opt: backward:   0.00h
# 11:58 madminer.utils.ml.tr INFO                   opt: clip grad norm:   0.00h
# 11:58 madminer.utils.ml.tr INFO                             opt: step:   0.00h
# 11:58 madminer.utils.ml.tr INFO                        optimizer step:   0.00h
# 11:58 madminer.utils.ml.tr INFO                 load validation batch:   0.00h
# 11:58 madminer.utils.ml.tr INFO               validation forward pass:   0.00h
# 11:58 madminer.utils.ml.tr INFO                 validation sum losses:   0.00h
# 11:58 madminer.utils.ml.tr INFO                        early stopping:   0.00h
# 11:58 madminer.utils.ml.tr INFO                          report epoch:   0.00h
# 11:58 madminer.ml.base     INFO    Saving model to models/alices

# %% [markdown]
# We can also try a little bit of mixing and matching -- let's train a model with CARL first and then with ALICES:

# %%
mix = ParameterizedRatioEstimator(n_hidden=(20, 20))

mix.train(
    method="carl",
    x="data_standard_balanced/x_train.npy",
    y="data_standard_balanced/y_train.npy",
    theta="data_standard_balanced/theta0_train.npy",
    n_epochs=10,
    initial_lr=0.001,
    final_lr=0.0003,
)

mix.train(
    method="alice",
    x="data_standard_balanced/x_train.npy",
    y="data_standard_balanced/y_train.npy",
    theta="data_standard_balanced/theta0_train.npy",
    r_xz="data_standard_balanced/r_xz_train.npy",
    t_xz="data_standard_balanced/t_xz_train.npy",
    alpha=0.1,
    n_epochs=10,
    initial_lr=0.0003,
    final_lr=0.0001,
)

mix.save("models_standard_balancedmix")
# Out:
# 11:58 madminer.ml.paramete INFO    Starting training
# 11:58 madminer.ml.paramete INFO      Method:                 carl
# 11:58 madminer.ml.paramete INFO      Batch size:             128
# 11:58 madminer.ml.paramete INFO      Optimizer:              amsgrad
# 11:58 madminer.ml.paramete INFO      Epochs:                 10
# 11:58 madminer.ml.paramete INFO      Learning rate:          0.001 initially, decaying to 0.0003
# 11:58 madminer.ml.paramete INFO      Validation split:       0.25
# 11:58 madminer.ml.paramete INFO      Early stopping:         True
# 11:58 madminer.ml.paramete INFO      Scale inputs:           True
# 11:58 madminer.ml.paramete INFO      Scale parameters:       True
# 11:58 madminer.ml.paramete INFO      Shuffle labels          False
# 11:58 madminer.ml.paramete INFO      Samples:                all
# 11:58 madminer.ml.paramete INFO    Loading training data
# 11:58 madminer.utils.vario INFO      Loading data/theta0_train.npy into RAM
# 11:58 madminer.utils.vario INFO      Loading data/x_train.npy into RAM
# 11:58 madminer.utils.vario INFO      Loading data/y_train.npy into RAM
# 11:58 madminer.ml.paramete INFO    Found 100000 samples with 1 parameters and 1 observables
# 11:58 madminer.ml.base     INFO    Setting up input rescaling
# 11:58 madminer.ml.paramete INFO    Rescaling parameters
# 11:58 madminer.ml.base     INFO    Setting up parameter rescaling
# 11:58 madminer.ml.paramete INFO    Creating model
# 11:58 madminer.ml.paramete INFO    Training model
# 11:58 madminer.utils.ml.tr INFO    Training on CPU with single precision
# 11:58 madminer.utils.ml.tr INFO      Epoch   1: train loss  0.65685 (xe:  0.657)
# 11:58 madminer.utils.ml.tr INFO                 val. loss   0.65551 (xe:  0.656)
# 11:58 madminer.utils.ml.tr INFO      Epoch   2: train loss  0.65261 (xe:  0.653)
# 11:58 madminer.utils.ml.tr INFO                 val. loss   0.65365 (xe:  0.654)
# 11:58 madminer.utils.ml.tr INFO      Epoch   3: train loss  0.65075 (xe:  0.651)
# 11:58 madminer.utils.ml.tr INFO                 val. loss   0.65345 (xe:  0.653)
# 11:58 madminer.utils.ml.tr INFO      Epoch   4: train loss  0.64951 (xe:  0.650)
# 11:58 madminer.utils.ml.tr INFO                 val. loss   0.65166 (xe:  0.652)
# 11:58 madminer.utils.ml.tr INFO      Epoch   5: train loss  0.64855 (xe:  0.649)
# 11:58 madminer.utils.ml.tr INFO                 val. loss   0.65034 (xe:  0.650)
# 11:58 madminer.utils.ml.tr INFO      Epoch   6: train loss  0.64781 (xe:  0.648)
# 11:58 madminer.utils.ml.tr INFO                 val. loss   0.65000 (xe:  0.650)
# 11:58 madminer.utils.ml.tr INFO      Epoch   7: train loss  0.64731 (xe:  0.647)
# 11:58 madminer.utils.ml.tr INFO                 val. loss   0.64989 (xe:  0.650)
# 11:58 madminer.utils.ml.tr INFO      Epoch   8: train loss  0.64705 (xe:  0.647)
# 11:58 madminer.utils.ml.tr INFO                 val. loss   0.64963 (xe:  0.650)
# 11:58 madminer.utils.ml.tr INFO      Epoch   9: train loss  0.64686 (xe:  0.647)
# 11:58 madminer.utils.ml.tr INFO                 val. loss   0.64969 (xe:  0.650)
# 11:58 madminer.utils.ml.tr INFO      Epoch  10: train loss  0.64672 (xe:  0.647)
# 11:58 madminer.utils.ml.tr INFO                 val. loss   0.64921 (xe:  0.649)
# 11:58 madminer.utils.ml.tr INFO    Early stopping did not improve performance
# 11:58 madminer.utils.ml.tr INFO    Training time spend on:
# 11:58 madminer.utils.ml.tr INFO                      initialize model:   0.00h
# 11:58 madminer.utils.ml.tr INFO                                   ALL:   0.01h
# 11:58 madminer.utils.ml.tr INFO                            check data:   0.00h
# 11:58 madminer.utils.ml.tr INFO                          make dataset:   0.00h
# 11:58 madminer.utils.ml.tr INFO                       make dataloader:   0.00h
# 11:58 madminer.utils.ml.tr INFO                       setup optimizer:   0.00h
# 11:58 madminer.utils.ml.tr INFO                   initialize training:   0.00h
# 11:58 madminer.utils.ml.tr INFO                                set lr:   0.00h
# 11:58 madminer.utils.ml.tr INFO                   load training batch:   0.00h
# 11:58 madminer.utils.ml.tr INFO                        fwd: move data:   0.00h
# 11:58 madminer.utils.ml.tr INFO                   fwd: check for nans:   0.00h
# 11:58 madminer.utils.ml.tr INFO                    fwd: model.forward:   0.00h
# 11:58 madminer.utils.ml.tr INFO                 fwd: calculate losses:   0.00h
# 11:58 madminer.utils.ml.tr INFO                 training forward pass:   0.00h
# 11:58 madminer.utils.ml.tr INFO                   training sum losses:   0.00h
# 11:58 madminer.utils.ml.tr INFO                        opt: zero grad:   0.00h
# 11:58 madminer.utils.ml.tr INFO                         opt: backward:   0.00h
# 11:58 madminer.utils.ml.tr INFO                   opt: clip grad norm:   0.00h
# 11:58 madminer.utils.ml.tr INFO                             opt: step:   0.00h
# 11:58 madminer.utils.ml.tr INFO                        optimizer step:   0.00h
# 11:58 madminer.utils.ml.tr INFO                 load validation batch:   0.00h
# 11:58 madminer.utils.ml.tr INFO               validation forward pass:   0.00h
# 11:58 madminer.utils.ml.tr INFO                 validation sum losses:   0.00h
# 11:58 madminer.utils.ml.tr INFO                        early stopping:   0.00h
# 11:58 madminer.utils.ml.tr INFO                          report epoch:   0.00h
# 11:58 madminer.ml.paramete INFO    Starting training
# 11:58 madminer.ml.paramete INFO      Method:                 alice
# 11:58 madminer.ml.paramete INFO      Batch size:             128
# 11:58 madminer.ml.paramete INFO      Optimizer:              amsgrad
# 11:58 madminer.ml.paramete INFO      Epochs:                 10
# 11:58 madminer.ml.paramete INFO      Learning rate:          0.0003 initially, decaying to 0.0001
# 11:58 madminer.ml.paramete INFO      Validation split:       0.25
# 11:58 madminer.ml.paramete INFO      Early stopping:         True
# 11:58 madminer.ml.paramete INFO      Scale inputs:           True
# 11:58 madminer.ml.paramete INFO      Scale parameters:       True
# 11:58 madminer.ml.paramete INFO      Shuffle labels          False
# 11:58 madminer.ml.paramete INFO      Samples:                all
# 11:58 madminer.ml.paramete INFO    Loading training data
# 11:58 madminer.utils.vario INFO      Loading data/theta0_train.npy into RAM
# 11:58 madminer.utils.vario INFO      Loading data/x_train.npy into RAM
# 11:58 madminer.utils.vario INFO      Loading data/y_train.npy into RAM
# 11:58 madminer.utils.vario INFO      Loading data/r_xz_train.npy into RAM
# 11:58 madminer.utils.vario INFO      Loading data/t_xz_train.npy into RAM
# 11:58 madminer.ml.paramete INFO    Found 100000 samples with 1 parameters and 1 observables
# 11:58 madminer.ml.base     INFO    Input rescaling already defined. To overwrite, call initialize_input_transform(x, overwrite=True).
# 11:58 madminer.ml.paramete INFO    Rescaling parameters
# 11:58 madminer.ml.base     INFO    Setting up parameter rescaling
# 11:58 madminer.ml.paramete INFO    Training model
# 11:58 madminer.utils.ml.tr INFO    Training on CPU with single precision
# 11:58 madminer.utils.ml.tr INFO      Epoch   1: train loss  0.64564 (improved_xe:  0.646)
# 11:58 madminer.utils.ml.tr INFO                 val. loss   0.64523 (improved_xe:  0.645)
# 11:58 madminer.utils.ml.tr INFO      Epoch   2: train loss  0.64535 (improved_xe:  0.645)
# 11:58 madminer.utils.ml.tr INFO                 val. loss   0.64499 (improved_xe:  0.645)
# 11:58 madminer.utils.ml.tr INFO      Epoch   3: train loss  0.64521 (improved_xe:  0.645)
# 11:58 madminer.utils.ml.tr INFO                 val. loss   0.64496 (improved_xe:  0.645)
# 11:58 madminer.utils.ml.tr INFO      Epoch   4: train loss  0.64513 (improved_xe:  0.645)
# 11:58 madminer.utils.ml.tr INFO                 val. loss   0.64495 (improved_xe:  0.645)
# 11:58 madminer.utils.ml.tr INFO      Epoch   5: train loss  0.64508 (improved_xe:  0.645)
# 11:58 madminer.utils.ml.tr INFO                 val. loss   0.64481 (improved_xe:  0.645)
# 11:58 madminer.utils.ml.tr INFO      Epoch   6: train loss  0.64504 (improved_xe:  0.645)
# 11:58 madminer.utils.ml.tr INFO                 val. loss   0.64476 (improved_xe:  0.645)
# 11:58 madminer.utils.ml.tr INFO      Epoch   7: train loss  0.64502 (improved_xe:  0.645)
# 11:58 madminer.utils.ml.tr INFO                 val. loss   0.64476 (improved_xe:  0.645)
# 11:58 madminer.utils.ml.tr INFO      Epoch   8: train loss  0.64500 (improved_xe:  0.645)
# 11:58 madminer.utils.ml.tr INFO                 val. loss   0.64464 (improved_xe:  0.645)
# 11:59 madminer.utils.ml.tr INFO      Epoch   9: train loss  0.64499 (improved_xe:  0.645)
# 11:59 madminer.utils.ml.tr INFO                 val. loss   0.64476 (improved_xe:  0.645)
# 11:59 madminer.utils.ml.tr INFO      Epoch  10: train loss  0.64497 (improved_xe:  0.645)
# 11:59 madminer.utils.ml.tr INFO                 val. loss   0.64477 (improved_xe:  0.645)
# 11:59 madminer.utils.ml.tr INFO    Early stopping after epoch 8, with loss  0.64464 compared to final loss  0.64477
# 11:59 madminer.utils.ml.tr INFO    Training time spend on:
# 11:59 madminer.utils.ml.tr INFO                      initialize model:   0.00h
# 11:59 madminer.utils.ml.tr INFO                                   ALL:   0.01h
# 11:59 madminer.utils.ml.tr INFO                            check data:   0.00h
# 11:59 madminer.utils.ml.tr INFO                          make dataset:   0.00h
# 11:59 madminer.utils.ml.tr INFO                       make dataloader:   0.00h
# 11:59 madminer.utils.ml.tr INFO                       setup optimizer:   0.00h
# 11:59 madminer.utils.ml.tr INFO                   initialize training:   0.00h
# 11:59 madminer.utils.ml.tr INFO                                set lr:   0.00h
# 11:59 madminer.utils.ml.tr INFO                   load training batch:   0.00h
# 11:59 madminer.utils.ml.tr INFO                        fwd: move data:   0.00h
# 11:59 madminer.utils.ml.tr INFO                   fwd: check for nans:   0.00h
# 11:59 madminer.utils.ml.tr INFO                    fwd: model.forward:   0.00h
# 11:59 madminer.utils.ml.tr INFO                 fwd: calculate losses:   0.00h
# 11:59 madminer.utils.ml.tr INFO                 training forward pass:   0.00h
# 11:59 madminer.utils.ml.tr INFO                   training sum losses:   0.00h
# 11:59 madminer.utils.ml.tr INFO                        opt: zero grad:   0.00h
# 11:59 madminer.utils.ml.tr INFO                         opt: backward:   0.00h
# 11:59 madminer.utils.ml.tr INFO                   opt: clip grad norm:   0.00h
# 11:59 madminer.utils.ml.tr INFO                             opt: step:   0.00h
# 11:59 madminer.utils.ml.tr INFO                        optimizer step:   0.00h
# 11:59 madminer.utils.ml.tr INFO                 load validation batch:   0.00h
# 11:59 madminer.utils.ml.tr INFO               validation forward pass:   0.00h
# 11:59 madminer.utils.ml.tr INFO                 validation sum losses:   0.00h
# 11:59 madminer.utils.ml.tr INFO                        early stopping:   0.00h
# 11:59 madminer.utils.ml.tr INFO                          report epoch:   0.00h
# 11:59 madminer.ml.base     INFO    Saving model to models/mix

# %% [markdown]
# ## 4. Generate evaluation data

# %% [markdown]
# Let us now generate some test data, which is sampled corresponding to `theta=1`

# %%
n_param_points_test = 1000  # number of parameter points to test
theta_test = 1.0 * np.ones(shape=n_param_points_test)

# %% [markdown]
# Run the simulator to get observations:

# %%
x_test = []
for t in theta_test:
    x_test.append(simulate(t)[0])
np.save("data_standard_balanced/x_test.npy", x_test)

# %% [markdown]
# We want to evaluate the expected likelihood ratio on a range of parameter points:

# %%
theta_grid = np.linspace(-5.0, 5.0, 100).reshape(-1, 1)
np.save("data_standard_balanced/theta_grid.npy", theta_grid)

# %% [markdown]
# In this toy example, we can calculate the true likelihood ratio. We will save the expected log likelihood ratio (multiplied with a conventional factor of -2):

# %%
all_log_r_test_true = []
nllr_test_true = []

for theta in theta_grid:
    log_r = np.log(calculate_likelihood_ratio(x_test, theta))
    nllr_test_true.append(-2.0 * np.mean(log_r))
    all_log_r_test_true.append(log_r)

all_log_r_test_true = np.asarray(all_log_r_test_true).reshape((100, n_param_points_test))
nllr_test_true = np.asarray(nllr_test_true)

# %% [markdown]
# ## 5. Evaluation

# %% [markdown]
# It's time to evaluate our likelihood ratio estimators!

# %%
carl = ParameterizedRatioEstimator()
carl.load("models_standard_balancedcarl")

log_r, _ = carl.evaluate(
    theta="data_standard_balanced/theta_grid.npy",
    x="data_standard_balanced/x_test.npy",
    evaluate_score=False,
)

nllr_test_carl = -2.0 * np.mean(log_r, axis=1)
mse_carl = np.mean((all_log_r_test_true - log_r) ** 2)
print("MSE:", mse_carl)
# Out:
# 11:59 madminer.ml.base     INFO    Loading model from models/carl
# 11:59 madminer.utils.vario INFO      Loading data/x_test.npy into RAM
# 11:59 madminer.utils.vario INFO      Loading data/theta_grid.npy into RAM
# MSE: 0.016598196198759345

# %%
alices = ParameterizedRatioEstimator()
alices.load("models_standard_balancedalices")

log_r, _ = alices.evaluate(
    theta="data_standard_balanced/theta_grid.npy",
    x="data_standard_balanced/x_test.npy",
    evaluate_score=False,
)

nllr_test_alices = -2.0 * np.mean(log_r, axis=1)
mse_alices = np.mean((all_log_r_test_true - log_r) ** 2)
print("MSE:", mse_alices)
# Out:
# 11:59 madminer.ml.base     INFO    Loading model from models/alices
# 11:59 madminer.utils.vario INFO      Loading data/x_test.npy into RAM
# 11:59 madminer.utils.vario INFO      Loading data/theta_grid.npy into RAM
# MSE: 0.0036182470292972064

# %%
mix = ParameterizedRatioEstimator()
mix.load("models_standard_balancedmix")

log_r, _ = mix.evaluate(
    theta="data_standard_balanced/theta_grid.npy",
    x="data_standard_balanced/x_test.npy",
    evaluate_score=False,
)

nllr_test_mix = -2.0 * np.mean(log_r, axis=1)
mse_mix = np.mean((all_log_r_test_true - log_r) ** 2)
print("MSE:", mse_mix)
# Out:
# 11:59 madminer.ml.base     INFO    Loading model from models/mix
# 11:59 madminer.utils.vario INFO      Loading data/x_test.npy into RAM
# 11:59 madminer.utils.vario INFO      Loading data/theta_grid.npy into RAM
# MSE: 0.005137807290532101

# %% [markdown]
# This is the expected log likelihood ratio over parameter space:

# %%
best_fit_alices = float(theta_grid[np.argmin(nllr_test_alices)])
best_fit_carl = float(theta_grid[np.argmin(nllr_test_carl)])
best_fit_mix = float(theta_grid[np.argmin(nllr_test_mix)])

fig = plt.figure(figsize=(5, 5))

plt.plot(
    theta_grid,
    nllr_test_true,
    ls="--",
    c="black",
    label=r"Ground truth ($\theta = 1.0$)",
)
plt.plot(
    theta_grid,
    nllr_test_carl,
    label=r"CARL ($\hat{\theta} = " + "{:.3f}$)".format(best_fit_carl),
)
plt.plot(
    theta_grid,
    nllr_test_alices,
    label=r"ALICES ($\hat{\theta} = " + "{:.3f}$)".format(best_fit_alices),
)
plt.plot(
    theta_grid,
    nllr_test_mix,
    label=r"CARL-ALICES ($\hat{\theta} = " + "{:.3f}$)".format(best_fit_mix),
)

plt.xlabel(r"$\theta$")
plt.ylabel(r"$\mathbb{E}_x [ -2\, \log \,r(x | \theta, \theta_{1}) ]$")

plt.legend()
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_2555922/1526069039.py:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   best_fit_alices = float(theta_grid[np.argmin(nllr_test_alices)])
# /tmp/ipykernel_2555922/1526069039.py:2: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   best_fit_carl = float(theta_grid[np.argmin(nllr_test_carl)])
# /tmp/ipykernel_2555922/1526069039.py:3: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   best_fit_mix = float(theta_grid[np.argmin(nllr_test_mix)])

# %% [markdown]
# You should see that the new ALICES approach leads to a better approximation of the true likelihood ratio than the CARL estimate. Note that we only trained in the parameter range (-4, 4), so the deviations at the left and right of the plot are to be expected.

# %%
plt.hist(x_test)
# Out:
# (array([  6.,  36.,  88., 203., 225., 236., 144.,  50.,  10.,   2.]),
#  array([-6.66282459, -5.04017922, -3.41753385, -1.79488848, -0.1722431 ,
#          1.45040227,  3.07304764,  4.69569301,  6.31833838,  7.94098375,
#          9.56362913]),
#  <BarContainer object of 10 artists>)
